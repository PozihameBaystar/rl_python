# %% [markdown]
# # 自作のTRPOノートブック

# %%
import numpy as np
import copy
from dataclasses import dataclass, field, asdict, is_dataclass

import sys
import logging

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal

import gymnasium as gym

from myActivator import tanhAndScale
from myFunction import make_squashed_gaussian

# %%
logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s [%(levelname)s] %(message)s",
                    stream=sys.stdout, datefmt="%H:%M:%S")

# %%
env = gym.make("Pendulum-v1")
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
for key in vars(env.unwrapped):
    logging.info('%s: %s', key, vars(env.unwrapped)[key])
# Out:
# 04:10:35 [INFO] id: Pendulum-v1
# 04:10:35 [INFO] entry_point: gymnasium.envs.classic_control.pendulum:PendulumEnv
# 04:10:35 [INFO] reward_threshold: None
# 04:10:35 [INFO] nondeterministic: False
# 04:10:35 [INFO] max_episode_steps: 200
# 04:10:35 [INFO] order_enforce: True
# 04:10:35 [INFO] disable_env_checker: False
# 04:10:35 [INFO] kwargs: {}
# 04:10:35 [INFO] additional_wrappers: ()
# 04:10:35 [INFO] vector_entry_point: None
# 04:10:35 [INFO] namespace: None
# 04:10:35 [INFO] name: Pendulum
# 04:10:35 [INFO] version: 1
# 04:10:35 [INFO] max_speed: 8
# 04:10:35 [INFO] max_torque: 2.0
# 04:10:35 [INFO] dt: 0.05
# 04:10:35 [INFO] g: 10.0
# 04:10:35 [INFO] m: 1.0
# 04:10:35 [INFO] l: 1.0
# 04:10:35 [INFO] render_mode: None
# 04:10:35 [INFO] screen_dim: 500
# 04:10:35 [INFO] screen: None
# 04:10:35 [INFO] clock: None
# 04:10:35 [INFO] isopen: True
# 04:10:35 [INFO] action_space: Box(-2.0, 2.0, (1,), float32)
# 04:10:35 [INFO] observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# 04:10:35 [INFO] spec: EnvSpec(id='Pendulum-v1', entry_point='gymnasium.envs.classic_control.pendulum:PendulumEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=False, disable_env_checker=True, kwargs={}, namespace=None, name='Pendulum', version=1, additional_wrappers=(), vector_entry_point=None)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from dataclasses import dataclass, field

@dataclass
class Config:
    # ===== Pendulum-v1 specs =====
    obs_dim: int = 3
    act_dim: int = 1

    # TRPOAgent 側は Config.u_llim / Config.u_ulim を参照
    u_llim: list[float] = field(default_factory=lambda: [-2.0])
    u_ulim: list[float] = field(default_factory=lambda: [ 2.0])

    # ===== Network architecture =====
    V_net_in: int = 3
    P_net_in: int = 3

    # ★修正: [256, 256] -> [64, 64] に変更
    # Pendulumのような単純な系でパラメータが多すぎると、TRPOの共役勾配法が不安定になります
    V_net_sizes: list[int] = field(default_factory=lambda: [64, 64])
    P_net_sizes: list[int] = field(default_factory=lambda: [64, 64])

    V_net_out: int = 1
    P_net_out: int = 1  # = act_dim

    # ===== Optimizer =====
    V_lr: float = 1e-3
    P_lr: float = 3e-4   # unused

    # ===== GAE / discount =====
    gamma: float = 0.99
    lam: float = 0.97

    # ===== TRPO hyperparameters =====
    max_kl: float = 1e-2
    cg_iters: int = 10
    cg_damping: float = 0.1

    ls_max_steps: int = 10
    ls_backtrack: float = 0.8
    ls_accept_ratio: float = 0.1

    # ===== Value function training =====
    value_train_iters: int = 80
    value_l2_reg: float = 1e-3

    # ===== Rollout / training loop side =====
    batch_steps: int = 5000
    bootstrap_on_timeout: bool = False

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal
from dataclasses import asdict, is_dataclass

class TRPOAgent:
    """
    Baseline（動いてる版）に寄せた TRPO 実装（修正済み完全版）。

    修正点:
    1. step() メソッドをデフォルトで「決定論的（平均値）」に変更し、評価時のスコアを安定化。
    2. update_net() で actions の形状を (Batch, act_dim) に強制し、Broadcasting事故を防止。
    3. update_net() で log_probs がリスト(float)かTensorか判別し、確実に計算グラフから切断。
    """

    def __init__(self, Config, device=None):
        if Config is None:
            raise ValueError("No Config!!")
        self.Config = Config

        # device
        if device is None:
            self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        else:
            self.device = torch.device(device)

        # action bounds (for env clip only)
        self.u_low = torch.as_tensor(Config.u_llim, dtype=torch.float32, device=self.device)
        self.u_high = torch.as_tensor(Config.u_ulim, dtype=torch.float32, device=self.device)

        # networks
        self.V_net = self.build_net(Config.V_net_in, Config.V_net_sizes, Config.V_net_out).to(self.device)
        self.P_net = self.build_net(Config.P_net_in, Config.P_net_sizes, Config.P_net_out).to(self.device)

        self.V_net.train()
        self.P_net.train()

        # log_std は状態に依存しないパラメータ
        action_dim = Config.P_net_out
        self.log_std = nn.Parameter(torch.zeros(action_dim, device=self.device))

        # critic optimizer（baselineはAdam）
        self.V_optim = optim.Adam(self.V_net.parameters(), lr=Config.V_lr)

        # hyperparams
        self.gamma = float(Config.gamma)
        self.tau = float(Config.lam)  # baselineの TAU (= GAE lambda)
        self.max_kl = float(Config.max_kl)
        self.cg_iters = int(Config.cg_iters)
        self.cg_damping = float(Config.cg_damping)

        self.value_train_iters = int(getattr(Config, "value_train_iters", 5))
        self.value_l2_reg = float(getattr(Config, "value_l2_reg", 1e-3))

        self.backtrack_coeff = float(getattr(Config, "ls_backtrack", 0.8))
        self.backtrack_iters = int(getattr(Config, "ls_max_steps", 10))

    def build_net(self, input_size, hidden_sizes, output_size):
        layers = []
        prev = input_size
        for h in hidden_sizes:
            layers.append(nn.Linear(prev, h))
            layers.append(nn.Tanh())
            prev = h
        layers.append(nn.Linear(prev, output_size))
        return nn.Sequential(*layers)

    # ------------------------------------------------------------
    # Policy helpers (baseline-style)
    # ------------------------------------------------------------
    def _policy_mean(self, states: torch.Tensor) -> torch.Tensor:
        # (T, obs_dim) -> (T, act_dim)
        return self.P_net(states)

    def _policy_dist(self, states: torch.Tensor) -> Normal:
        mean = self._policy_mean(states)
        std = torch.exp(self.log_std)  # (act_dim,)
        # broadcasting: (T, act_dim) with (act_dim,)
        return Normal(mean, std)

    def _log_prob(self, states: torch.Tensor, actions: torch.Tensor) -> torch.Tensor:
        # returns shape (T,)
        dist = self._policy_dist(states)
        return dist.log_prob(actions).sum(dim=-1)

    @torch.no_grad()
    def get_action_and_log_prob(self, state, deterministic=False):
        """
        deterministic: Trueなら平均値(mean)を返す。Falseならサンプリング。
        """
        s = torch.as_tensor(state, dtype=torch.float32, device=self.device)
        if s.dim() == 1:
            s = s.unsqueeze(0)  # (1, obs_dim)

        dist = self._policy_dist(s)  # Normal(mean, std)

        if deterministic:
            a = dist.mean  # (1, act_dim)
            logp = None
        else:
            a = dist.sample()
            logp = dist.log_prob(a).sum(dim=-1)  # (1,)

        # 返す action は “clip前” を返す（baselineと同じ）
        # envに入れる直前で clip してください
        a = a.squeeze(0)
        if logp is not None:
            logp = logp.squeeze(0)
        return a, logp

    @torch.no_grad()
    def step(self, state):
        """
        【重要修正】推論時はデフォルトで「決定論的（平均値）」を使用する。
        これにより、評価時のスコアが安定して高くなる。
        """
        a, _ = self.get_action_and_log_prob(state, deterministic=True)
        return a.cpu().numpy()

    # ------------------------------------------------------------
    # Flat params / grads (baseline-style)
    # ------------------------------------------------------------
    def _flat_params(self) -> torch.Tensor:
        return torch.cat([p.data.view(-1) for p in list(self.P_net.parameters()) + [self.log_std]])

    def _set_flat_params(self, flat: torch.Tensor):
        idx = 0
        # P_net params
        for p in self.P_net.parameters():
            n = p.numel()
            p.data.copy_(flat[idx:idx+n].view_as(p))
            idx += n
        # log_std
        n = self.log_std.numel()
        self.log_std.data.copy_(flat[idx:idx+n].view_as(self.log_std))
        idx += n

    def _flat_grad(self, scalar: torch.Tensor, retain_graph=False, create_graph=False) -> torch.Tensor:
        params = list(self.P_net.parameters()) + [self.log_std]
        grads = torch.autograd.grad(
            scalar, params,
            retain_graph=retain_graph,
            create_graph=create_graph,
            allow_unused=False,
        )
        return torch.cat([g.contiguous().view(-1) for g in grads])

    # ------------------------------------------------------------
    # GAE (baseline-style)
    # ------------------------------------------------------------
    @torch.no_grad()
    def _compute_gae(self, rewards, values, next_values, dones):
        """
        rewards, dones: (T,)
        values, next_values: (T,)
        """
        T = rewards.shape[0]
        adv = torch.zeros_like(rewards)
        gae = 0.0

        for t in reversed(range(T)):
            if t == T - 1:
                nv = next_values[t]
            else:
                nv = values[t + 1]
            delta = rewards[t] + self.gamma * nv * (1.0 - dones[t]) - values[t]
            gae = delta + self.gamma * self.tau * (1.0 - dones[t]) * gae
            adv[t] = gae

        ret = adv + values
        return adv, ret

    # ------------------------------------------------------------
    # TRPO core (baseline-style)
    # ------------------------------------------------------------
    def _conjugate_gradient(self, Avp_fn, b, n_iters=10, residual_tol=1e-10):
        x = torch.zeros_like(b)
        r = b.clone()
        p = b.clone()
        rdotr = torch.dot(r, r)

        for _ in range(n_iters):
            Ap = Avp_fn(p)
            alpha = rdotr / (torch.dot(p, Ap) + 1e-8)
            x = x + alpha * p
            r = r - alpha * Ap
            new_rdotr = torch.dot(r, r)
            if new_rdotr < residual_tol:
                break
            beta = new_rdotr / (rdotr + 1e-12)
            p = r + beta * p
            rdotr = new_rdotr
        return x

    def _fisher_vector_product(self, states: torch.Tensor, v: torch.Tensor):
        dist_new = self._policy_dist(states)

        # detach old
        mean_old = dist_new.mean.detach()
        std_old = dist_new.stddev.detach()
        dist_old = Normal(mean_old, std_old)

        # KL(old||new)
        kl = torch.distributions.kl_divergence(dist_old, dist_new).sum(dim=-1).mean()

        # grad KL
        kl_grad = self._flat_grad(kl, retain_graph=True, create_graph=True)

        # (grad KL)^T v
        kl_grad_v = torch.dot(kl_grad, v)

        # Hessian-vector product
        hvp = self._flat_grad(kl_grad_v, retain_graph=True, create_graph=False)

        return hvp + self.cg_damping * v

    def _surrogate_loss(self, states, actions, advantages, old_log_probs):
        new_logp = self._log_prob(states, actions)
        ratio = torch.exp(new_logp - old_log_probs)
        return -(ratio * advantages).mean()

    def _trpo_step(self, states, actions, advantages, old_log_probs):
        # 1) policy gradient of surrogate loss
        loss = self._surrogate_loss(states, actions, advantages, old_log_probs)
        g = self._flat_grad(loss, retain_graph=True, create_graph=False)

        # 2) CG: solve F x = -g
        def Fvp(v):
            return self._fisher_vector_product(states, v)

        step_dir = self._conjugate_gradient(Fvp, -g, n_iters=self.cg_iters)

        # 3) scale to satisfy KL constraint
        shs = 0.5 * torch.dot(step_dir, Fvp(step_dir))
        if shs.item() <= 0.0:
            return False

        lm = torch.sqrt(shs / self.max_kl)
        full_step = step_dir / (lm + 1e-8)

        # 4) line search
        old_params = self._flat_params()
        old_loss = loss.item()

        step_frac = 1.0
        for _ in range(self.backtrack_iters):
            new_params = old_params + step_frac * full_step
            self._set_flat_params(new_params)

            with torch.no_grad():
                new_loss = self._surrogate_loss(states, actions, advantages, old_log_probs).item()

            if new_loss < old_loss:
                return True

            step_frac *= self.backtrack_coeff

        # fail: revert
        self._set_flat_params(old_params)
        return False

    # ------------------------------------------------------------
    # Value update (baseline-style)
    # ------------------------------------------------------------
    def _update_value_function(self, states, returns):
        last_loss = None
        for _ in range(self.value_train_iters):
            v_pred = self.V_net(states).squeeze(-1)
            v_loss = (v_pred - returns).pow(2).mean()

            # L2 reg
            l2 = 0.0
            for p in self.V_net.parameters():
                l2 = l2 + p.pow(2).sum()
            v_loss = v_loss + self.value_l2_reg * l2

            self.V_optim.zero_grad()
            v_loss.backward()
            self.V_optim.step()

            last_loss = v_loss.item()
        return last_loss

    # ------------------------------------------------------------
    # Public update API (Fixed Version)
    # ------------------------------------------------------------
    def update_net(self, states, actions, log_probs, rewards, states_next, dones):
        """
        学習ループから呼ばれるメイン更新関数。

        Fixes:
        1. actions.view(-1, act_dim) で形状不一致バグを修正。
        2. old_log_probs の detach 漏れを修正。
        """
        states = torch.as_tensor(states, dtype=torch.float32, device=self.device)
        states_next = torch.as_tensor(states_next, dtype=torch.float32, device=self.device)
        rewards = torch.as_tensor(rewards, dtype=torch.float32, device=self.device).view(-1)
        dones = torch.as_tensor(dones, dtype=torch.float32, device=self.device).view(-1)

        # 【修正】Actionの次元を明示的に整形 (Broadcasting事故防止)
        # 入力が (Batch,) だと broadcasting で (Batch, Batch) になり計算が壊れるため、(Batch, 1) 等に強制する
        actions = torch.as_tensor(actions, dtype=torch.float32, device=self.device).view(-1, self.Config.act_dim)

        # 【修正】old_log_probs を確実に計算グラフから切断 (.detach())
        if isinstance(log_probs, (list, tuple)):
            # floatのリストが来た場合 (推奨) -> Tensor化
            old_log_probs = torch.tensor(log_probs, dtype=torch.float32, device=self.device).view(-1)
        else:
            # Tensorが来た場合 -> detachしてコピー
            old_log_probs = torch.as_tensor(log_probs, dtype=torch.float32, device=self.device).view(-1).detach()

        # 1) values
        with torch.no_grad():
            values = self.V_net(states).squeeze(-1)
            next_values = self.V_net(states_next).squeeze(-1)

        # 2) GAE
        with torch.no_grad():
            advantages, returns = self._compute_gae(rewards, values, next_values, dones)
            # normalize advantage
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        # 3) TRPO policy update
        trpo_ok = self._trpo_step(states, actions, advantages, old_log_probs)

        # 4) Value update
        v_loss = self._update_value_function(states, returns)

        return {"V_loss": v_loss, "trpo_ok": trpo_ok}

    # ------------------------------------------------------------
    # misc
    # ------------------------------------------------------------
    def to(self, device):
        self.device = torch.device(device)
        self.V_net.to(self.device)
        self.P_net.to(self.device)
        self.log_std.data = self.log_std.data.to(self.device)
        self.u_low = self.u_low.to(self.device)
        self.u_high = self.u_high.to(self.device)
        return self

    def mode2eval(self):
        self.V_net.eval()
        self.P_net.eval()

    def mode2train(self):
        self.V_net.train()
        self.P_net.train()

    def save_all(self, path: str, extra: dict | None = None):
        cfg = asdict(self.Config) if is_dataclass(self.Config) else self.Config
        save_dict = {
            "Config": cfg,
            "V_net_state_dict": self.V_net.state_dict(),
            "P_net_state_dict": self.P_net.state_dict(),
            "log_std": self.log_std.data,
        }
        if extra is not None:
            save_dict.update(extra)
        torch.save(save_dict, path)
        
    def load_all(self, path: str, map_location=None):
        load_dict = torch.load(path, map_location=map_location)
        self.V_net.load_state_dict(load_dict["V_net_state_dict"])
        self.P_net.load_state_dict(load_dict["P_net_state_dict"])
        self.log_std.data = load_dict["log_std"].to(self.device)

# %%
import numpy as np
import torch
import logging

def train_trpo(
    env,
    agent,
    total_step: int = 200_000,
    batch_steps: int | None = None,
    random_steps: int = 0,
    bootstrap_on_timeout: bool | None = None,
    log_interval_updates: int = 1,
):
    if batch_steps is None:
        batch_steps = int(getattr(agent.Config, "batch_steps", 5000))
    if bootstrap_on_timeout is None:
        bootstrap_on_timeout = bool(getattr(agent.Config, "bootstrap_on_timeout", False))

    print(f"Start Training: Device={agent.device}, Batch={batch_steps}")

    low_np = agent.u_low.detach().cpu().numpy()
    high_np = agent.u_high.detach().cpu().numpy()

    V_loss_history = []
    trpo_ok_history = []
    
    # 評価用に学習中のReward推移（ノイズあり）と評価用Reward（ノイズなし）を分ける
    train_reward_history = []

    # rollout buffer
    rollout = {"obs": [], "act": [], "logp": [], "rew": [], "obs_next": [], "done": []}

    def rollout_clear():
        for k in rollout:
            rollout[k].clear()

    obs, info = env.reset()
    ep_return = 0.0
    episode_num = 1
    update_num = 0

    for t in range(total_step):
        # --- (1) 行動選択 ---
        if t < random_steps:
            action_raw = np.atleast_1d(env.action_space.sample()).astype(np.float32)
            logp_val = 0.0
            use_for_update = False
        else:
            use_for_update = True
            with torch.no_grad():
                # 学習用データ取集なので deterministic=False (探索する)
                a_t, logp_t = agent.get_action_and_log_prob(obs, deterministic=False)
            
            action_raw = np.atleast_1d(a_t.detach().cpu().numpy()).astype(np.float32)
            # ★修正: メモリ節約のため item() で float にして保持する
            logp_val = logp_t.item()

        # --- (2) env step ---
        action_env = np.clip(action_raw, low_np, high_np)
        obs_next, reward, terminated, truncated, info = env.step(action_env)

        ep_return += float(reward)

        if bootstrap_on_timeout:
            done_for_gae = float(terminated)
        else:
            done_for_gae = float(terminated or truncated)
        
        done_for_reset = (terminated or truncated)

        # --- (3) 保存 ---
        if use_for_update:
            rollout["obs"].append(np.asarray(obs, dtype=np.float32))
            rollout["act"].append(np.asarray(action_raw, dtype=np.float32))
            rollout["logp"].append(logp_val)  # float
            rollout["rew"].append(float(reward))
            rollout["obs_next"].append(np.asarray(obs_next, dtype=np.float32))
            rollout["done"].append(float(done_for_gae))

        # --- (4) Reset判定 ---
        if done_for_reset:
            train_reward_history.append(ep_return)
            episode_num += 1
            ep_return = 0.0
            obs, info = env.reset()
        else:
            obs = obs_next

        # --- (5) Update ---
        if len(rollout["obs"]) >= batch_steps:
            update_num += 1

            # numpy/list -> tensor conversion
            states      = np.stack(rollout["obs"], axis=0)
            actions     = np.stack(rollout["act"], axis=0)
            log_probs   = rollout["logp"] # list of floats
            rewards     = np.asarray(rollout["rew"], dtype=np.float32)
            states_next = np.stack(rollout["obs_next"], axis=0)
            dones       = np.asarray(rollout["done"], dtype=np.float32)

            # Update
            out = agent.update_net(states, actions, log_probs, rewards, states_next, dones)
            rollout_clear()

            if isinstance(out, dict):
                V_loss_history.append(float(out.get("V_loss", 0.0)))
                trpo_ok_history.append(bool(out.get("trpo_ok", False)))

            # --- ★修正: 評価フェーズ (Evaluation) ---
            # ノイズなしでプレイして真の実力を測る
            if (update_num % log_interval_updates) == 0:
                eval_score = evaluate(env, agent, n_episodes=3)
                vloss = V_loss_history[-1] if V_loss_history else 0.0
                trpo_res = "OK" if trpo_ok_history[-1] else "NG"
                
                logging.info(
                    f"Update {update_num:4d} | Eval Score: {eval_score:8.2f} | V_Loss: {vloss:.4f} | TRPO: {trpo_res}"
                )

    return V_loss_history, trpo_ok_history, train_reward_history

# ★追加: 評価用関数
def evaluate(env, agent, n_episodes=3):
    scores = []
    for _ in range(n_episodes):
        obs, _ = env.reset()
        done = False
        score = 0.0
        while not done:
            # step() は内部で deterministic=True に修正済み
            action = agent.step(obs)
            # Env側でclip
            action = np.clip(action, agent.u_low.cpu().numpy(), agent.u_high.cpu().numpy())
            
            obs, rew, term, trunc, _ = env.step(action)
            score += rew
            done = term or trunc
        scores.append(score)
    return np.mean(scores)

# %%
agent = TRPOAgent(Config=Config(),device=device)
total_step=2500000

Vh, ph, rh = train_trpo(
    env=env,
    agent=agent,
    total_step=total_step,
    batch_steps=2048,
)
# Out:
# Start Training: Device=cuda, Batch=2048
# 04:10:41 [INFO] Update    1 | Eval Score: -1507.51 | V_Loss: 13777.2090 | TRPO: OK
# 04:10:45 [INFO] Update    2 | Eval Score: -1229.02 | V_Loss: 20503.7539 | TRPO: OK
# 04:10:50 [INFO] Update    3 | Eval Score:  -995.58 | V_Loss: 15797.1523 | TRPO: OK
# 04:10:54 [INFO] Update    4 | Eval Score: -1050.86 | V_Loss: 14221.4336 | TRPO: OK
# 04:10:59 [INFO] Update    5 | Eval Score:  -965.41 | V_Loss: 13971.7393 | TRPO: OK
# 04:11:03 [INFO] Update    6 | Eval Score:  -979.62 | V_Loss: 18486.4316 | TRPO: OK
# 04:11:07 [INFO] Update    7 | Eval Score:  -984.24 | V_Loss: 12865.2773 | TRPO: OK
# 04:11:11 [INFO] Update    8 | Eval Score: -1416.60 | V_Loss: 13844.6689 | TRPO: OK
# 04:11:16 [INFO] Update    9 | Eval Score:  -990.24 | V_Loss: 16324.8418 | TRPO: OK
# 04:11:20 [INFO] Update   10 | Eval Score: -1237.56 | V_Loss: 11457.9531 | TRPO: OK
# 04:11:25 [INFO] Update   11 | Eval Score: -1196.27 | V_Loss: 13341.6514 | TRPO: OK
# 04:11:29 [INFO] Update   12 | Eval Score: -1286.89 | V_Loss: 16537.6387 | TRPO: OK
# 04:11:34 [INFO] Update   13 | Eval Score: -1138.05 | V_Loss: 13312.0029 | TRPO: OK
# 04:11:38 [INFO] Update   14 | Eval Score:  -968.37 | V_Loss: 12118.7607 | TRPO: OK
# 04:11:43 [INFO] Update   15 | Eval Score: -1222.17 | V_Loss: 11971.7637 | TRPO: OK
# 04:11:47 [INFO] Update   16 | Eval Score: -1221.73 | V_Loss: 10124.6006 | TRPO: OK
# 04:11:52 [INFO] Update   17 | Eval Score: -1085.39 | V_Loss: 10004.6367 | TRPO: OK
# 04:11:56 [INFO] Update   18 | Eval Score:  -986.25 | V_Loss: 8986.9121 | TRPO: OK
# 04:12:01 [INFO] Update   19 | Eval Score: -1172.59 | V_Loss: 8302.1377 | TRPO: OK
# 04:12:05 [INFO] Update   20 | Eval Score:  -993.74 | V_Loss: 8967.4736 | TRPO: OK
# 04:12:10 [INFO] Update   21 | Eval Score: -1072.56 | V_Loss: 8583.0527 | TRPO: OK
# 04:12:14 [INFO] Update   22 | Eval Score: -1047.34 | V_Loss: 10781.5752 | TRPO: OK
# 04:12:18 [INFO] Update   23 | Eval Score:  -916.57 | V_Loss: 9090.0674 | TRPO: OK
# 04:12:22 [INFO] Update   24 | Eval Score:  -937.55 | V_Loss: 9156.2539 | TRPO: OK
# 04:12:26 [INFO] Update   25 | Eval Score:  -995.68 | V_Loss: 5273.7129 | TRPO: OK
# 04:12:30 [INFO] Update   26 | Eval Score:  -890.57 | V_Loss: 6914.9985 | TRPO: OK
# 04:12:34 [INFO] Update   27 | Eval Score:  -915.42 | V_Loss: 6692.5630 | TRPO: OK
# 04:12:39 [INFO] Update   28 | Eval Score:  -918.98 | V_Loss: 5753.0137 | TRPO: OK
# 04:12:43 [INFO] Update   29 | Eval Score:  -937.56 | V_Loss: 6813.9668 | TRPO: OK
# 04:12:47 [INFO] Update   30 | Eval Score:  -952.47 | V_Loss: 5297.9834 | TRPO: OK
# 04:12:51 [INFO] Update   31 | Eval Score:  -924.02 | V_Loss: 5609.9395 | TRPO: OK
# 04:12:55 [INFO] Update   32 | Eval Score: -1038.45 | V_Loss: 5331.3955 | TRPO: OK
# 04:12:59 [INFO] Update   33 | Eval Score:  -923.58 | V_Loss: 5125.8428 | TRPO: OK
# 04:13:03 [INFO] Update   34 | Eval Score:  -854.66 | V_Loss: 5632.1030 | TRPO: OK
# 04:13:07 [INFO] Update   35 | Eval Score:  -808.39 | V_Loss: 5546.6543 | TRPO: OK
# 04:13:12 [INFO] Update   36 | Eval Score:  -743.48 | V_Loss: 4408.3306 | TRPO: OK
# 04:13:16 [INFO] Update   37 | Eval Score: -1041.47 | V_Loss: 4646.7505 | TRPO: OK
# 04:13:20 [INFO] Update   38 | Eval Score:  -886.29 | V_Loss: 4487.3882 | TRPO: OK
# 04:13:24 [INFO] Update   39 | Eval Score:  -765.47 | V_Loss: 4424.7373 | TRPO: OK
# 04:13:29 [INFO] Update   40 | Eval Score:  -827.73 | V_Loss: 4118.7837 | TRPO: OK
# 04:13:33 [INFO] Update   41 | Eval Score:  -741.34 | V_Loss: 4336.1709 | TRPO: OK
# 04:13:37 [INFO] Update   42 | Eval Score:  -816.17 | V_Loss: 4645.8652 | TRPO: OK
# 04:13:41 [INFO] Update   43 | Eval Score:  -844.01 | V_Loss: 4084.2107 | TRPO: OK
# 04:13:45 [INFO] Update   44 | Eval Score:  -869.84 | V_Loss: 3984.7554 | TRPO: OK
# 04:13:50 [INFO] Update   45 | Eval Score:  -785.05 | V_Loss: 4059.2825 | TRPO: OK
# 04:13:54 [INFO] Update   46 | Eval Score:  -709.26 | V_Loss: 3845.8179 | TRPO: OK
# 04:13:58 [INFO] Update   47 | Eval Score:  -770.77 | V_Loss: 3928.8159 | TRPO: OK
# 04:14:02 [INFO] Update   48 | Eval Score:  -762.23 | V_Loss: 4152.3906 | TRPO: OK
# 04:14:06 [INFO] Update   49 | Eval Score:  -776.61 | V_Loss: 3972.5583 | TRPO: OK
# 04:14:10 [INFO] Update   50 | Eval Score:  -684.74 | V_Loss: 3443.7358 | TRPO: OK
# 04:14:14 [INFO] Update   51 | Eval Score:  -745.60 | V_Loss: 3593.2200 | TRPO: OK
# 04:14:19 [INFO] Update   52 | Eval Score:  -665.73 | V_Loss: 3202.2300 | TRPO: OK
# 04:14:23 [INFO] Update   53 | Eval Score:  -720.29 | V_Loss: 2888.6790 | TRPO: OK
# 04:14:27 [INFO] Update   54 | Eval Score:  -769.66 | V_Loss: 2693.8259 | TRPO: OK
# 04:14:31 [INFO] Update   55 | Eval Score:  -749.70 | V_Loss: 2886.1128 | TRPO: OK
# 04:14:35 [INFO] Update   56 | Eval Score:  -713.23 | V_Loss: 2864.6416 | TRPO: OK
# 04:14:39 [INFO] Update   57 | Eval Score:  -748.38 | V_Loss: 3004.8450 | TRPO: OK
# 04:14:44 [INFO] Update   58 | Eval Score:  -733.26 | V_Loss: 3183.9409 | TRPO: OK
# 04:14:48 [INFO] Update   59 | Eval Score:  -666.07 | V_Loss: 2722.4509 | TRPO: OK
# 04:14:52 [INFO] Update   60 | Eval Score:  -752.66 | V_Loss: 2470.5447 | TRPO: OK
# 04:14:56 [INFO] Update   61 | Eval Score:  -704.79 | V_Loss: 2651.5730 | TRPO: OK
# 04:15:00 [INFO] Update   62 | Eval Score:  -668.17 | V_Loss: 2364.4126 | TRPO: OK
# 04:15:05 [INFO] Update   63 | Eval Score:  -748.77 | V_Loss: 2746.9900 | TRPO: OK
# 04:15:09 [INFO] Update   64 | Eval Score:  -691.17 | V_Loss: 2554.6350 | TRPO: OK
# 04:15:13 [INFO] Update   65 | Eval Score:  -788.98 | V_Loss: 3054.0247 | TRPO: OK
# 04:15:17 [INFO] Update   66 | Eval Score:  -676.45 | V_Loss: 2937.1477 | TRPO: OK
# 04:15:21 [INFO] Update   67 | Eval Score:  -700.11 | V_Loss: 3047.9636 | TRPO: OK
# 04:15:25 [INFO] Update   68 | Eval Score:  -676.88 | V_Loss: 2940.0308 | TRPO: OK
# 04:15:30 [INFO] Update   69 | Eval Score:  -706.20 | V_Loss: 2827.0857 | TRPO: OK
# 04:15:34 [INFO] Update   70 | Eval Score:  -666.23 | V_Loss: 2468.9077 | TRPO: OK
# 04:15:38 [INFO] Update   71 | Eval Score:  -667.29 | V_Loss: 2666.5488 | TRPO: OK
# 04:15:42 [INFO] Update   72 | Eval Score:  -622.98 | V_Loss: 2340.6675 | TRPO: OK
# 04:15:47 [INFO] Update   73 | Eval Score:  -710.03 | V_Loss: 2260.5303 | TRPO: OK
# 04:15:51 [INFO] Update   74 | Eval Score:  -674.63 | V_Loss: 2523.0979 | TRPO: OK
# 04:15:55 [INFO] Update   75 | Eval Score:  -668.50 | V_Loss: 2381.9834 | TRPO: OK
# 04:15:59 [INFO] Update   76 | Eval Score:  -655.85 | V_Loss: 2600.2759 | TRPO: OK
# 04:16:03 [INFO] Update   77 | Eval Score:  -609.14 | V_Loss: 2296.8423 | TRPO: OK
# 04:16:07 [INFO] Update   78 | Eval Score:  -634.06 | V_Loss: 2121.4358 | TRPO: OK
# 04:16:11 [INFO] Update   79 | Eval Score:  -629.16 | V_Loss: 2452.1597 | TRPO: OK
# 04:16:15 [INFO] Update   80 | Eval Score:  -684.82 | V_Loss: 2145.1208 | TRPO: OK
# 04:16:20 [INFO] Update   81 | Eval Score:  -609.76 | V_Loss: 2067.2012 | TRPO: OK
# 04:16:24 [INFO] Update   82 | Eval Score:  -525.80 | V_Loss: 2657.0217 | TRPO: OK
# 04:16:28 [INFO] Update   83 | Eval Score:  -700.86 | V_Loss: 2607.4919 | TRPO: OK
# 04:16:33 [INFO] Update   84 | Eval Score:  -549.21 | V_Loss: 2437.9622 | TRPO: OK
# 04:16:37 [INFO] Update   85 | Eval Score:  -623.21 | V_Loss: 2407.9961 | TRPO: OK
# 04:16:41 [INFO] Update   86 | Eval Score:  -514.85 | V_Loss: 2128.2871 | TRPO: OK
# 04:16:45 [INFO] Update   87 | Eval Score:  -643.98 | V_Loss: 2368.3936 | TRPO: OK
# 04:16:49 [INFO] Update   88 | Eval Score:  -662.00 | V_Loss: 2430.7007 | TRPO: OK
# 04:16:54 [INFO] Update   89 | Eval Score:  -602.04 | V_Loss: 1984.8615 | TRPO: OK
# 04:16:58 [INFO] Update   90 | Eval Score:  -652.39 | V_Loss: 2182.9370 | TRPO: OK
# 04:17:02 [INFO] Update   91 | Eval Score:  -553.33 | V_Loss: 2328.8384 | TRPO: OK
# 04:17:06 [INFO] Update   92 | Eval Score:  -659.20 | V_Loss: 1873.0681 | TRPO: OK
# 04:17:11 [INFO] Update   93 | Eval Score:  -509.12 | V_Loss: 2285.8936 | TRPO: OK
# 04:17:15 [INFO] Update   94 | Eval Score:  -692.65 | V_Loss: 1982.9955 | TRPO: OK
# 04:17:19 [INFO] Update   95 | Eval Score:  -752.90 | V_Loss: 2029.0472 | TRPO: OK
# 04:17:23 [INFO] Update   96 | Eval Score:  -667.79 | V_Loss: 1879.0276 | TRPO: OK
# 04:17:28 [INFO] Update   97 | Eval Score:  -630.98 | V_Loss: 2235.3381 | TRPO: OK
# 04:17:32 [INFO] Update   98 | Eval Score:  -663.08 | V_Loss: 1801.7413 | TRPO: OK
# 04:17:36 [INFO] Update   99 | Eval Score:  -589.07 | V_Loss: 1710.1287 | TRPO: OK
# 04:17:40 [INFO] Update  100 | Eval Score:  -567.40 | V_Loss: 1920.8661 | TRPO: OK
# 04:17:45 [INFO] Update  101 | Eval Score:  -647.43 | V_Loss: 1677.8624 | TRPO: OK
# 04:17:49 [INFO] Update  102 | Eval Score:  -591.97 | V_Loss: 1690.3356 | TRPO: OK
# 04:17:53 [INFO] Update  103 | Eval Score:  -592.77 | V_Loss: 2151.4221 | TRPO: OK
# 04:17:57 [INFO] Update  104 | Eval Score:  -622.73 | V_Loss: 1527.1692 | TRPO: OK
# 04:18:01 [INFO] Update  105 | Eval Score:  -592.47 | V_Loss: 1852.8448 | TRPO: OK
# 04:18:06 [INFO] Update  106 | Eval Score:  -578.17 | V_Loss: 1413.0853 | TRPO: OK
# 04:18:10 [INFO] Update  107 | Eval Score:  -568.62 | V_Loss: 1863.0446 | TRPO: OK
# 04:18:14 [INFO] Update  108 | Eval Score:  -615.12 | V_Loss: 1540.3864 | TRPO: OK
# 04:18:18 [INFO] Update  109 | Eval Score:  -593.06 | V_Loss: 1672.4526 | TRPO: OK
# 04:18:22 [INFO] Update  110 | Eval Score:  -506.49 | V_Loss: 1532.7782 | TRPO: OK
# 04:18:27 [INFO] Update  111 | Eval Score:  -540.66 | V_Loss: 1588.0797 | TRPO: OK
# 04:18:31 [INFO] Update  112 | Eval Score:  -509.03 | V_Loss: 2056.2136 | TRPO: OK
# 04:18:35 [INFO] Update  113 | Eval Score:  -489.19 | V_Loss: 1344.0829 | TRPO: OK
# 04:18:39 [INFO] Update  114 | Eval Score:  -504.20 | V_Loss: 1391.4563 | TRPO: OK
# 04:18:43 [INFO] Update  115 | Eval Score:  -470.08 | V_Loss: 1447.3392 | TRPO: OK
# 04:18:47 [INFO] Update  116 | Eval Score:  -506.05 | V_Loss: 1608.6097 | TRPO: OK
# 04:18:51 [INFO] Update  117 | Eval Score:  -541.41 | V_Loss: 1492.4794 | TRPO: OK
# 04:18:55 [INFO] Update  118 | Eval Score:  -587.55 | V_Loss: 1150.9119 | TRPO: OK
# 04:19:00 [INFO] Update  119 | Eval Score:  -553.35 | V_Loss: 1706.1300 | TRPO: OK
# 04:19:04 [INFO] Update  120 | Eval Score:  -506.64 | V_Loss: 1315.4443 | TRPO: OK
# 04:19:08 [INFO] Update  121 | Eval Score:  -635.73 | V_Loss: 1188.1266 | TRPO: OK
# 04:19:12 [INFO] Update  122 | Eval Score:  -494.51 | V_Loss: 1417.2446 | TRPO: OK
# 04:19:16 [INFO] Update  123 | Eval Score:  -575.25 | V_Loss: 1172.3418 | TRPO: OK
# 04:19:21 [INFO] Update  124 | Eval Score:  -545.83 | V_Loss: 1378.6433 | TRPO: OK
# 04:19:25 [INFO] Update  125 | Eval Score:  -502.81 | V_Loss: 1372.9386 | TRPO: OK
# 04:19:29 [INFO] Update  126 | Eval Score:  -617.50 | V_Loss: 1293.2166 | TRPO: OK
# 04:19:33 [INFO] Update  127 | Eval Score:  -507.84 | V_Loss: 1435.8320 | TRPO: OK
# 04:19:38 [INFO] Update  128 | Eval Score:  -498.50 | V_Loss: 1184.4961 | TRPO: OK
# 04:19:42 [INFO] Update  129 | Eval Score:  -508.54 | V_Loss: 1289.6144 | TRPO: OK
# 04:19:46 [INFO] Update  130 | Eval Score:  -422.88 | V_Loss: 1075.8231 | TRPO: OK
# 04:19:50 [INFO] Update  131 | Eval Score:  -512.16 | V_Loss: 1247.1895 | TRPO: OK
# 04:19:54 [INFO] Update  132 | Eval Score:  -504.28 | V_Loss: 1178.5090 | TRPO: OK
# 04:19:58 [INFO] Update  133 | Eval Score:  -619.97 | V_Loss: 1313.3810 | TRPO: OK
# 04:20:02 [INFO] Update  134 | Eval Score:  -543.42 | V_Loss: 1078.6448 | TRPO: OK
# 04:20:07 [INFO] Update  135 | Eval Score:  -503.56 | V_Loss: 1351.7266 | TRPO: OK
# 04:20:11 [INFO] Update  136 | Eval Score:  -428.37 | V_Loss: 1107.0789 | TRPO: OK
# 04:20:15 [INFO] Update  137 | Eval Score:  -476.71 | V_Loss: 1118.9824 | TRPO: OK
# 04:20:19 [INFO] Update  138 | Eval Score:  -476.10 | V_Loss: 1248.7740 | TRPO: OK
# 04:20:23 [INFO] Update  139 | Eval Score:  -515.19 | V_Loss: 712.2608 | TRPO: OK
# 04:20:27 [INFO] Update  140 | Eval Score:  -427.70 | V_Loss: 975.3174 | TRPO: OK
# 04:20:32 [INFO] Update  141 | Eval Score:  -577.81 | V_Loss: 901.2670 | TRPO: OK
# 04:20:36 [INFO] Update  142 | Eval Score:  -483.85 | V_Loss: 1153.0690 | TRPO: OK
# 04:20:40 [INFO] Update  143 | Eval Score:  -442.08 | V_Loss: 829.0025 | TRPO: OK
# 04:20:44 [INFO] Update  144 | Eval Score:  -381.95 | V_Loss: 852.0239 | TRPO: OK
# 04:20:48 [INFO] Update  145 | Eval Score:  -461.59 | V_Loss: 937.3713 | TRPO: OK
# 04:20:52 [INFO] Update  146 | Eval Score:  -379.87 | V_Loss: 797.2042 | TRPO: OK
# 04:20:56 [INFO] Update  147 | Eval Score:  -498.64 | V_Loss: 736.1604 | TRPO: OK
# 04:21:01 [INFO] Update  148 | Eval Score:  -459.31 | V_Loss: 712.2109 | TRPO: OK
# 04:21:05 [INFO] Update  149 | Eval Score:  -338.32 | V_Loss: 869.3895 | TRPO: OK
# 04:21:09 [INFO] Update  150 | Eval Score:  -301.63 | V_Loss: 583.2841 | TRPO: OK
# 04:21:13 [INFO] Update  151 | Eval Score:  -257.91 | V_Loss: 500.5395 | TRPO: OK
# 04:21:17 [INFO] Update  152 | Eval Score:  -255.62 | V_Loss: 600.9833 | TRPO: OK
# 04:21:21 [INFO] Update  153 | Eval Score:  -246.92 | V_Loss: 430.5890 | TRPO: OK
# 04:21:26 [INFO] Update  154 | Eval Score:  -290.81 | V_Loss: 395.1619 | TRPO: OK
# 04:21:30 [INFO] Update  155 | Eval Score:  -162.90 | V_Loss: 321.4586 | TRPO: OK
# 04:21:34 [INFO] Update  156 | Eval Score:   -93.41 | V_Loss: 213.4321 | TRPO: OK
# 04:21:39 [INFO] Update  157 | Eval Score:  -199.15 | V_Loss: 42.6941 | TRPO: OK
# 04:21:43 [INFO] Update  158 | Eval Score:   -92.34 | V_Loss: 42.5695 | TRPO: OK
# 04:21:47 [INFO] Update  159 | Eval Score:  -214.22 | V_Loss: 33.1165 | TRPO: OK
# 04:21:51 [INFO] Update  160 | Eval Score:   -88.85 | V_Loss: 17.3580 | TRPO: OK
# 04:21:55 [INFO] Update  161 | Eval Score:  -285.81 | V_Loss: 41.2079 | TRPO: OK
# 04:21:59 [INFO] Update  162 | Eval Score:  -180.89 | V_Loss: 46.6686 | TRPO: OK
# 04:22:03 [INFO] Update  163 | Eval Score:  -247.36 | V_Loss: 20.2531 | TRPO: OK
# 04:22:07 [INFO] Update  164 | Eval Score:  -165.90 | V_Loss: 13.7964 | TRPO: OK
# 04:22:12 [INFO] Update  165 | Eval Score:  -137.41 | V_Loss: 16.0601 | TRPO: OK
# 04:22:16 [INFO] Update  166 | Eval Score:  -237.80 | V_Loss: 7.8452 | TRPO: OK
# 04:22:20 [INFO] Update  167 | Eval Score:  -189.37 | V_Loss: 9.2049 | TRPO: OK
# 04:22:24 [INFO] Update  168 | Eval Score:  -129.27 | V_Loss: 11.5965 | TRPO: OK
# 04:22:29 [INFO] Update  169 | Eval Score:  -264.18 | V_Loss: 9.2438 | TRPO: OK
# 04:22:33 [INFO] Update  170 | Eval Score:  -128.77 | V_Loss: 8.1045 | TRPO: OK
# 04:22:37 [INFO] Update  171 | Eval Score:  -209.82 | V_Loss: 26.2752 | TRPO: OK
# 04:22:41 [INFO] Update  172 | Eval Score:  -222.58 | V_Loss: 19.1503 | TRPO: OK
# 04:22:45 [INFO] Update  173 | Eval Score:  -173.58 | V_Loss: 8.0731 | TRPO: OK
# 04:22:50 [INFO] Update  174 | Eval Score:  -218.92 | V_Loss: 5.0691 | TRPO: OK
# 04:22:54 [INFO] Update  175 | Eval Score:  -128.06 | V_Loss: 15.3954 | TRPO: OK
# 04:22:58 [INFO] Update  176 | Eval Score:  -264.81 | V_Loss: 8.6170 | TRPO: OK
# 04:23:02 [INFO] Update  177 | Eval Score:  -168.09 | V_Loss: 20.3589 | TRPO: OK
# 04:23:06 [INFO] Update  178 | Eval Score:  -126.09 | V_Loss: 11.7215 | TRPO: OK
# 04:23:10 [INFO] Update  179 | Eval Score:  -165.17 | V_Loss: 6.2979 | TRPO: OK
# 04:23:15 [INFO] Update  180 | Eval Score:  -172.73 | V_Loss: 4.5652 | TRPO: OK
# 04:23:19 [INFO] Update  181 | Eval Score:  -127.27 | V_Loss: 5.6671 | TRPO: OK
# 04:23:23 [INFO] Update  182 | Eval Score:  -200.92 | V_Loss: 5.5924 | TRPO: OK
# 04:23:28 [INFO] Update  183 | Eval Score:  -128.04 | V_Loss: 14.9668 | TRPO: OK
# 04:23:32 [INFO] Update  184 | Eval Score:  -127.23 | V_Loss: 11.0240 | TRPO: OK
# 04:23:36 [INFO] Update  185 | Eval Score:  -127.86 | V_Loss: 3.5043 | TRPO: OK
# 04:23:41 [INFO] Update  186 | Eval Score:  -123.43 | V_Loss: 5.1651 | TRPO: OK
# 04:23:45 [INFO] Update  187 | Eval Score:  -206.96 | V_Loss: 125.6094 | TRPO: OK
# 04:23:49 [INFO] Update  188 | Eval Score:  -159.32 | V_Loss: 65.0330 | TRPO: OK
# 04:23:53 [INFO] Update  189 | Eval Score:  -163.13 | V_Loss: 7.1219 | TRPO: OK
# 04:23:58 [INFO] Update  190 | Eval Score:  -127.03 | V_Loss: 9.3854 | TRPO: OK
# 04:24:02 [INFO] Update  191 | Eval Score:  -215.66 | V_Loss: 7.4325 | TRPO: OK
# 04:24:06 [INFO] Update  192 | Eval Score:  -170.16 | V_Loss: 6.1132 | TRPO: OK
# 04:24:10 [INFO] Update  193 | Eval Score:   -84.60 | V_Loss: 4.8693 | TRPO: OK
# 04:24:15 [INFO] Update  194 | Eval Score:  -243.76 | V_Loss: 5.5652 | TRPO: OK
# 04:24:19 [INFO] Update  195 | Eval Score:  -173.33 | V_Loss: 5.4955 | TRPO: OK
# 04:24:23 [INFO] Update  196 | Eval Score:  -223.50 | V_Loss: 4.3129 | TRPO: OK
# 04:24:27 [INFO] Update  197 | Eval Score:   -88.59 | V_Loss: 23.1005 | TRPO: OK
# 04:24:31 [INFO] Update  198 | Eval Score:  -128.33 | V_Loss: 4.3828 | TRPO: OK
# 04:24:36 [INFO] Update  199 | Eval Score:  -170.38 | V_Loss: 5.8979 | TRPO: OK
# 04:24:40 [INFO] Update  200 | Eval Score:   -46.00 | V_Loss: 3.0094 | TRPO: OK
# 04:24:44 [INFO] Update  201 | Eval Score:  -290.85 | V_Loss: 5.1134 | TRPO: OK
# 04:24:48 [INFO] Update  202 | Eval Score:  -178.20 | V_Loss: 5.4191 | TRPO: OK
# 04:24:52 [INFO] Update  203 | Eval Score:   -45.59 | V_Loss: 3.4425 | TRPO: OK
# 04:24:56 [INFO] Update  204 | Eval Score:  -292.62 | V_Loss: 24.3743 | TRPO: OK
# 04:25:00 [INFO] Update  205 | Eval Score:  -212.82 | V_Loss: 4.0324 | TRPO: OK
# 04:25:05 [INFO] Update  206 | Eval Score:   -85.97 | V_Loss: 3.0170 | TRPO: OK
# 04:25:09 [INFO] Update  207 | Eval Score:  -170.27 | V_Loss: 8.6524 | TRPO: OK
# 04:25:13 [INFO] Update  208 | Eval Score:  -126.70 | V_Loss: 3.3594 | TRPO: OK
# 04:25:17 [INFO] Update  209 | Eval Score:  -124.47 | V_Loss: 4.1022 | TRPO: OK
# 04:25:21 [INFO] Update  210 | Eval Score:   -42.01 | V_Loss: 4.8542 | TRPO: OK
# 04:25:25 [INFO] Update  211 | Eval Score:  -172.93 | V_Loss: 2.9850 | TRPO: OK
# 04:25:30 [INFO] Update  212 | Eval Score:  -127.55 | V_Loss: 3.0117 | TRPO: OK
# 04:25:34 [INFO] Update  213 | Eval Score:  -160.93 | V_Loss: 6.5573 | TRPO: OK
# 04:25:38 [INFO] Update  214 | Eval Score:  -205.76 | V_Loss: 5.2540 | TRPO: OK
# 04:25:42 [INFO] Update  215 | Eval Score:  -167.28 | V_Loss: 3.0673 | TRPO: OK
# 04:25:46 [INFO] Update  216 | Eval Score:   -98.07 | V_Loss: 9.6626 | TRPO: OK
# 04:25:50 [INFO] Update  217 | Eval Score:  -117.51 | V_Loss: 22.8079 | TRPO: OK
# 04:25:55 [INFO] Update  218 | Eval Score:  -205.75 | V_Loss: 5.5420 | TRPO: OK
# 04:25:59 [INFO] Update  219 | Eval Score:  -181.03 | V_Loss: 11.6049 | TRPO: OK
# 04:26:03 [INFO] Update  220 | Eval Score:  -126.99 | V_Loss: 10.8219 | TRPO: OK
# 04:26:07 [INFO] Update  221 | Eval Score:  -126.15 | V_Loss: 3.4557 | TRPO: OK
# 04:26:11 [INFO] Update  222 | Eval Score:  -128.96 | V_Loss: 3.3173 | TRPO: OK
# 04:26:15 [INFO] Update  223 | Eval Score:   -43.54 | V_Loss: 2.8918 | TRPO: OK
# 04:26:20 [INFO] Update  224 | Eval Score:  -195.70 | V_Loss: 3.7076 | TRPO: OK
# 04:26:24 [INFO] Update  225 | Eval Score:  -166.66 | V_Loss: 3.5556 | TRPO: OK
# 04:26:28 [INFO] Update  226 | Eval Score:  -174.00 | V_Loss: 3.1269 | TRPO: OK
# 04:26:32 [INFO] Update  227 | Eval Score:  -234.92 | V_Loss: 3.6769 | TRPO: OK
# 04:26:36 [INFO] Update  228 | Eval Score:  -196.90 | V_Loss: 3.5106 | TRPO: OK
# 04:26:40 [INFO] Update  229 | Eval Score:  -186.39 | V_Loss: 3.2598 | TRPO: OK
# 04:26:44 [INFO] Update  230 | Eval Score:  -146.66 | V_Loss: 3.4409 | TRPO: OK
# 04:26:49 [INFO] Update  231 | Eval Score:  -163.43 | V_Loss: 6.4170 | TRPO: OK
# 04:26:53 [INFO] Update  232 | Eval Score:  -235.59 | V_Loss: 3.6510 | TRPO: OK
# 04:26:57 [INFO] Update  233 | Eval Score:  -197.52 | V_Loss: 4.2242 | TRPO: OK
# 04:27:01 [INFO] Update  234 | Eval Score:  -173.54 | V_Loss: 3.1438 | TRPO: OK
# 04:27:05 [INFO] Update  235 | Eval Score:  -183.85 | V_Loss: 3.4409 | TRPO: OK
# 04:27:09 [INFO] Update  236 | Eval Score:  -277.66 | V_Loss: 5.7790 | TRPO: OK
# 04:27:14 [INFO] Update  237 | Eval Score:  -161.24 | V_Loss: 4.1951 | TRPO: OK
# 04:27:18 [INFO] Update  238 | Eval Score:   -85.53 | V_Loss: 4.2967 | TRPO: OK
# 04:27:22 [INFO] Update  239 | Eval Score:   -83.45 | V_Loss: 8.7498 | TRPO: OK
# 04:27:26 [INFO] Update  240 | Eval Score:  -124.83 | V_Loss: 4.2099 | TRPO: OK
# 04:27:30 [INFO] Update  241 | Eval Score:  -213.93 | V_Loss: 8.3346 | TRPO: OK
# 04:27:34 [INFO] Update  242 | Eval Score:   -85.79 | V_Loss: 5.4760 | TRPO: OK
# 04:27:39 [INFO] Update  243 | Eval Score:  -121.38 | V_Loss: 4.9883 | TRPO: OK
# 04:27:43 [INFO] Update  244 | Eval Score:  -124.25 | V_Loss: 4.4245 | TRPO: OK
# 04:27:47 [INFO] Update  245 | Eval Score:  -169.51 | V_Loss: 2.9765 | TRPO: OK
# 04:27:51 [INFO] Update  246 | Eval Score:  -161.50 | V_Loss: 3.0323 | TRPO: OK
# 04:27:55 [INFO] Update  247 | Eval Score:  -125.81 | V_Loss: 2.9926 | TRPO: OK
# 04:28:00 [INFO] Update  248 | Eval Score:  -151.13 | V_Loss: 3.9091 | TRPO: OK
# 04:28:04 [INFO] Update  249 | Eval Score:  -163.10 | V_Loss: 4.3683 | TRPO: OK
# 04:28:08 [INFO] Update  250 | Eval Score:  -166.04 | V_Loss: 6.3940 | TRPO: OK
# 04:28:12 [INFO] Update  251 | Eval Score:  -124.88 | V_Loss: 2.7960 | TRPO: OK
# 04:28:16 [INFO] Update  252 | Eval Score:  -168.55 | V_Loss: 3.8992 | TRPO: OK
# 04:28:21 [INFO] Update  253 | Eval Score:  -123.46 | V_Loss: 2.7779 | TRPO: OK
# 04:28:25 [INFO] Update  254 | Eval Score:  -121.78 | V_Loss: 3.5561 | TRPO: OK
# 04:28:29 [INFO] Update  255 | Eval Score:  -250.47 | V_Loss: 4.9500 | TRPO: OK
# 04:28:33 [INFO] Update  256 | Eval Score:  -123.62 | V_Loss: 5.2767 | TRPO: OK
# 04:28:37 [INFO] Update  257 | Eval Score:  -125.48 | V_Loss: 3.3967 | TRPO: OK
# 04:28:42 [INFO] Update  258 | Eval Score:  -234.91 | V_Loss: 2.8225 | TRPO: OK
# 04:28:46 [INFO] Update  259 | Eval Score:  -125.21 | V_Loss: 2.9023 | TRPO: OK
# 04:28:50 [INFO] Update  260 | Eval Score:  -208.07 | V_Loss: 3.8241 | TRPO: OK
# 04:28:54 [INFO] Update  261 | Eval Score:  -131.74 | V_Loss: 3.2242 | TRPO: OK
# 04:28:58 [INFO] Update  262 | Eval Score:   -82.74 | V_Loss: 2.7158 | TRPO: OK
# 04:29:02 [INFO] Update  263 | Eval Score:   -84.51 | V_Loss: 3.0010 | TRPO: OK
# 04:29:06 [INFO] Update  264 | Eval Score:  -125.06 | V_Loss: 2.8217 | TRPO: OK
# 04:29:10 [INFO] Update  265 | Eval Score:  -203.72 | V_Loss: 2.5836 | TRPO: OK
# 04:29:15 [INFO] Update  266 | Eval Score:  -124.15 | V_Loss: 2.5960 | TRPO: OK
# 04:29:19 [INFO] Update  267 | Eval Score:  -128.66 | V_Loss: 2.7214 | TRPO: OK
# 04:29:23 [INFO] Update  268 | Eval Score:  -207.65 | V_Loss: 5.8158 | TRPO: OK
# 04:29:27 [INFO] Update  269 | Eval Score:   -82.18 | V_Loss: 5.3108 | TRPO: OK
# 04:29:31 [INFO] Update  270 | Eval Score:  -179.58 | V_Loss: 2.9805 | TRPO: OK
# 04:29:36 [INFO] Update  271 | Eval Score:  -120.80 | V_Loss: 6.4593 | TRPO: OK
# 04:29:40 [INFO] Update  272 | Eval Score:  -168.85 | V_Loss: 7.4365 | TRPO: OK
# 04:29:44 [INFO] Update  273 | Eval Score:  -123.19 | V_Loss: 3.3271 | TRPO: OK
# 04:29:48 [INFO] Update  274 | Eval Score:   -86.86 | V_Loss: 2.9362 | TRPO: OK
# 04:29:52 [INFO] Update  275 | Eval Score:  -124.66 | V_Loss: 2.7758 | TRPO: OK
# 04:29:56 [INFO] Update  276 | Eval Score:  -130.50 | V_Loss: 10.4558 | TRPO: OK
# 04:30:01 [INFO] Update  277 | Eval Score:  -127.65 | V_Loss: 4.1914 | TRPO: OK
# 04:30:05 [INFO] Update  278 | Eval Score:  -166.94 | V_Loss: 2.8829 | TRPO: OK
# 04:30:09 [INFO] Update  279 | Eval Score:  -161.99 | V_Loss: 3.4473 | TRPO: OK
# 04:30:13 [INFO] Update  280 | Eval Score:  -171.10 | V_Loss: 2.7289 | TRPO: OK
# 04:30:17 [INFO] Update  281 | Eval Score:  -126.49 | V_Loss: 7.4720 | TRPO: OK
# 04:30:22 [INFO] Update  282 | Eval Score:  -121.56 | V_Loss: 3.0380 | TRPO: OK
# 04:30:26 [INFO] Update  283 | Eval Score:   -82.18 | V_Loss: 5.1458 | TRPO: OK
# 04:30:30 [INFO] Update  284 | Eval Score:  -263.42 | V_Loss: 2.8924 | TRPO: OK
# 04:30:34 [INFO] Update  285 | Eval Score:  -142.14 | V_Loss: 2.8830 | TRPO: OK
# 04:30:39 [INFO] Update  286 | Eval Score:  -133.05 | V_Loss: 2.9105 | TRPO: OK
# 04:30:43 [INFO] Update  287 | Eval Score:  -127.17 | V_Loss: 2.8447 | TRPO: OK
# 04:30:47 [INFO] Update  288 | Eval Score:  -166.31 | V_Loss: 11.4545 | TRPO: OK
# 04:30:51 [INFO] Update  289 | Eval Score:  -201.44 | V_Loss: 2.6801 | TRPO: OK
# 04:30:55 [INFO] Update  290 | Eval Score:  -220.21 | V_Loss: 5.5429 | TRPO: OK
# 04:30:59 [INFO] Update  291 | Eval Score:  -126.46 | V_Loss: 2.8550 | TRPO: OK
# 04:31:03 [INFO] Update  292 | Eval Score:   -80.64 | V_Loss: 3.9875 | TRPO: OK
# 04:31:08 [INFO] Update  293 | Eval Score:  -215.71 | V_Loss: 2.6996 | TRPO: OK
# 04:31:12 [INFO] Update  294 | Eval Score:   -85.48 | V_Loss: 2.5996 | TRPO: OK
# 04:31:16 [INFO] Update  295 | Eval Score:   -87.24 | V_Loss: 2.7476 | TRPO: OK
# 04:31:20 [INFO] Update  296 | Eval Score:  -245.06 | V_Loss: 2.8183 | TRPO: OK
# 04:31:24 [INFO] Update  297 | Eval Score:  -124.80 | V_Loss: 5.4111 | TRPO: OK
# 04:31:28 [INFO] Update  298 | Eval Score:  -202.77 | V_Loss: 2.6881 | TRPO: OK
# 04:31:33 [INFO] Update  299 | Eval Score:  -164.47 | V_Loss: 2.5991 | TRPO: OK
# 04:31:37 [INFO] Update  300 | Eval Score:  -160.94 | V_Loss: 4.9803 | TRPO: OK
# 04:31:41 [INFO] Update  301 | Eval Score:  -169.34 | V_Loss: 2.7925 | TRPO: OK
# 04:31:45 [INFO] Update  302 | Eval Score:  -209.64 | V_Loss: 3.1649 | TRPO: OK
# 04:31:49 [INFO] Update  303 | Eval Score:  -122.24 | V_Loss: 2.6630 | TRPO: OK
# 04:31:53 [INFO] Update  304 | Eval Score:   -86.09 | V_Loss: 2.5869 | TRPO: OK
# 04:31:58 [INFO] Update  305 | Eval Score:  -181.63 | V_Loss: 6.4201 | TRPO: OK
# 04:32:02 [INFO] Update  306 | Eval Score:  -211.94 | V_Loss: 2.7395 | TRPO: OK
# 04:32:06 [INFO] Update  307 | Eval Score:  -120.25 | V_Loss: 3.8684 | TRPO: OK
# 04:32:10 [INFO] Update  308 | Eval Score:   -85.09 | V_Loss: 2.6640 | TRPO: OK
# 04:32:14 [INFO] Update  309 | Eval Score:  -270.31 | V_Loss: 3.2846 | TRPO: OK
# 04:32:18 [INFO] Update  310 | Eval Score:  -124.68 | V_Loss: 3.1813 | TRPO: OK
# 04:32:23 [INFO] Update  311 | Eval Score:  -279.83 | V_Loss: 74.7776 | TRPO: OK
# 04:32:27 [INFO] Update  312 | Eval Score:   -83.11 | V_Loss: 4.0578 | TRPO: OK
# 04:32:31 [INFO] Update  313 | Eval Score:  -165.50 | V_Loss: 4.0960 | TRPO: OK
# 04:32:35 [INFO] Update  314 | Eval Score:   -85.75 | V_Loss: 3.1838 | TRPO: OK
# 04:32:39 [INFO] Update  315 | Eval Score:  -123.39 | V_Loss: 2.9442 | TRPO: OK
# 04:32:43 [INFO] Update  316 | Eval Score:  -241.21 | V_Loss: 4.2934 | TRPO: OK
# 04:32:48 [INFO] Update  317 | Eval Score:  -167.75 | V_Loss: 2.8841 | TRPO: OK
# 04:32:53 [INFO] Update  318 | Eval Score:  -176.61 | V_Loss: 3.2396 | TRPO: OK
# 04:32:57 [INFO] Update  319 | Eval Score:  -121.16 | V_Loss: 2.9258 | TRPO: OK
# 04:33:01 [INFO] Update  320 | Eval Score:  -277.94 | V_Loss: 2.6596 | TRPO: OK
# 04:33:05 [INFO] Update  321 | Eval Score:  -163.94 | V_Loss: 2.6509 | TRPO: OK
# 04:33:09 [INFO] Update  322 | Eval Score:  -172.37 | V_Loss: 4.9576 | TRPO: OK
# 04:33:14 [INFO] Update  323 | Eval Score:  -162.24 | V_Loss: 2.9670 | TRPO: OK
# 04:33:18 [INFO] Update  324 | Eval Score:   -81.44 | V_Loss: 9.0878 | TRPO: OK
# 04:33:22 [INFO] Update  325 | Eval Score:  -123.82 | V_Loss: 3.0893 | TRPO: OK
# 04:33:26 [INFO] Update  326 | Eval Score:  -237.72 | V_Loss: 2.8627 | TRPO: OK
# 04:33:30 [INFO] Update  327 | Eval Score:  -230.33 | V_Loss: 3.2138 | TRPO: OK
# 04:33:34 [INFO] Update  328 | Eval Score:  -199.15 | V_Loss: 3.0379 | TRPO: OK
# 04:33:39 [INFO] Update  329 | Eval Score:  -160.19 | V_Loss: 4.7974 | TRPO: OK
# 04:33:43 [INFO] Update  330 | Eval Score:  -165.53 | V_Loss: 3.2863 | TRPO: OK
# 04:33:47 [INFO] Update  331 | Eval Score:  -201.64 | V_Loss: 2.7822 | TRPO: OK
# 04:33:51 [INFO] Update  332 | Eval Score:   -43.71 | V_Loss: 2.7326 | TRPO: OK
# 04:33:55 [INFO] Update  333 | Eval Score:  -158.10 | V_Loss: 3.6175 | TRPO: OK
# 04:33:59 [INFO] Update  334 | Eval Score:  -176.59 | V_Loss: 2.6392 | TRPO: OK
# 04:34:03 [INFO] Update  335 | Eval Score:   -81.32 | V_Loss: 3.3740 | TRPO: OK
# 04:34:07 [INFO] Update  336 | Eval Score:  -123.73 | V_Loss: 2.5744 | TRPO: OK
# 04:34:12 [INFO] Update  337 | Eval Score:  -124.99 | V_Loss: 3.3603 | TRPO: OK
# 04:34:16 [INFO] Update  338 | Eval Score:  -121.47 | V_Loss: 2.8338 | TRPO: OK
# 04:34:20 [INFO] Update  339 | Eval Score:   -40.97 | V_Loss: 2.7694 | TRPO: OK
# 04:34:24 [INFO] Update  340 | Eval Score:  -121.03 | V_Loss: 2.7573 | TRPO: OK
# 04:34:28 [INFO] Update  341 | Eval Score:  -161.02 | V_Loss: 2.6795 | TRPO: OK
# 04:34:33 [INFO] Update  342 | Eval Score:  -158.82 | V_Loss: 2.6001 | TRPO: OK
# 04:34:37 [INFO] Update  343 | Eval Score:  -121.84 | V_Loss: 2.6068 | TRPO: OK
# 04:34:41 [INFO] Update  344 | Eval Score:  -119.27 | V_Loss: 2.5940 | TRPO: OK
# 04:34:45 [INFO] Update  345 | Eval Score:  -126.51 | V_Loss: 2.5475 | TRPO: OK
# 04:34:50 [INFO] Update  346 | Eval Score:  -205.42 | V_Loss: 3.1366 | TRPO: OK
# 04:34:54 [INFO] Update  347 | Eval Score:  -121.64 | V_Loss: 2.8929 | TRPO: OK
# 04:34:58 [INFO] Update  348 | Eval Score:  -125.45 | V_Loss: 2.5686 | TRPO: OK
# 04:35:02 [INFO] Update  349 | Eval Score:  -229.31 | V_Loss: 2.7964 | TRPO: OK
# 04:35:06 [INFO] Update  350 | Eval Score:  -119.79 | V_Loss: 2.5498 | TRPO: OK
# 04:35:11 [INFO] Update  351 | Eval Score:  -183.33 | V_Loss: 2.7419 | TRPO: OK
# 04:35:15 [INFO] Update  352 | Eval Score:   -82.31 | V_Loss: 4.0634 | TRPO: OK
# 04:35:19 [INFO] Update  353 | Eval Score:  -125.04 | V_Loss: 3.0410 | TRPO: OK
# 04:35:23 [INFO] Update  354 | Eval Score:  -126.26 | V_Loss: 7.5452 | TRPO: OK
# 04:35:28 [INFO] Update  355 | Eval Score:  -202.99 | V_Loss: 2.6651 | TRPO: OK
# 04:35:32 [INFO] Update  356 | Eval Score:  -204.79 | V_Loss: 2.5899 | TRPO: OK
# 04:35:36 [INFO] Update  357 | Eval Score:   -80.33 | V_Loss: 4.8854 | TRPO: OK
# 04:35:40 [INFO] Update  358 | Eval Score:  -258.99 | V_Loss: 2.6443 | TRPO: OK
# 04:35:44 [INFO] Update  359 | Eval Score:  -166.53 | V_Loss: 2.7611 | TRPO: OK
# 04:35:48 [INFO] Update  360 | Eval Score:  -130.77 | V_Loss: 5.7168 | TRPO: OK
# 04:35:53 [INFO] Update  361 | Eval Score:  -118.93 | V_Loss: 2.5902 | TRPO: OK
# 04:35:57 [INFO] Update  362 | Eval Score:  -158.48 | V_Loss: 3.1130 | TRPO: OK
# 04:36:01 [INFO] Update  363 | Eval Score:  -162.20 | V_Loss: 2.5809 | TRPO: OK
# 04:36:05 [INFO] Update  364 | Eval Score:  -258.98 | V_Loss: 2.7776 | TRPO: OK
# 04:36:09 [INFO] Update  365 | Eval Score:  -203.14 | V_Loss: 2.6836 | TRPO: OK
# 04:36:14 [INFO] Update  366 | Eval Score:   -80.81 | V_Loss: 2.7199 | TRPO: OK
# 04:36:18 [INFO] Update  367 | Eval Score:  -166.76 | V_Loss: 2.7975 | TRPO: OK
# 04:36:22 [INFO] Update  368 | Eval Score:  -124.45 | V_Loss: 3.0037 | TRPO: OK
# 04:36:26 [INFO] Update  369 | Eval Score:  -195.43 | V_Loss: 3.5155 | TRPO: OK
# 04:36:30 [INFO] Update  370 | Eval Score:  -122.27 | V_Loss: 2.6450 | TRPO: OK
# 04:36:35 [INFO] Update  371 | Eval Score:  -205.43 | V_Loss: 2.6576 | TRPO: OK
# 04:36:39 [INFO] Update  372 | Eval Score:  -162.45 | V_Loss: 3.9208 | TRPO: OK
# 04:36:43 [INFO] Update  373 | Eval Score:  -121.93 | V_Loss: 5.1990 | TRPO: OK
# 04:36:47 [INFO] Update  374 | Eval Score:  -210.78 | V_Loss: 3.5129 | TRPO: OK
# 04:36:51 [INFO] Update  375 | Eval Score:  -126.90 | V_Loss: 2.8966 | TRPO: OK
# 04:36:56 [INFO] Update  376 | Eval Score:  -166.34 | V_Loss: 2.6434 | TRPO: OK
# 04:37:00 [INFO] Update  377 | Eval Score:  -167.26 | V_Loss: 2.5491 | TRPO: OK
# 04:37:04 [INFO] Update  378 | Eval Score:   -86.17 | V_Loss: 2.5615 | TRPO: OK
# 04:37:08 [INFO] Update  379 | Eval Score:  -161.11 | V_Loss: 2.5747 | TRPO: OK
# 04:37:12 [INFO] Update  380 | Eval Score:  -122.60 | V_Loss: 2.7616 | TRPO: OK
# 04:37:16 [INFO] Update  381 | Eval Score:  -167.99 | V_Loss: 4.7849 | TRPO: OK
# 04:37:20 [INFO] Update  382 | Eval Score:  -239.07 | V_Loss: 3.0549 | TRPO: OK
# 04:37:25 [INFO] Update  383 | Eval Score:  -211.40 | V_Loss: 2.8282 | TRPO: OK
# 04:37:29 [INFO] Update  384 | Eval Score:   -43.21 | V_Loss: 2.5523 | TRPO: OK
# 04:37:33 [INFO] Update  385 | Eval Score:   -82.39 | V_Loss: 2.6167 | TRPO: OK
# 04:37:37 [INFO] Update  386 | Eval Score:  -180.25 | V_Loss: 2.8665 | TRPO: OK
# 04:37:41 [INFO] Update  387 | Eval Score:   -81.77 | V_Loss: 2.5015 | TRPO: OK
# 04:37:45 [INFO] Update  388 | Eval Score:  -159.90 | V_Loss: 2.7612 | TRPO: OK
# 04:37:50 [INFO] Update  389 | Eval Score:  -172.15 | V_Loss: 2.6084 | TRPO: OK
# 04:37:54 [INFO] Update  390 | Eval Score:  -168.73 | V_Loss: 2.5974 | TRPO: OK
# 04:37:58 [INFO] Update  391 | Eval Score:  -161.97 | V_Loss: 129.6953 | TRPO: OK
# 04:38:02 [INFO] Update  392 | Eval Score:  -119.25 | V_Loss: 8.7171 | TRPO: OK
# 04:38:06 [INFO] Update  393 | Eval Score:  -161.59 | V_Loss: 4.2273 | TRPO: OK
# 04:38:11 [INFO] Update  394 | Eval Score:  -162.57 | V_Loss: 7.3857 | TRPO: OK
# 04:38:15 [INFO] Update  395 | Eval Score:   -82.98 | V_Loss: 3.3444 | TRPO: OK
# 04:38:19 [INFO] Update  396 | Eval Score:    -2.70 | V_Loss: 3.1951 | TRPO: OK
# 04:38:23 [INFO] Update  397 | Eval Score:  -140.36 | V_Loss: 4.1035 | TRPO: OK
# 04:38:28 [INFO] Update  398 | Eval Score:  -157.82 | V_Loss: 2.9650 | TRPO: OK
# 04:38:33 [INFO] Update  399 | Eval Score:  -121.27 | V_Loss: 2.7395 | TRPO: OK
# 04:38:38 [INFO] Update  400 | Eval Score:  -213.68 | V_Loss: 2.8557 | TRPO: OK
# 04:38:42 [INFO] Update  401 | Eval Score:  -248.10 | V_Loss: 3.0039 | TRPO: OK
# 04:38:46 [INFO] Update  402 | Eval Score:  -123.73 | V_Loss: 3.8708 | TRPO: OK
# 04:38:50 [INFO] Update  403 | Eval Score:   -82.38 | V_Loss: 2.7324 | TRPO: OK
# 04:38:55 [INFO] Update  404 | Eval Score:   -79.02 | V_Loss: 8.2477 | TRPO: OK
# 04:38:59 [INFO] Update  405 | Eval Score:  -120.20 | V_Loss: 7.8597 | TRPO: OK
# 04:39:03 [INFO] Update  406 | Eval Score:  -124.99 | V_Loss: 2.7929 | TRPO: OK
# 04:39:08 [INFO] Update  407 | Eval Score:  -206.38 | V_Loss: 2.6403 | TRPO: OK
# 04:39:12 [INFO] Update  408 | Eval Score:  -210.64 | V_Loss: 2.9729 | TRPO: OK
# 04:39:17 [INFO] Update  409 | Eval Score:  -246.58 | V_Loss: 2.5769 | TRPO: OK
# 04:39:22 [INFO] Update  410 | Eval Score:  -162.99 | V_Loss: 2.8139 | TRPO: OK
# 04:39:26 [INFO] Update  411 | Eval Score:  -160.22 | V_Loss: 2.6218 | TRPO: OK
# 04:39:31 [INFO] Update  412 | Eval Score:  -213.31 | V_Loss: 16.1995 | TRPO: OK
# 04:39:36 [INFO] Update  413 | Eval Score:  -174.54 | V_Loss: 8.5138 | TRPO: OK
# 04:39:40 [INFO] Update  414 | Eval Score:  -120.93 | V_Loss: 2.7421 | TRPO: OK
# 04:39:44 [INFO] Update  415 | Eval Score:   -83.06 | V_Loss: 4.1357 | TRPO: OK
# 04:39:48 [INFO] Update  416 | Eval Score:  -151.38 | V_Loss: 2.7232 | TRPO: OK
# 04:39:52 [INFO] Update  417 | Eval Score:  -184.89 | V_Loss: 6.1410 | TRPO: OK
# 04:39:56 [INFO] Update  418 | Eval Score:  -121.01 | V_Loss: 2.7541 | TRPO: OK
# 04:40:00 [INFO] Update  419 | Eval Score:  -243.62 | V_Loss: 2.8539 | TRPO: OK
# 04:40:05 [INFO] Update  420 | Eval Score:  -119.73 | V_Loss: 2.8460 | TRPO: OK
# 04:40:09 [INFO] Update  421 | Eval Score:  -198.25 | V_Loss: 2.8635 | TRPO: OK
# 04:40:13 [INFO] Update  422 | Eval Score:  -121.08 | V_Loss: 2.6261 | TRPO: OK
# 04:40:17 [INFO] Update  423 | Eval Score:  -162.97 | V_Loss: 2.6566 | TRPO: OK
# 04:40:21 [INFO] Update  424 | Eval Score:  -164.40 | V_Loss: 2.9132 | TRPO: OK
# 04:40:25 [INFO] Update  425 | Eval Score:  -162.48 | V_Loss: 2.6089 | TRPO: OK
# 04:40:30 [INFO] Update  426 | Eval Score:  -126.23 | V_Loss: 2.8540 | TRPO: OK
# 04:40:34 [INFO] Update  427 | Eval Score:   -84.18 | V_Loss: 2.7688 | TRPO: OK
# 04:40:38 [INFO] Update  428 | Eval Score:  -233.82 | V_Loss: 2.6688 | TRPO: OK
# 04:40:42 [INFO] Update  429 | Eval Score:   -81.84 | V_Loss: 7.9506 | TRPO: OK
# 04:40:47 [INFO] Update  430 | Eval Score:  -123.56 | V_Loss: 5.2264 | TRPO: OK
# 04:40:51 [INFO] Update  431 | Eval Score:  -163.85 | V_Loss: 3.0566 | TRPO: OK
# 04:40:55 [INFO] Update  432 | Eval Score:  -122.46 | V_Loss: 2.8158 | TRPO: OK
# 04:40:59 [INFO] Update  433 | Eval Score:  -260.93 | V_Loss: 2.8692 | TRPO: OK
# 04:41:03 [INFO] Update  434 | Eval Score:  -122.22 | V_Loss: 5.7416 | TRPO: OK
# 04:41:08 [INFO] Update  435 | Eval Score:  -203.64 | V_Loss: 2.8107 | TRPO: OK
# 04:41:12 [INFO] Update  436 | Eval Score:  -164.42 | V_Loss: 7.5207 | TRPO: OK
# 04:41:16 [INFO] Update  437 | Eval Score:  -153.91 | V_Loss: 3.0530 | TRPO: OK
# 04:41:20 [INFO] Update  438 | Eval Score:  -122.23 | V_Loss: 2.7894 | TRPO: OK
# 04:41:24 [INFO] Update  439 | Eval Score:  -159.76 | V_Loss: 4.9789 | TRPO: OK
# 04:41:28 [INFO] Update  440 | Eval Score:  -122.72 | V_Loss: 15.7504 | TRPO: OK
# 04:41:32 [INFO] Update  441 | Eval Score:   -75.07 | V_Loss: 5.6420 | TRPO: OK
# 04:41:37 [INFO] Update  442 | Eval Score:  -119.53 | V_Loss: 8.9032 | TRPO: OK
# 04:41:41 [INFO] Update  443 | Eval Score:  -118.16 | V_Loss: 7.6002 | TRPO: OK
# 04:41:45 [INFO] Update  444 | Eval Score:   -41.87 | V_Loss: 3.4263 | TRPO: OK
# 04:41:49 [INFO] Update  445 | Eval Score:  -173.44 | V_Loss: 2.8096 | TRPO: OK
# 04:41:53 [INFO] Update  446 | Eval Score:  -271.94 | V_Loss: 4.3741 | TRPO: OK
# 04:41:58 [INFO] Update  447 | Eval Score:  -160.50 | V_Loss: 3.0561 | TRPO: OK
# 04:42:02 [INFO] Update  448 | Eval Score:  -193.17 | V_Loss: 22.3712 | TRPO: OK
# 04:42:06 [INFO] Update  449 | Eval Score:  -162.46 | V_Loss: 2.9579 | TRPO: OK
# 04:42:10 [INFO] Update  450 | Eval Score:  -157.56 | V_Loss: 6.2770 | TRPO: OK
# 04:42:14 [INFO] Update  451 | Eval Score:  -162.92 | V_Loss: 4.5503 | TRPO: OK
# 04:42:19 [INFO] Update  452 | Eval Score:  -212.26 | V_Loss: 2.9372 | TRPO: OK
# 04:42:23 [INFO] Update  453 | Eval Score:  -114.11 | V_Loss: 3.7578 | TRPO: OK
# 04:42:27 [INFO] Update  454 | Eval Score:   -41.62 | V_Loss: 6.6773 | TRPO: OK
# 04:42:31 [INFO] Update  455 | Eval Score:  -205.64 | V_Loss: 3.3261 | TRPO: OK
# 04:42:35 [INFO] Update  456 | Eval Score:  -159.83 | V_Loss: 43.7090 | TRPO: OK
# 04:42:40 [INFO] Update  457 | Eval Score:  -142.88 | V_Loss: 3.7845 | TRPO: OK
# 04:42:44 [INFO] Update  458 | Eval Score:  -170.89 | V_Loss: 3.5335 | TRPO: OK
# 04:42:48 [INFO] Update  459 | Eval Score:   -83.39 | V_Loss: 3.1086 | TRPO: OK
# 04:42:52 [INFO] Update  460 | Eval Score:  -154.09 | V_Loss: 4.3276 | TRPO: OK
# 04:42:56 [INFO] Update  461 | Eval Score:  -161.12 | V_Loss: 3.0435 | TRPO: OK
# 04:43:00 [INFO] Update  462 | Eval Score:   -84.18 | V_Loss: 3.0157 | TRPO: OK
# 04:43:05 [INFO] Update  463 | Eval Score:  -166.95 | V_Loss: 2.9710 | TRPO: OK
# 04:43:09 [INFO] Update  464 | Eval Score:  -126.48 | V_Loss: 8.0556 | TRPO: OK
# 04:43:13 [INFO] Update  465 | Eval Score:  -163.41 | V_Loss: 3.1848 | TRPO: OK
# 04:43:17 [INFO] Update  466 | Eval Score:  -262.33 | V_Loss: 2.8863 | TRPO: OK
# 04:43:21 [INFO] Update  467 | Eval Score:  -124.07 | V_Loss: 3.0126 | TRPO: OK
# 04:43:26 [INFO] Update  468 | Eval Score:  -161.42 | V_Loss: 3.2125 | TRPO: OK
# 04:43:30 [INFO] Update  469 | Eval Score:   -82.52 | V_Loss: 2.7934 | TRPO: OK
# 04:43:34 [INFO] Update  470 | Eval Score:  -234.63 | V_Loss: 3.0229 | TRPO: OK
# 04:43:38 [INFO] Update  471 | Eval Score:  -201.56 | V_Loss: 2.7555 | TRPO: OK
# 04:43:42 [INFO] Update  472 | Eval Score:  -128.00 | V_Loss: 2.8891 | TRPO: OK
# 04:43:46 [INFO] Update  473 | Eval Score:   -41.33 | V_Loss: 2.9751 | TRPO: OK
# 04:43:50 [INFO] Update  474 | Eval Score:  -158.01 | V_Loss: 2.8769 | TRPO: OK
# 04:43:55 [INFO] Update  475 | Eval Score:  -121.69 | V_Loss: 24.7315 | TRPO: OK
# 04:43:59 [INFO] Update  476 | Eval Score:  -212.33 | V_Loss: 7.6369 | TRPO: OK
# 04:44:03 [INFO] Update  477 | Eval Score:  -122.93 | V_Loss: 2.8150 | TRPO: OK
# 04:44:07 [INFO] Update  478 | Eval Score:  -125.54 | V_Loss: 2.8826 | TRPO: OK
# 04:44:11 [INFO] Update  479 | Eval Score:   -82.79 | V_Loss: 3.4359 | TRPO: OK
# 04:44:15 [INFO] Update  480 | Eval Score:  -164.77 | V_Loss: 2.8208 | TRPO: OK
# 04:44:19 [INFO] Update  481 | Eval Score:  -127.43 | V_Loss: 2.7585 | TRPO: OK
# 04:44:24 [INFO] Update  482 | Eval Score:  -242.40 | V_Loss: 3.2361 | TRPO: OK
# 04:44:28 [INFO] Update  483 | Eval Score:   -82.04 | V_Loss: 3.6188 | TRPO: OK
# 04:44:32 [INFO] Update  484 | Eval Score:   -41.33 | V_Loss: 3.2010 | TRPO: OK
# 04:44:37 [INFO] Update  485 | Eval Score:  -159.54 | V_Loss: 2.6383 | TRPO: OK
# 04:44:43 [INFO] Update  486 | Eval Score:  -123.89 | V_Loss: 2.8534 | TRPO: OK
# 04:44:50 [INFO] Update  487 | Eval Score:   -85.60 | V_Loss: 2.7348 | TRPO: OK
# 04:44:56 [INFO] Update  488 | Eval Score:  -246.10 | V_Loss: 2.6450 | TRPO: OK
# 04:45:00 [INFO] Update  489 | Eval Score:  -160.97 | V_Loss: 2.6978 | TRPO: OK
# 04:45:04 [INFO] Update  490 | Eval Score:   -81.13 | V_Loss: 2.7463 | TRPO: OK
# 04:45:08 [INFO] Update  491 | Eval Score:  -159.77 | V_Loss: 2.6676 | TRPO: OK
# 04:45:12 [INFO] Update  492 | Eval Score:  -120.25 | V_Loss: 2.7044 | TRPO: OK
# 04:45:17 [INFO] Update  493 | Eval Score:  -122.09 | V_Loss: 3.4578 | TRPO: OK
# 04:45:21 [INFO] Update  494 | Eval Score:  -159.59 | V_Loss: 2.8089 | TRPO: OK
# 04:45:25 [INFO] Update  495 | Eval Score:  -204.94 | V_Loss: 3.4978 | TRPO: OK
# 04:45:29 [INFO] Update  496 | Eval Score:  -145.13 | V_Loss: 2.6197 | TRPO: OK
# 04:45:34 [INFO] Update  497 | Eval Score:  -124.82 | V_Loss: 2.6715 | TRPO: OK
# 04:45:38 [INFO] Update  498 | Eval Score:  -122.24 | V_Loss: 2.7942 | TRPO: OK
# 04:45:42 [INFO] Update  499 | Eval Score:  -123.63 | V_Loss: 2.6858 | TRPO: OK
# 04:45:46 [INFO] Update  500 | Eval Score:  -118.49 | V_Loss: 2.6730 | TRPO: OK
# 04:45:51 [INFO] Update  501 | Eval Score:  -155.60 | V_Loss: 2.6717 | TRPO: OK
# 04:45:55 [INFO] Update  502 | Eval Score:   -75.94 | V_Loss: 2.5527 | TRPO: OK
# 04:45:59 [INFO] Update  503 | Eval Score:   -82.02 | V_Loss: 2.7077 | TRPO: OK
# 04:46:03 [INFO] Update  504 | Eval Score:  -157.69 | V_Loss: 2.6688 | TRPO: OK
# 04:46:08 [INFO] Update  505 | Eval Score:  -121.86 | V_Loss: 2.6587 | TRPO: OK
# 04:46:12 [INFO] Update  506 | Eval Score:  -165.33 | V_Loss: 2.5427 | TRPO: OK
# 04:46:16 [INFO] Update  507 | Eval Score:  -245.99 | V_Loss: 6.0791 | TRPO: OK
# 04:46:20 [INFO] Update  508 | Eval Score:  -161.74 | V_Loss: 2.5944 | TRPO: OK
# 04:46:24 [INFO] Update  509 | Eval Score:  -122.54 | V_Loss: 2.6593 | TRPO: OK
# 04:46:28 [INFO] Update  510 | Eval Score:  -231.36 | V_Loss: 2.5909 | TRPO: OK
# 04:46:33 [INFO] Update  511 | Eval Score:  -166.12 | V_Loss: 2.5920 | TRPO: OK
# 04:46:37 [INFO] Update  512 | Eval Score:  -213.84 | V_Loss: 2.8825 | TRPO: OK
# 04:46:41 [INFO] Update  513 | Eval Score:  -206.04 | V_Loss: 2.8837 | TRPO: OK
# 04:46:45 [INFO] Update  514 | Eval Score:  -315.40 | V_Loss: 2.6239 | TRPO: OK
# 04:46:49 [INFO] Update  515 | Eval Score:  -126.97 | V_Loss: 2.5793 | TRPO: OK
# 04:46:53 [INFO] Update  516 | Eval Score:  -200.94 | V_Loss: 2.8726 | TRPO: OK
# 04:46:58 [INFO] Update  517 | Eval Score:  -162.01 | V_Loss: 2.7293 | TRPO: OK
# 04:47:02 [INFO] Update  518 | Eval Score:  -166.41 | V_Loss: 2.8498 | TRPO: OK
# 04:47:06 [INFO] Update  519 | Eval Score:  -207.23 | V_Loss: 3.7113 | TRPO: OK
# 04:47:10 [INFO] Update  520 | Eval Score:  -118.31 | V_Loss: 2.5929 | TRPO: OK
# 04:47:14 [INFO] Update  521 | Eval Score:  -159.53 | V_Loss: 2.5189 | TRPO: OK
# 04:47:19 [INFO] Update  522 | Eval Score:  -168.78 | V_Loss: 2.5713 | TRPO: OK
# 04:47:23 [INFO] Update  523 | Eval Score:  -201.63 | V_Loss: 2.8653 | TRPO: OK
# 04:47:27 [INFO] Update  524 | Eval Score:   -81.53 | V_Loss: 2.6130 | TRPO: OK
# 04:47:31 [INFO] Update  525 | Eval Score:  -122.25 | V_Loss: 2.5263 | TRPO: OK
# 04:47:36 [INFO] Update  526 | Eval Score:  -240.16 | V_Loss: 2.5700 | TRPO: OK
# 04:47:40 [INFO] Update  527 | Eval Score:  -161.97 | V_Loss: 2.8872 | TRPO: OK
# 04:47:44 [INFO] Update  528 | Eval Score:  -123.48 | V_Loss: 3.3399 | TRPO: OK
# 04:47:49 [INFO] Update  529 | Eval Score:  -198.61 | V_Loss: 3.6732 | TRPO: OK
# 04:47:53 [INFO] Update  530 | Eval Score:  -118.35 | V_Loss: 2.5658 | TRPO: OK
# 04:47:57 [INFO] Update  531 | Eval Score:   -41.04 | V_Loss: 5.1360 | TRPO: OK
# 04:48:01 [INFO] Update  532 | Eval Score:  -121.22 | V_Loss: 2.9065 | TRPO: OK
# 04:48:06 [INFO] Update  533 | Eval Score:  -166.14 | V_Loss: 2.6461 | TRPO: OK
# 04:48:10 [INFO] Update  534 | Eval Score:   -83.89 | V_Loss: 3.2467 | TRPO: OK
# 04:48:14 [INFO] Update  535 | Eval Score:  -204.27 | V_Loss: 2.6200 | TRPO: OK
# 04:48:18 [INFO] Update  536 | Eval Score:  -161.79 | V_Loss: 2.5290 | TRPO: OK
# 04:48:23 [INFO] Update  537 | Eval Score:  -125.23 | V_Loss: 2.5486 | TRPO: OK
# 04:48:27 [INFO] Update  538 | Eval Score:  -156.33 | V_Loss: 2.5359 | TRPO: OK
# 04:48:31 [INFO] Update  539 | Eval Score:   -80.43 | V_Loss: 2.6732 | TRPO: OK
# 04:48:36 [INFO] Update  540 | Eval Score:  -205.97 | V_Loss: 3.3888 | TRPO: OK
# 04:48:40 [INFO] Update  541 | Eval Score:   -81.04 | V_Loss: 2.5762 | TRPO: OK
# 04:48:44 [INFO] Update  542 | Eval Score:   -83.97 | V_Loss: 2.5088 | TRPO: OK
# 04:48:48 [INFO] Update  543 | Eval Score:   -80.22 | V_Loss: 2.6551 | TRPO: OK
# 04:48:52 [INFO] Update  544 | Eval Score:  -126.24 | V_Loss: 2.6135 | TRPO: OK
# 04:48:56 [INFO] Update  545 | Eval Score:  -133.16 | V_Loss: 2.7245 | TRPO: OK
# 04:49:00 [INFO] Update  546 | Eval Score:  -227.28 | V_Loss: 4.8121 | TRPO: OK
# 04:49:05 [INFO] Update  547 | Eval Score:  -161.31 | V_Loss: 7.4478 | TRPO: OK
# 04:49:09 [INFO] Update  548 | Eval Score:  -203.76 | V_Loss: 2.7685 | TRPO: OK
# 04:49:13 [INFO] Update  549 | Eval Score:  -163.58 | V_Loss: 4.1465 | TRPO: OK
# 04:49:18 [INFO] Update  550 | Eval Score:  -124.74 | V_Loss: 2.7565 | TRPO: OK
# 04:49:22 [INFO] Update  551 | Eval Score:  -161.53 | V_Loss: 2.4795 | TRPO: OK
# 04:49:26 [INFO] Update  552 | Eval Score:  -121.95 | V_Loss: 2.5422 | TRPO: OK
# 04:49:31 [INFO] Update  553 | Eval Score:  -163.45 | V_Loss: 5.8182 | TRPO: OK
# 04:49:35 [INFO] Update  554 | Eval Score:  -200.02 | V_Loss: 2.5458 | TRPO: OK
# 04:49:39 [INFO] Update  555 | Eval Score:   -83.38 | V_Loss: 2.7812 | TRPO: OK
# 04:49:43 [INFO] Update  556 | Eval Score:  -163.26 | V_Loss: 2.4757 | TRPO: OK
# 04:49:48 [INFO] Update  557 | Eval Score:  -121.45 | V_Loss: 2.5905 | TRPO: OK
# 04:49:52 [INFO] Update  558 | Eval Score:  -160.24 | V_Loss: 2.6479 | TRPO: OK
# 04:49:56 [INFO] Update  559 | Eval Score:  -118.90 | V_Loss: 2.4977 | TRPO: OK
# 04:50:00 [INFO] Update  560 | Eval Score:   -82.54 | V_Loss: 2.8098 | TRPO: OK
# 04:50:04 [INFO] Update  561 | Eval Score:  -197.15 | V_Loss: 3.5647 | TRPO: OK
# 04:50:08 [INFO] Update  562 | Eval Score:  -126.76 | V_Loss: 2.5387 | TRPO: OK
# 04:50:13 [INFO] Update  563 | Eval Score:  -122.97 | V_Loss: 2.5393 | TRPO: OK
# 04:50:17 [INFO] Update  564 | Eval Score:  -165.03 | V_Loss: 2.5892 | TRPO: OK
# 04:50:21 [INFO] Update  565 | Eval Score:  -252.00 | V_Loss: 4.5113 | TRPO: OK
# 04:50:25 [INFO] Update  566 | Eval Score:  -159.15 | V_Loss: 2.6040 | TRPO: OK
# 04:50:30 [INFO] Update  567 | Eval Score:  -118.25 | V_Loss: 2.5304 | TRPO: OK
# 04:50:34 [INFO] Update  568 | Eval Score:  -192.32 | V_Loss: 2.5057 | TRPO: OK
# 04:50:38 [INFO] Update  569 | Eval Score:  -200.87 | V_Loss: 2.4449 | TRPO: OK
# 04:50:43 [INFO] Update  570 | Eval Score:  -157.18 | V_Loss: 2.5272 | TRPO: OK
# 04:50:47 [INFO] Update  571 | Eval Score:   -82.08 | V_Loss: 2.8170 | TRPO: OK
# 04:50:51 [INFO] Update  572 | Eval Score:  -199.03 | V_Loss: 4.3355 | TRPO: OK
# 04:50:55 [INFO] Update  573 | Eval Score:  -157.13 | V_Loss: 2.4934 | TRPO: OK
# 04:50:59 [INFO] Update  574 | Eval Score:  -246.56 | V_Loss: 2.4390 | TRPO: OK
# 04:51:03 [INFO] Update  575 | Eval Score:  -122.61 | V_Loss: 2.4460 | TRPO: OK
# 04:51:07 [INFO] Update  576 | Eval Score:  -117.64 | V_Loss: 2.5281 | TRPO: OK
# 04:51:12 [INFO] Update  577 | Eval Score:   -81.44 | V_Loss: 2.5567 | TRPO: OK
# 04:51:16 [INFO] Update  578 | Eval Score:  -194.55 | V_Loss: 11.1615 | TRPO: OK
# 04:51:20 [INFO] Update  579 | Eval Score:  -124.49 | V_Loss: 3.1484 | TRPO: OK
# 04:51:24 [INFO] Update  580 | Eval Score:  -185.20 | V_Loss: 2.5358 | TRPO: OK
# 04:51:28 [INFO] Update  581 | Eval Score:  -159.48 | V_Loss: 3.2805 | TRPO: OK
# 04:51:33 [INFO] Update  582 | Eval Score:  -207.94 | V_Loss: 2.5006 | TRPO: OK
# 04:51:37 [INFO] Update  583 | Eval Score:  -194.47 | V_Loss: 2.5037 | TRPO: OK
# 04:51:41 [INFO] Update  584 | Eval Score:   -41.26 | V_Loss: 2.5837 | TRPO: OK
# 04:51:45 [INFO] Update  585 | Eval Score:   -83.60 | V_Loss: 2.4332 | TRPO: OK
# 04:51:49 [INFO] Update  586 | Eval Score:  -123.62 | V_Loss: 2.4333 | TRPO: OK
# 04:51:53 [INFO] Update  587 | Eval Score:  -120.50 | V_Loss: 2.4997 | TRPO: OK
# 04:51:58 [INFO] Update  588 | Eval Score:  -248.53 | V_Loss: 2.8334 | TRPO: OK
# 04:52:02 [INFO] Update  589 | Eval Score:  -121.43 | V_Loss: 2.5607 | TRPO: OK
# 04:52:06 [INFO] Update  590 | Eval Score:   -82.68 | V_Loss: 31.0746 | TRPO: OK
# 04:52:10 [INFO] Update  591 | Eval Score:  -237.09 | V_Loss: 2.7938 | TRPO: OK
# 04:52:14 [INFO] Update  592 | Eval Score:   -83.38 | V_Loss: 121.2900 | TRPO: OK
# 04:52:19 [INFO] Update  593 | Eval Score:   -79.35 | V_Loss: 115.4168 | TRPO: OK
# 04:52:23 [INFO] Update  594 | Eval Score:  -125.02 | V_Loss: 11.5824 | TRPO: OK
# 04:52:27 [INFO] Update  595 | Eval Score:  -204.50 | V_Loss: 4.5780 | TRPO: OK
# 04:52:31 [INFO] Update  596 | Eval Score:  -164.84 | V_Loss: 4.5569 | TRPO: OK
# 04:52:36 [INFO] Update  597 | Eval Score:  -228.42 | V_Loss: 5.5809 | TRPO: OK
# 04:52:40 [INFO] Update  598 | Eval Score:  -246.94 | V_Loss: 3.3119 | TRPO: OK
# 04:52:44 [INFO] Update  599 | Eval Score:  -127.02 | V_Loss: 3.8491 | TRPO: OK
# 04:52:48 [INFO] Update  600 | Eval Score:  -119.67 | V_Loss: 3.1352 | TRPO: OK
# ...
# 05:22:03 [INFO] Update 1019 | Eval Score:  -157.34 | V_Loss: 2.4027 | TRPO: OK
# 05:22:07 [INFO] Update 1020 | Eval Score:   -84.86 | V_Loss: 2.3925 | TRPO: OK
# 05:22:11 [INFO] Update 1021 | Eval Score:  -122.52 | V_Loss: 2.6899 | TRPO: OK
# 05:22:16 [INFO] Update 1022 | Eval Score:  -165.39 | V_Loss: 2.5281 | TRPO: OK
# 05:22:20 [INFO] Update 1023 | Eval Score:  -164.24 | V_Loss: 2.6763 | TRPO: OK
# 05:22:24 [INFO] Update 1024 | Eval Score:  -156.03 | V_Loss: 2.4075 | TRPO: OK
# 05:22:28 [INFO] Update 1025 | Eval Score:  -121.81 | V_Loss: 2.4282 | TRPO: OK
# 05:22:33 [INFO] Update 1026 | Eval Score:  -120.45 | V_Loss: 2.3707 | TRPO: OK
# 05:22:37 [INFO] Update 1027 | Eval Score:  -151.36 | V_Loss: 7.7470 | TRPO: OK
# 05:22:41 [INFO] Update 1028 | Eval Score:  -202.79 | V_Loss: 2.5657 | TRPO: OK
# 05:22:45 [INFO] Update 1029 | Eval Score:  -119.09 | V_Loss: 2.6271 | TRPO: OK
# 05:22:49 [INFO] Update 1030 | Eval Score:  -193.15 | V_Loss: 2.5354 | TRPO: OK
# 05:22:53 [INFO] Update 1031 | Eval Score:  -273.18 | V_Loss: 2.5448 | TRPO: OK
# 05:22:57 [INFO] Update 1032 | Eval Score:  -122.80 | V_Loss: 2.6672 | TRPO: OK
# 05:23:02 [INFO] Update 1033 | Eval Score:  -120.27 | V_Loss: 2.4387 | TRPO: OK
# 05:23:06 [INFO] Update 1034 | Eval Score:  -202.67 | V_Loss: 2.4151 | TRPO: OK
# 05:23:10 [INFO] Update 1035 | Eval Score:  -165.80 | V_Loss: 2.3989 | TRPO: OK
# 05:23:14 [INFO] Update 1036 | Eval Score:  -238.84 | V_Loss: 6.7743 | TRPO: OK
# 05:23:18 [INFO] Update 1037 | Eval Score:  -113.30 | V_Loss: 3.2026 | TRPO: OK
# 05:23:22 [INFO] Update 1038 | Eval Score:  -120.78 | V_Loss: 2.5970 | TRPO: OK
# 05:23:26 [INFO] Update 1039 | Eval Score:   -86.30 | V_Loss: 3.3615 | TRPO: OK
# 05:23:31 [INFO] Update 1040 | Eval Score:  -121.26 | V_Loss: 3.4304 | TRPO: OK
# 05:23:35 [INFO] Update 1041 | Eval Score:  -193.88 | V_Loss: 2.4282 | TRPO: OK
# 05:23:39 [INFO] Update 1042 | Eval Score:   -82.43 | V_Loss: 2.5962 | TRPO: OK
# 05:23:43 [INFO] Update 1043 | Eval Score:  -117.90 | V_Loss: 2.4756 | TRPO: OK
# 05:23:47 [INFO] Update 1044 | Eval Score:  -195.03 | V_Loss: 3.2545 | TRPO: OK
# 05:23:51 [INFO] Update 1045 | Eval Score:  -161.45 | V_Loss: 2.7422 | TRPO: OK
# 05:23:56 [INFO] Update 1046 | Eval Score:   -83.01 | V_Loss: 2.4380 | TRPO: OK
# 05:24:00 [INFO] Update 1047 | Eval Score:  -156.75 | V_Loss: 2.4141 | TRPO: OK
# 05:24:04 [INFO] Update 1048 | Eval Score:  -121.52 | V_Loss: 2.5193 | TRPO: OK
# 05:24:08 [INFO] Update 1049 | Eval Score:  -117.15 | V_Loss: 2.3755 | TRPO: OK
# 05:24:12 [INFO] Update 1050 | Eval Score:  -197.54 | V_Loss: 2.6580 | TRPO: OK
# 05:24:17 [INFO] Update 1051 | Eval Score:  -250.83 | V_Loss: 3.9021 | TRPO: OK
# 05:24:21 [INFO] Update 1052 | Eval Score:  -242.85 | V_Loss: 6.4156 | TRPO: OK
# 05:24:25 [INFO] Update 1053 | Eval Score:  -154.26 | V_Loss: 2.9737 | TRPO: OK
# 05:24:29 [INFO] Update 1054 | Eval Score:   -85.38 | V_Loss: 2.5263 | TRPO: OK
# 05:24:33 [INFO] Update 1055 | Eval Score:  -206.81 | V_Loss: 2.5694 | TRPO: OK
# 05:24:37 [INFO] Update 1056 | Eval Score:   -82.68 | V_Loss: 3.3689 | TRPO: OK
# 05:24:41 [INFO] Update 1057 | Eval Score:  -287.35 | V_Loss: 2.4310 | TRPO: OK
# 05:24:46 [INFO] Update 1058 | Eval Score:   -82.20 | V_Loss: 4.3513 | TRPO: OK
# 05:24:50 [INFO] Update 1059 | Eval Score:  -119.39 | V_Loss: 8.4848 | TRPO: OK
# 05:24:54 [INFO] Update 1060 | Eval Score:  -165.63 | V_Loss: 2.4860 | TRPO: OK
# 05:24:58 [INFO] Update 1061 | Eval Score:  -119.93 | V_Loss: 2.5618 | TRPO: OK
# 05:25:02 [INFO] Update 1062 | Eval Score:  -160.24 | V_Loss: 10.6153 | TRPO: OK
# 05:25:06 [INFO] Update 1063 | Eval Score:  -122.70 | V_Loss: 4.1852 | TRPO: OK
# 05:25:11 [INFO] Update 1064 | Eval Score:  -196.29 | V_Loss: 2.4984 | TRPO: OK
# 05:25:15 [INFO] Update 1065 | Eval Score:  -120.05 | V_Loss: 2.9446 | TRPO: OK
# 05:25:19 [INFO] Update 1066 | Eval Score:  -195.67 | V_Loss: 2.5286 | TRPO: OK
# 05:25:23 [INFO] Update 1067 | Eval Score:   -42.63 | V_Loss: 2.4724 | TRPO: OK
# 05:25:27 [INFO] Update 1068 | Eval Score:   -85.01 | V_Loss: 2.4412 | TRPO: OK
# 05:25:32 [INFO] Update 1069 | Eval Score:  -155.07 | V_Loss: 3.5131 | TRPO: OK
# 05:25:36 [INFO] Update 1070 | Eval Score:  -167.64 | V_Loss: 2.5429 | TRPO: OK
# 05:25:40 [INFO] Update 1071 | Eval Score:  -122.78 | V_Loss: 2.5236 | TRPO: OK
# 05:25:44 [INFO] Update 1072 | Eval Score:  -203.90 | V_Loss: 2.5102 | TRPO: OK
# 05:25:48 [INFO] Update 1073 | Eval Score:  -157.22 | V_Loss: 6.8722 | TRPO: OK
# 05:25:52 [INFO] Update 1074 | Eval Score:  -125.25 | V_Loss: 2.4658 | TRPO: OK
# 05:25:57 [INFO] Update 1075 | Eval Score:  -123.90 | V_Loss: 2.9202 | TRPO: OK
# 05:26:01 [INFO] Update 1076 | Eval Score:  -124.53 | V_Loss: 2.5243 | TRPO: OK
# 05:26:05 [INFO] Update 1077 | Eval Score:  -125.56 | V_Loss: 2.9345 | TRPO: OK
# 05:26:09 [INFO] Update 1078 | Eval Score:  -230.31 | V_Loss: 2.4108 | TRPO: OK
# 05:26:13 [INFO] Update 1079 | Eval Score:   -80.36 | V_Loss: 2.5271 | TRPO: OK
# 05:26:17 [INFO] Update 1080 | Eval Score:  -123.12 | V_Loss: 2.4380 | TRPO: OK
# 05:26:22 [INFO] Update 1081 | Eval Score:  -158.69 | V_Loss: 2.5804 | TRPO: OK
# 05:26:26 [INFO] Update 1082 | Eval Score:  -164.16 | V_Loss: 5.9605 | TRPO: OK
# 05:26:30 [INFO] Update 1083 | Eval Score:  -119.78 | V_Loss: 3.1694 | TRPO: OK
# 05:26:34 [INFO] Update 1084 | Eval Score:  -157.34 | V_Loss: 2.5891 | TRPO: OK
# 05:26:39 [INFO] Update 1085 | Eval Score:  -121.91 | V_Loss: 6.8479 | TRPO: OK
# 05:26:43 [INFO] Update 1086 | Eval Score:  -200.86 | V_Loss: 2.4711 | TRPO: OK
# 05:26:47 [INFO] Update 1087 | Eval Score:  -199.14 | V_Loss: 2.5227 | TRPO: OK
# 05:26:52 [INFO] Update 1088 | Eval Score:  -156.95 | V_Loss: 5.7182 | TRPO: OK
# 05:26:56 [INFO] Update 1089 | Eval Score:  -163.06 | V_Loss: 2.6109 | TRPO: OK
# 05:27:00 [INFO] Update 1090 | Eval Score:  -122.50 | V_Loss: 2.5270 | TRPO: OK
# 05:27:05 [INFO] Update 1091 | Eval Score:  -228.37 | V_Loss: 2.4515 | TRPO: OK
# 05:27:09 [INFO] Update 1092 | Eval Score:  -154.58 | V_Loss: 6.9501 | TRPO: OK
# 05:27:13 [INFO] Update 1093 | Eval Score:  -120.44 | V_Loss: 2.4618 | TRPO: OK
# 05:27:17 [INFO] Update 1094 | Eval Score:  -164.41 | V_Loss: 2.5050 | TRPO: OK
# 05:27:22 [INFO] Update 1095 | Eval Score:   -82.01 | V_Loss: 2.4373 | TRPO: OK
# 05:27:26 [INFO] Update 1096 | Eval Score:  -166.38 | V_Loss: 2.8548 | TRPO: OK
# 05:27:30 [INFO] Update 1097 | Eval Score:  -202.75 | V_Loss: 4.5643 | TRPO: OK
# 05:27:34 [INFO] Update 1098 | Eval Score:  -166.06 | V_Loss: 2.5264 | TRPO: OK
# 05:27:39 [INFO] Update 1099 | Eval Score:  -161.67 | V_Loss: 2.6237 | TRPO: OK
# 05:27:43 [INFO] Update 1100 | Eval Score:   -83.09 | V_Loss: 2.5007 | TRPO: OK
# 05:27:47 [INFO] Update 1101 | Eval Score:  -162.37 | V_Loss: 2.8262 | TRPO: OK
# 05:27:51 [INFO] Update 1102 | Eval Score:  -140.13 | V_Loss: 3.4960 | TRPO: OK
# 05:27:55 [INFO] Update 1103 | Eval Score:   -83.14 | V_Loss: 2.5276 | TRPO: OK
# 05:27:59 [INFO] Update 1104 | Eval Score:  -130.89 | V_Loss: 2.4341 | TRPO: OK
# 05:28:03 [INFO] Update 1105 | Eval Score:   -82.99 | V_Loss: 2.7417 | TRPO: OK
# 05:28:08 [INFO] Update 1106 | Eval Score:   -81.95 | V_Loss: 2.4189 | TRPO: OK
# 05:28:12 [INFO] Update 1107 | Eval Score:   -85.80 | V_Loss: 2.4792 | TRPO: OK
# 05:28:16 [INFO] Update 1108 | Eval Score:  -159.98 | V_Loss: 2.4200 | TRPO: OK
# 05:28:20 [INFO] Update 1109 | Eval Score:  -122.46 | V_Loss: 4.6751 | TRPO: OK
# 05:28:24 [INFO] Update 1110 | Eval Score:  -198.20 | V_Loss: 2.4791 | TRPO: OK
# 05:28:29 [INFO] Update 1111 | Eval Score:  -201.56 | V_Loss: 2.4260 | TRPO: OK
# 05:28:33 [INFO] Update 1112 | Eval Score:  -163.11 | V_Loss: 2.4929 | TRPO: OK
# 05:28:37 [INFO] Update 1113 | Eval Score:  -160.64 | V_Loss: 2.3867 | TRPO: OK
# 05:28:42 [INFO] Update 1114 | Eval Score:  -119.37 | V_Loss: 2.4361 | TRPO: OK
# 05:28:46 [INFO] Update 1115 | Eval Score:  -185.26 | V_Loss: 2.6783 | TRPO: OK
# 05:28:50 [INFO] Update 1116 | Eval Score:  -123.26 | V_Loss: 2.4471 | TRPO: OK
# 05:28:54 [INFO] Update 1117 | Eval Score:  -122.84 | V_Loss: 2.3959 | TRPO: OK
# 05:28:58 [INFO] Update 1118 | Eval Score:  -267.57 | V_Loss: 6.1468 | TRPO: OK
# 05:29:03 [INFO] Update 1119 | Eval Score:  -159.97 | V_Loss: 2.4417 | TRPO: OK
# 05:29:07 [INFO] Update 1120 | Eval Score:  -119.30 | V_Loss: 3.8114 | TRPO: OK
# 05:29:11 [INFO] Update 1121 | Eval Score:  -143.86 | V_Loss: 2.4387 | TRPO: OK
# 05:29:15 [INFO] Update 1122 | Eval Score:  -163.15 | V_Loss: 2.8367 | TRPO: OK
# 05:29:19 [INFO] Update 1123 | Eval Score:    -2.20 | V_Loss: 6.2415 | TRPO: OK
# 05:29:24 [INFO] Update 1124 | Eval Score:   -81.68 | V_Loss: 2.4727 | TRPO: OK
# 05:29:28 [INFO] Update 1125 | Eval Score:  -245.63 | V_Loss: 2.3955 | TRPO: OK
# 05:29:32 [INFO] Update 1126 | Eval Score:  -193.77 | V_Loss: 3.0026 | TRPO: OK
# 05:29:36 [INFO] Update 1127 | Eval Score:   -41.26 | V_Loss: 2.7552 | TRPO: OK
# 05:29:41 [INFO] Update 1128 | Eval Score:  -237.37 | V_Loss: 2.4740 | TRPO: OK
# 05:29:45 [INFO] Update 1129 | Eval Score:  -125.19 | V_Loss: 2.4211 | TRPO: OK
# 05:29:49 [INFO] Update 1130 | Eval Score:  -119.95 | V_Loss: 2.4928 | TRPO: OK
# 05:29:53 [INFO] Update 1131 | Eval Score:  -117.26 | V_Loss: 2.4401 | TRPO: OK
# 05:29:57 [INFO] Update 1132 | Eval Score:   -79.47 | V_Loss: 2.5810 | TRPO: OK
# 05:30:01 [INFO] Update 1133 | Eval Score:   -80.93 | V_Loss: 2.4058 | TRPO: OK
# 05:30:05 [INFO] Update 1134 | Eval Score:   -40.45 | V_Loss: 5.5030 | TRPO: OK
# 05:30:10 [INFO] Update 1135 | Eval Score:  -116.56 | V_Loss: 2.3800 | TRPO: OK
# 05:30:14 [INFO] Update 1136 | Eval Score:  -123.15 | V_Loss: 2.4167 | TRPO: OK
# 05:30:18 [INFO] Update 1137 | Eval Score:  -166.17 | V_Loss: 2.4136 | TRPO: OK
# 05:30:22 [INFO] Update 1138 | Eval Score:  -168.66 | V_Loss: 2.5382 | TRPO: OK
# 05:30:26 [INFO] Update 1139 | Eval Score:  -124.32 | V_Loss: 2.4580 | TRPO: OK
# 05:30:31 [INFO] Update 1140 | Eval Score:   -82.32 | V_Loss: 2.6448 | TRPO: OK
# 05:30:35 [INFO] Update 1141 | Eval Score:  -118.93 | V_Loss: 2.4994 | TRPO: OK
# 05:30:39 [INFO] Update 1142 | Eval Score:  -159.05 | V_Loss: 2.4477 | TRPO: OK
# 05:30:43 [INFO] Update 1143 | Eval Score:  -230.30 | V_Loss: 2.3679 | TRPO: OK
# 05:30:47 [INFO] Update 1144 | Eval Score:  -167.26 | V_Loss: 2.3587 | TRPO: OK
# 05:30:52 [INFO] Update 1145 | Eval Score:  -122.34 | V_Loss: 3.5867 | TRPO: OK
# 05:30:56 [INFO] Update 1146 | Eval Score:   -78.42 | V_Loss: 2.3645 | TRPO: OK
# 05:31:00 [INFO] Update 1147 | Eval Score:  -194.92 | V_Loss: 2.4680 | TRPO: OK
# 05:31:04 [INFO] Update 1148 | Eval Score:  -238.63 | V_Loss: 3.2027 | TRPO: OK
# 05:31:08 [INFO] Update 1149 | Eval Score:  -158.25 | V_Loss: 2.4509 | TRPO: OK
# 05:31:13 [INFO] Update 1150 | Eval Score:  -200.95 | V_Loss: 2.4133 | TRPO: OK
# 05:31:17 [INFO] Update 1151 | Eval Score:  -163.23 | V_Loss: 2.3936 | TRPO: OK
# 05:31:21 [INFO] Update 1152 | Eval Score:  -121.64 | V_Loss: 2.3858 | TRPO: OK
# 05:31:25 [INFO] Update 1153 | Eval Score:  -209.30 | V_Loss: 2.3709 | TRPO: OK
# 05:31:30 [INFO] Update 1154 | Eval Score:  -125.64 | V_Loss: 2.3860 | TRPO: OK
# 05:31:34 [INFO] Update 1155 | Eval Score:  -230.61 | V_Loss: 2.3555 | TRPO: OK
# 05:31:38 [INFO] Update 1156 | Eval Score:  -124.42 | V_Loss: 3.0948 | TRPO: OK
# 05:31:42 [INFO] Update 1157 | Eval Score:  -209.93 | V_Loss: 4.0910 | TRPO: OK
# 05:31:46 [INFO] Update 1158 | Eval Score:  -122.47 | V_Loss: 2.4168 | TRPO: OK
# 05:31:50 [INFO] Update 1159 | Eval Score:   -80.71 | V_Loss: 2.3381 | TRPO: OK
# 05:31:54 [INFO] Update 1160 | Eval Score:  -167.15 | V_Loss: 2.3275 | TRPO: OK
# 05:31:59 [INFO] Update 1161 | Eval Score:   -41.66 | V_Loss: 2.3710 | TRPO: OK
# 05:32:03 [INFO] Update 1162 | Eval Score:   -82.42 | V_Loss: 2.3488 | TRPO: OK
# 05:32:07 [INFO] Update 1163 | Eval Score:  -161.22 | V_Loss: 2.3263 | TRPO: OK
# 05:32:11 [INFO] Update 1164 | Eval Score:  -201.56 | V_Loss: 2.4380 | TRPO: OK
# 05:32:15 [INFO] Update 1165 | Eval Score:  -123.31 | V_Loss: 2.6695 | TRPO: OK
# 05:32:19 [INFO] Update 1166 | Eval Score:  -168.12 | V_Loss: 2.3961 | TRPO: OK
# 05:32:24 [INFO] Update 1167 | Eval Score:  -164.39 | V_Loss: 2.4097 | TRPO: OK
# 05:32:28 [INFO] Update 1168 | Eval Score:   -78.67 | V_Loss: 2.3090 | TRPO: OK
# 05:32:32 [INFO] Update 1169 | Eval Score:  -122.83 | V_Loss: 2.3419 | TRPO: OK
# 05:32:36 [INFO] Update 1170 | Eval Score:  -159.83 | V_Loss: 2.3504 | TRPO: OK
# 05:32:40 [INFO] Update 1171 | Eval Score:  -260.48 | V_Loss: 2.3668 | TRPO: OK
# 05:32:45 [INFO] Update 1172 | Eval Score:  -164.12 | V_Loss: 2.2945 | TRPO: OK
# 05:32:49 [INFO] Update 1173 | Eval Score:  -202.66 | V_Loss: 2.3370 | TRPO: OK
# 05:32:54 [INFO] Update 1174 | Eval Score:  -240.67 | V_Loss: 2.3022 | TRPO: OK
# 05:32:58 [INFO] Update 1175 | Eval Score:   -81.80 | V_Loss: 2.2813 | TRPO: OK
# 05:33:03 [INFO] Update 1176 | Eval Score:  -191.99 | V_Loss: 2.3296 | TRPO: OK
# 05:33:07 [INFO] Update 1177 | Eval Score:  -154.47 | V_Loss: 2.4246 | TRPO: OK
# 05:33:11 [INFO] Update 1178 | Eval Score:  -125.09 | V_Loss: 2.4766 | TRPO: OK
# 05:33:15 [INFO] Update 1179 | Eval Score:  -159.60 | V_Loss: 2.2674 | TRPO: OK
# 05:33:19 [INFO] Update 1180 | Eval Score:  -163.49 | V_Loss: 2.2422 | TRPO: OK
# 05:33:23 [INFO] Update 1181 | Eval Score:  -121.50 | V_Loss: 2.2793 | TRPO: OK
# 05:33:27 [INFO] Update 1182 | Eval Score:  -119.36 | V_Loss: 2.9485 | TRPO: OK
# 05:33:32 [INFO] Update 1183 | Eval Score:  -122.84 | V_Loss: 2.5144 | TRPO: OK
# 05:33:36 [INFO] Update 1184 | Eval Score:  -127.17 | V_Loss: 2.2889 | TRPO: OK
# 05:33:40 [INFO] Update 1185 | Eval Score:  -202.30 | V_Loss: 2.2416 | TRPO: OK
# 05:33:44 [INFO] Update 1186 | Eval Score:  -164.60 | V_Loss: 2.2454 | TRPO: OK
# 05:33:48 [INFO] Update 1187 | Eval Score:  -198.72 | V_Loss: 2.2316 | TRPO: OK
# 05:33:52 [INFO] Update 1188 | Eval Score:  -121.64 | V_Loss: 2.2207 | TRPO: OK
# 05:33:57 [INFO] Update 1189 | Eval Score:  -167.06 | V_Loss: 2.2315 | TRPO: OK
# 05:34:01 [INFO] Update 1190 | Eval Score:  -202.39 | V_Loss: 2.2886 | TRPO: OK
# 05:34:05 [INFO] Update 1191 | Eval Score:  -118.97 | V_Loss: 2.2606 | TRPO: OK
# 05:34:09 [INFO] Update 1192 | Eval Score:   -41.93 | V_Loss: 3.6652 | TRPO: OK
# 05:34:13 [INFO] Update 1193 | Eval Score:  -161.01 | V_Loss: 2.4142 | TRPO: OK
# 05:34:18 [INFO] Update 1194 | Eval Score:   -41.87 | V_Loss: 2.2698 | TRPO: OK
# 05:34:22 [INFO] Update 1195 | Eval Score:  -118.25 | V_Loss: 2.2533 | TRPO: OK
# 05:34:26 [INFO] Update 1196 | Eval Score:   -81.03 | V_Loss: 2.8010 | TRPO: OK
# 05:34:31 [INFO] Update 1197 | Eval Score:  -162.49 | V_Loss: 2.2333 | TRPO: OK
# 05:34:35 [INFO] Update 1198 | Eval Score:  -124.73 | V_Loss: 2.2542 | TRPO: OK
# 05:34:39 [INFO] Update 1199 | Eval Score:  -126.19 | V_Loss: 2.3888 | TRPO: OK
# 05:34:43 [INFO] Update 1200 | Eval Score:  -206.91 | V_Loss: 2.2233 | TRPO: OK
# 05:34:47 [INFO] Update 1201 | Eval Score:  -158.02 | V_Loss: 2.2647 | TRPO: OK
# 05:34:52 [INFO] Update 1202 | Eval Score:  -123.46 | V_Loss: 2.2631 | TRPO: OK
# 05:34:56 [INFO] Update 1203 | Eval Score:  -159.90 | V_Loss: 2.2799 | TRPO: OK
# 05:35:00 [INFO] Update 1204 | Eval Score:  -163.79 | V_Loss: 2.2255 | TRPO: OK
# 05:35:04 [INFO] Update 1205 | Eval Score:  -206.18 | V_Loss: 2.2317 | TRPO: OK
# 05:35:08 [INFO] Update 1206 | Eval Score:  -227.80 | V_Loss: 2.3805 | TRPO: OK
# 05:35:13 [INFO] Update 1207 | Eval Score:  -122.54 | V_Loss: 2.2380 | TRPO: OK
# 05:35:17 [INFO] Update 1208 | Eval Score:  -122.16 | V_Loss: 2.2184 | TRPO: OK
# 05:35:21 [INFO] Update 1209 | Eval Score:  -161.71 | V_Loss: 2.3474 | TRPO: OK
# 05:35:25 [INFO] Update 1210 | Eval Score:  -154.86 | V_Loss: 2.2474 | TRPO: OK
# 05:35:30 [INFO] Update 1211 | Eval Score:  -121.76 | V_Loss: 3.1252 | TRPO: OK
# 05:35:34 [INFO] Update 1212 | Eval Score:  -182.46 | V_Loss: 2.2309 | TRPO: OK
# 05:35:38 [INFO] Update 1213 | Eval Score:  -165.91 | V_Loss: 2.5750 | TRPO: OK
# 05:35:42 [INFO] Update 1214 | Eval Score:  -195.36 | V_Loss: 2.2698 | TRPO: OK
# 05:35:46 [INFO] Update 1215 | Eval Score:  -120.34 | V_Loss: 2.2374 | TRPO: OK
# 05:35:51 [INFO] Update 1216 | Eval Score:  -121.84 | V_Loss: 2.3205 | TRPO: OK
# 05:35:55 [INFO] Update 1217 | Eval Score:  -120.73 | V_Loss: 6.3020 | TRPO: OK
# 05:35:59 [INFO] Update 1218 | Eval Score:  -153.15 | V_Loss: 2.3097 | TRPO: OK
# 05:36:03 [INFO] Update 1219 | Eval Score:  -162.39 | V_Loss: 2.2690 | TRPO: OK
# 05:36:07 [INFO] Update 1220 | Eval Score:  -121.12 | V_Loss: 2.2199 | TRPO: OK

# %%
env.close()

# %%
from pathlib import Path
from datetime import datetime

def make_unique_path(path: str | Path) -> Path:
    """
    path が既に存在する場合、末尾に _1, _2, ... を付けて未使用のパスを返す。
    例: ddpg_final_20251221_235959.pth -> ddpg_final_20251221_235959_1.pth -> ...
    """
    p = Path(path)

    # 存在しないならそのまま使う
    if not p.exists():
        return p

    parent = p.parent
    stem = p.stem      # 拡張子抜きファイル名
    suffix = p.suffix  # ".pth"

    i = 1
    while True:
        cand = parent / f"{stem}_{i}{suffix}"
        if not cand.exists():
            return cand
        i += 1


# 推論用に eval モードにしておく（保存自体は train のままでも可）
agent.mode2eval()

stamp = datetime.now().strftime("%Y%m%d_%H%M%S")

models_dir = Path("./models")
models_dir.mkdir(parents=True, exist_ok=True)

base_path = models_dir / f"trpo_final_{stamp}.pth"
save_path = make_unique_path(base_path)

agent.save_all(
    save_path.as_posix(),
    extra={
        "total_step": int(total_step),
        "reward_history": rh,  # 必要ならそのままでOK
    }
)

print(f"saved to {save_path}")
# Out:
# saved to models/trpo_final_20260129_053609.pth

# %% [markdown]
# # 自作のTD3ノートブック

# %%
import copy
from dataclasses import dataclass, asdict, is_dataclass, field
import sys
import logging

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import gymnasium as gym

from myActivator import tanhAndScale
from myReplayBuffer import ReplayBuffer

# %%
logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s [%(levelname)s] %(message)s",
                    stream=sys.stdout, datefmt="%H:%M:%S")

# %%
env = gym.make("Pendulum-v1")
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
for key in vars(env.unwrapped):
    logging.info('%s: %s', key, vars(env.unwrapped)[key])
# Out:
# 13:21:00 [INFO] id: Pendulum-v1
# 13:21:00 [INFO] entry_point: gymnasium.envs.classic_control.pendulum:PendulumEnv
# 13:21:00 [INFO] reward_threshold: None
# 13:21:00 [INFO] nondeterministic: False
# 13:21:00 [INFO] max_episode_steps: 200
# 13:21:00 [INFO] order_enforce: True
# 13:21:00 [INFO] disable_env_checker: False
# 13:21:00 [INFO] kwargs: {}
# 13:21:00 [INFO] additional_wrappers: ()
# 13:21:00 [INFO] vector_entry_point: None
# 13:21:00 [INFO] namespace: None
# 13:21:00 [INFO] name: Pendulum
# 13:21:00 [INFO] version: 1
# 13:21:00 [INFO] max_speed: 8
# 13:21:00 [INFO] max_torque: 2.0
# 13:21:00 [INFO] dt: 0.05
# 13:21:00 [INFO] g: 10.0
# 13:21:00 [INFO] m: 1.0
# 13:21:00 [INFO] l: 1.0
# 13:21:00 [INFO] render_mode: None
# 13:21:00 [INFO] screen_dim: 500
# 13:21:00 [INFO] screen: None
# 13:21:00 [INFO] clock: None
# 13:21:00 [INFO] isopen: True
# 13:21:00 [INFO] action_space: Box(-2.0, 2.0, (1,), float32)
# 13:21:00 [INFO] observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# 13:21:00 [INFO] spec: EnvSpec(id='Pendulum-v1', entry_point='gymnasium.envs.classic_control.pendulum:PendulumEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=False, disable_env_checker=True, kwargs={}, namespace=None, name='Pendulum', version=1, additional_wrappers=(), vector_entry_point=None)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
@dataclass
class Config:
    # =========================
    # ニューラルネットの設定
    # =========================
    Q_net_sizes: list[int] = field(default_factory=lambda: [64, 64])
    P_net_sizes: list[int] = field(default_factory=lambda: [64, 64])
    Q_net_in: int = 4  # obs(3) + action(1)
    P_net_in: int = 3  # obs(3)
    Q_net_out: int = 1
    P_net_out: int = 1

    # =========================
    # 環境の制約
    # =========================
    # Pendulum-v1の仕様通り
    u_ulim: float = 2.0
    u_llim: float = -2.0

    # =========================
    # 学習に関するパラメータ
    # =========================
    # Pendulumは状態空間が狭いので、学習率は少し高めの 1e-3 (0.001) でも
    # 早く収束することが多いです。不安定なら 3e-4 に下げてください。
    Q_lr1: float = 1e-3
    Q_lr2: float = 1e-3
    P_lr: float = 1e-3
    
    gamma: float = 0.99
    
    sig: float = 0.1
    
    tau: float = 5e-3

# %%
class TD3Agent:
    def __init__(self,Config,device=None):
        if Config:
            self.Config = Config
        else:
            raise ValueError("No Config!!")
        
        # ---- device 決定（CUDAがあればCUDA、指示が無ければ）----
        if device is None:
            self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        else:
            self.device = torch.device(device)

        # ---- action bounds（deviceを揃える為 Tensor 化）----
        self.u_low = torch.as_tensor(Config.u_llim, dtype=torch.float32, device=self.device)
        self.u_high = torch.as_tensor(Config.u_ulim, dtype=torch.float32, device=self.device)

        self.Q_net1 = self.build_net(
            Config.Q_net_in,
            Config.Q_net_sizes,
            Config.Q_net_out,
        ).to(self.device)
        self.Q_net1.train()

        self.Q_net2 = self.build_net(
            Config.Q_net_in,
            Config.Q_net_sizes,
            Config.Q_net_out,
        ).to(self.device)
        self.Q_net2.train()

        self.P_net = self.build_net(
            Config.P_net_in,
            Config.P_net_sizes,
            Config.P_net_out,
            tanhAndScale(a_high=self.u_high,a_low=self.u_low),
        ).to(self.device)
        self.P_net.train()

        # ---- Target nets ----
        self.Q_target_net1 = copy.deepcopy(self.Q_net1).to(self.device)
        self.Q_target_net2 = copy.deepcopy(self.Q_net2).to(self.device)
        self.P_target_net = copy.deepcopy(self.P_net).to(self.device)
        self.Q_target_net1.eval()
        self.Q_target_net2.eval()
        self.P_target_net.eval()

        self.Q_optim1 = optim.Adam(self.Q_net1.parameters(), lr=Config.Q_lr1)
        self.Q_optim2 = optim.Adam(self.Q_net2.parameters(), lr=Config.Q_lr2)
        self.P_optim = optim.Adam(self.P_net.parameters(), lr=Config.P_lr)

        # Actorの学習頻度を設定するための変数（これを特定の数で割った余りが0の時だけactor更新にする）
        self.actor_update_counter = 0
        self.policy_update_freq = 2  # TD3の論文では2に設定されていることが多い

        # TDターゲットの計算の際に使用するノイズのクリッピング範囲
        self.target_policy_noise_clip = 0.5  # TD3論文では0.5に設定されていることが多い

    def to(self, device):
        """エージェントの内部のネットと必要Tensorを全部指定 device に移す"""
        self.device = torch.device(device)
        self.Q_net1.to(self.device)
        self.Q_net2.to(self.device)
        self.P_net.to(self.device)
        self.Q_target_net1.to(self.device)
        self.Q_target_net2.to(self.device)
        self.P_target_net.to(self.device)
        self.u_low = self.u_low.to(self.device)
        self.u_high = self.u_high.to(self.device)
        return self

    def build_net(self, input_size, hidden_sizes, output_size=1, output_activator=None):
        layers = []
        for input_size, output_size in zip([input_size]+hidden_sizes, hidden_sizes+[output_size]):
            layers.append(nn.Linear(input_size, output_size))
            layers.append(nn.ReLU())
        layers = layers[:-1]  # 最後のReLUだけ取り除く
        if output_activator:
            layers.append(output_activator)
        net = nn.Sequential(*layers)
        return net
    
    @torch.no_grad()
    def step(self, observation):
        """ノイズ無し（評価用）。環境に渡す行動を返す。"""
        obs_t = torch.as_tensor(observation, dtype=torch.float32, device=self.device)
        if obs_t.dim() == 1:
            obs_t = obs_t.unsqueeze(0)
        
        action = self.P_net(obs_t)
        action = torch.clamp(action, self.u_low, self.u_high)
        return action.squeeze(0).cpu().numpy()
    
    @torch.no_grad()
    def step_with_noise(self, observation):
        # observationをTensorにし、deviceに送る
        obs = torch.as_tensor(observation, dtype=torch.float32, device=self.device)
        if obs.dim() == 1:
            obs = obs.unsqueeze(0)
        
        # 決定論的行動決定
        action = self.P_net(obs)  # shape: (1, act_dim)

        # ε ~ N(0, σ^2 I) を生成して加算（探索ノイズを加える）
        eps = float(self.Config.sig) * torch.randn_like(action)
        action = action + eps

        # 出力製薬 [u_low, u_high] 以内に収める
        action = torch.clamp(action, self.u_low, self.u_high)

        # 環境に渡すならバッチ次元を落として渡す
        return action.squeeze(0).cpu().numpy()
    
    def save_all(self, path: str, extra: dict | None = None):
        """
        Actor/Critic + target nets をまとめて保存（最終モデル用）。
        """
        cfg = asdict(self.Config) if is_dataclass(self.Config) else self.Config

        ckpt = {
            "config": cfg,
            "P_net": self.P_net.state_dict(),
            "Q_net1": self.Q_net1.state_dict(),
            "Q_net2": self.Q_net2.state_dict(),
            "P_target_net": self.P_target_net.state_dict(),
            "Q_target_net1": self.Q_target_net1.state_dict(),
            "Q_target_net2": self.Q_target_net2.state_dict(),
        }
        if extra is not None:
            ckpt["extra"] = extra

        torch.save(ckpt, path)


    def load_all(self, path: str, map_location=None):
        """
        save_all() で保存したチェックポイントをロード。

        PyTorch 2.6 以降:
        torch.load() のデフォルトが weights_only=True になったため、
        config/extra を含むチェックポイントはそのままだと UnpicklingError になり得る。
        その回避として「信頼できるチェックポイントに限り」 weights_only=False を明示する。

        ※ map_location は "cpu" や device を指定可。
        """
        # PyTorch 2.6+ では weights_only 引数がある
        try:
            ckpt = torch.load(path, map_location=map_location, weights_only=False)
        except TypeError:
            # 古い PyTorch（weights_only 引数が無い）向け
            ckpt = torch.load(path, map_location=map_location)

        self.P_net.load_state_dict(ckpt["P_net"])
        self.Q_net1.load_state_dict(ckpt["Q_net1"])
        self.Q_net2.load_state_dict(ckpt["Q_net2"])
        self.P_target_net.load_state_dict(ckpt["P_target_net"])
        self.Q_target_net1.load_state_dict(ckpt["Q_target_net1"])
        self.Q_target_net2.load_state_dict(ckpt["Q_target_net2"])

        return ckpt.get("extra", None)
    
    def mode2eval(self):
        self.P_net.eval()
        self.Q_net1.eval()
        self.Q_net2.eval()

    def mode2train(self):
        self.P_net.train()
        self.Q_net1.train()
        self.Q_net2.train()

    @torch.no_grad()
    def soft_update(self, target_net, online_net, tau):
        """
        Polyak averaging:
          θ' ← (1-τ) θ' + τ θ
        """
        for target_param, online_param in zip(target_net.parameters(), online_net.parameters()):
            target_param.mul_(1.0-tau).add_(tau*online_param)

    def update_net(self, states, actions, rewards, states_next, dones=None):
        """
        1回の更新（Critic→Actor→Target soft update）
        戻り値： (q_loss, p_loss) のスカラー
        """
        # ---- minibatch を device 上 Tensor に統一 ----
        states = torch.as_tensor(states, dtype=torch.float32, device=self.device)
        actions = torch.as_tensor(actions, dtype=torch.float32, device=self.device)
        rewards = torch.as_tensor(rewards, dtype=torch.float32, device=self.device)
        states_next = torch.as_tensor(states_next, dtype=torch.float32, device=self.device)

        if rewards.dim() == 1:
            rewards = rewards.unsqueeze(1)
        
        if dones is None:
            dones = torch.zeros((states.shape[0],1), dtype=torch.float32, device=self.device)
        else:
            dones = torch.as_tensor(dones, dtype=torch.float32, device=self.device)
            if dones.dim() == 1:
                dones = dones.unsqueeze(1)
        
        with torch.no_grad():
            actions_next_for_target = self.P_target_net(states_next)
            actions_next_for_target += torch.clamp(
                torch.randn_like(actions_next_for_target) * self.Config.sig,
                -self.target_policy_noise_clip,
                self.target_policy_noise_clip,
            )
            Q_target1 = self.Q_target_net1(torch.cat([states_next,actions_next_for_target],dim=1))
            Q_target2 = self.Q_target_net2(torch.cat([states_next,actions_next_for_target],dim=1))
            y_targets = rewards + self.Config.gamma*(1-dones)*torch.min(Q_target1,Q_target2)

        Q_values1 = self.Q_net1(torch.cat([states,actions],dim=1))
        Q_values2 = self.Q_net2(torch.cat([states,actions],dim=1))
        Q_loss1 = F.mse_loss(y_targets,Q_values1)
        Q_loss2 = F.mse_loss(y_targets,Q_values2)
        self.Q_optim1.zero_grad()
        self.Q_optim2.zero_grad()
        Q_loss1.backward()
        Q_loss2.backward()
        self.Q_optim1.step()
        self.Q_optim2.step()

        # ---- Actor update ----
        # Actor 更新は一定頻度でのみ行う
        if self.actor_update_counter % self.policy_update_freq == 0:
            # Actor 更新では Q_net を通すが、Q_net自体は更新しないので凍結
            for p in self.Q_net1.parameters():
                p.requires_grad_(False)

            actions_for_Ploss = self.P_net(states)
            P_loss = -self.Q_net1(torch.cat([states,actions_for_Ploss],dim=1)).mean()
            self.P_optim.zero_grad()
            P_loss.backward()
            self.P_optim.step()

            for p in self.Q_net1.parameters():
                p.requires_grad_(True)

            # ---- Target net update ----
            self.soft_update(
                target_net=self.Q_target_net1,
                online_net=self.Q_net1,
                tau=self.Config.tau,
            )
            self.soft_update(
                target_net=self.Q_target_net2,
                online_net=self.Q_net2,
                tau=self.Config.tau,
            )
            self.soft_update(
                target_net=self.P_target_net,
                online_net=self.P_net,
                tau=self.Config.tau
            )
        else:
            P_loss = torch.tensor(0.0)  # Actor更新しなかった場合は0を返すようにしておく

        self.actor_update_counter += 1

        return float(Q_loss1.item()), float(Q_loss2.item()), float(P_loss.item())

# %%
def train(
    env,
    agent,
    buffer,
    total_step=40000,
    warmup_steps=1000,
    batch_num=512,
):
    print("cuda available:", torch.cuda.is_available())
    print("agent device:", agent.device)
    print("P_net device:", next(agent.P_net.parameters()).device)
    print("Q_net1 device:", next(agent.Q_net1.parameters()).device)
    print("Q_net2 device:", next(agent.Q_net2.parameters()).device)

    # ログ保存用リスト
    Q_loss1_history = []
    Q_loss2_history = []
    P_loss_history = []
    reward_history = []
    
    episode_num = 1
    reward_log = 0

    # 1) 環境を初期化して最初の観測を得る
    obs, info = env.reset()

    # 2) 環境ステップを total_step 回す
    for t in range(total_step):

        # logging.info("train step %d start", t)

        # 行動選択：warmupまではランダム行動
        if len(buffer) < warmup_steps:
            action = env.action_space.sample()
            # logging.info("warmup now")
        else:
            # TD3の方策；ノイズ入りの行動
            action = agent.step_with_noise(obs)
            # logging.info("training")

        # 3) 環境を1ステップ進める
        obs_next, reward, terminated, truncated, info = env.step(action)
        reward_log += reward

        # 4) “エピソード終了”判定（reset のため）
        done = float(terminated)

        # ---- (B) バッファに格納：学習ターゲット用の done は方針に注意 ----
        # 方針1（簡単）：done をそのまま入れる（truncatedでもブートストラップ停止）
        buffer.add(obs, action, reward, obs_next, done)

        # 方針2（理屈に忠実）：terminated を入れる（truncatedはブートストラップ継続）
        # buffer.add(obs, action, reward, obs_next, terminated)

        # 5) 次の観測へ更新（done なら reset）
        # doneはterminatedにしたので、ここではterminatedとtruncatedのorを使う
        if terminated or truncated:
            logging.info('train episode %d: reward = %.2f',
                            episode_num, reward_log)
            episode_num += 1
            obs, info = env.reset()
            reward_history.append(reward_log)
            reward_log = 0
        else:
            obs = obs_next

        # 6) バッファが十分でなければ学習をスキップ
        if len(buffer) < warmup_steps:
            continue

        # 7) ミニバッチを取り出して更新
        minibatch = buffer.sample(batch_num)
        states      = minibatch["obs"]
        actions     = minibatch["act"]
        rewards     = minibatch["rew"]
        states_next = minibatch["obs_next"]
        dones       = minibatch["done"]

        Q_loss1, Q_loss2, P_loss = agent.update_net(states, actions, rewards, states_next, dones)

        # 8) ログが欲しいならここで（毎step item() は遅くなるので間引くのが定石）
        if t % 100 == 0:
            Q_loss1_history.append(Q_loss1)
            Q_loss2_history.append(Q_loss2)
            P_loss_history.append(P_loss)

    return Q_loss1_history, Q_loss2_history, P_loss_history, reward_history

# %%
agent = TD3Agent(Config=Config(),device=device)
TD3ReplayBuffer = ReplayBuffer(obs_dim=3,act_dim=1,size=100000,device=device)
total_step = 350000
warmup_steps = 50000
batch_num = 2048

Qh1, Qh2,  Ph, rh = train(
    env=env,
    agent=agent,
    buffer=TD3ReplayBuffer,
    total_step=total_step,
    warmup_steps=warmup_steps,
    batch_num=batch_num
)
# Out:
# cuda available: True
# agent device: cuda
# P_net device: cuda:0
# Q_net1 device: cuda:0
# Q_net2 device: cuda:0
# 13:21:02 [INFO] train episode 1: reward = -901.91
# 13:21:02 [INFO] train episode 2: reward = -1296.12
# 13:21:02 [INFO] train episode 3: reward = -1172.58
# 13:21:02 [INFO] train episode 4: reward = -972.56
# 13:21:02 [INFO] train episode 5: reward = -1164.39
# 13:21:02 [INFO] train episode 6: reward = -915.60
# 13:21:02 [INFO] train episode 7: reward = -1245.62
# 13:21:02 [INFO] train episode 8: reward = -1170.60
# 13:21:02 [INFO] train episode 9: reward = -1707.38
# 13:21:02 [INFO] train episode 10: reward = -1068.00
# 13:21:02 [INFO] train episode 11: reward = -1066.14
# 13:21:02 [INFO] train episode 12: reward = -1603.65
# 13:21:02 [INFO] train episode 13: reward = -1269.07
# 13:21:02 [INFO] train episode 14: reward = -1437.97
# 13:21:02 [INFO] train episode 15: reward = -964.31
# 13:21:02 [INFO] train episode 16: reward = -1666.95
# 13:21:02 [INFO] train episode 17: reward = -1210.33
# 13:21:02 [INFO] train episode 18: reward = -1727.04
# 13:21:02 [INFO] train episode 19: reward = -774.92
# 13:21:02 [INFO] train episode 20: reward = -974.63
# 13:21:02 [INFO] train episode 21: reward = -833.24
# 13:21:02 [INFO] train episode 22: reward = -984.39
# 13:21:02 [INFO] train episode 23: reward = -1242.88
# 13:21:02 [INFO] train episode 24: reward = -1524.65
# 13:21:02 [INFO] train episode 25: reward = -1730.95
# 13:21:02 [INFO] train episode 26: reward = -1189.99
# 13:21:02 [INFO] train episode 27: reward = -886.58
# 13:21:02 [INFO] train episode 28: reward = -1813.31
# 13:21:02 [INFO] train episode 29: reward = -1334.13
# 13:21:02 [INFO] train episode 30: reward = -976.20
# 13:21:02 [INFO] train episode 31: reward = -1244.01
# 13:21:02 [INFO] train episode 32: reward = -1387.89
# 13:21:03 [INFO] train episode 33: reward = -1478.65
# 13:21:03 [INFO] train episode 34: reward = -1377.24
# 13:21:03 [INFO] train episode 35: reward = -790.79
# 13:21:03 [INFO] train episode 36: reward = -1155.97
# 13:21:03 [INFO] train episode 37: reward = -1305.71
# 13:21:03 [INFO] train episode 38: reward = -1438.38
# 13:21:03 [INFO] train episode 39: reward = -1678.42
# 13:21:03 [INFO] train episode 40: reward = -859.46
# 13:21:03 [INFO] train episode 41: reward = -1437.53
# 13:21:03 [INFO] train episode 42: reward = -1549.16
# 13:21:03 [INFO] train episode 43: reward = -1603.75
# 13:21:03 [INFO] train episode 44: reward = -966.79
# 13:21:03 [INFO] train episode 45: reward = -1175.03
# 13:21:03 [INFO] train episode 46: reward = -1255.57
# 13:21:03 [INFO] train episode 47: reward = -1479.82
# 13:21:03 [INFO] train episode 48: reward = -1189.78
# 13:21:03 [INFO] train episode 49: reward = -970.41
# 13:21:03 [INFO] train episode 50: reward = -1294.79
# 13:21:03 [INFO] train episode 51: reward = -890.26
# 13:21:03 [INFO] train episode 52: reward = -1153.72
# 13:21:03 [INFO] train episode 53: reward = -1362.28
# 13:21:03 [INFO] train episode 54: reward = -1668.66
# 13:21:03 [INFO] train episode 55: reward = -896.61
# 13:21:03 [INFO] train episode 56: reward = -1398.43
# 13:21:03 [INFO] train episode 57: reward = -1109.86
# 13:21:03 [INFO] train episode 58: reward = -1730.24
# 13:21:03 [INFO] train episode 59: reward = -1286.33
# 13:21:03 [INFO] train episode 60: reward = -1270.90
# 13:21:03 [INFO] train episode 61: reward = -986.31
# 13:21:03 [INFO] train episode 62: reward = -1622.14
# 13:21:03 [INFO] train episode 63: reward = -998.38
# 13:21:03 [INFO] train episode 64: reward = -1080.64
# 13:21:03 [INFO] train episode 65: reward = -1381.96
# 13:21:03 [INFO] train episode 66: reward = -763.64
# 13:21:03 [INFO] train episode 67: reward = -1815.55
# 13:21:03 [INFO] train episode 68: reward = -1207.28
# 13:21:03 [INFO] train episode 69: reward = -1155.72
# 13:21:03 [INFO] train episode 70: reward = -864.96
# 13:21:03 [INFO] train episode 71: reward = -776.20
# 13:21:03 [INFO] train episode 72: reward = -877.16
# 13:21:03 [INFO] train episode 73: reward = -1097.91
# 13:21:03 [INFO] train episode 74: reward = -1309.54
# 13:21:03 [INFO] train episode 75: reward = -1410.21
# 13:21:03 [INFO] train episode 76: reward = -1554.81
# 13:21:03 [INFO] train episode 77: reward = -1062.41
# 13:21:03 [INFO] train episode 78: reward = -1331.30
# 13:21:03 [INFO] train episode 79: reward = -1471.13
# 13:21:03 [INFO] train episode 80: reward = -1024.10
# 13:21:03 [INFO] train episode 81: reward = -1096.54
# 13:21:03 [INFO] train episode 82: reward = -862.25
# 13:21:03 [INFO] train episode 83: reward = -1425.89
# 13:21:03 [INFO] train episode 84: reward = -864.15
# 13:21:03 [INFO] train episode 85: reward = -1483.23
# 13:21:03 [INFO] train episode 86: reward = -775.89
# 13:21:03 [INFO] train episode 87: reward = -968.25
# 13:21:03 [INFO] train episode 88: reward = -1497.28
# 13:21:04 [INFO] train episode 89: reward = -1458.03
# 13:21:04 [INFO] train episode 90: reward = -754.05
# 13:21:04 [INFO] train episode 91: reward = -1378.61
# 13:21:04 [INFO] train episode 92: reward = -1806.80
# 13:21:04 [INFO] train episode 93: reward = -866.88
# 13:21:04 [INFO] train episode 94: reward = -1270.28
# 13:21:04 [INFO] train episode 95: reward = -1582.93
# 13:21:04 [INFO] train episode 96: reward = -1133.95
# 13:21:04 [INFO] train episode 97: reward = -1742.17
# 13:21:04 [INFO] train episode 98: reward = -823.64
# 13:21:04 [INFO] train episode 99: reward = -660.02
# 13:21:04 [INFO] train episode 100: reward = -1477.15
# 13:21:04 [INFO] train episode 101: reward = -901.45
# 13:21:04 [INFO] train episode 102: reward = -1015.09
# 13:21:04 [INFO] train episode 103: reward = -1585.49
# 13:21:04 [INFO] train episode 104: reward = -976.98
# 13:21:04 [INFO] train episode 105: reward = -1059.36
# 13:21:04 [INFO] train episode 106: reward = -858.20
# 13:21:04 [INFO] train episode 107: reward = -976.47
# 13:21:04 [INFO] train episode 108: reward = -1329.25
# 13:21:04 [INFO] train episode 109: reward = -1649.40
# 13:21:04 [INFO] train episode 110: reward = -992.66
# 13:21:04 [INFO] train episode 111: reward = -1274.64
# 13:21:04 [INFO] train episode 112: reward = -983.04
# 13:21:04 [INFO] train episode 113: reward = -1581.91
# 13:21:04 [INFO] train episode 114: reward = -1445.47
# 13:21:04 [INFO] train episode 115: reward = -1463.97
# 13:21:04 [INFO] train episode 116: reward = -1386.76
# 13:21:04 [INFO] train episode 117: reward = -1159.74
# 13:21:04 [INFO] train episode 118: reward = -1529.39
# 13:21:04 [INFO] train episode 119: reward = -1730.68
# 13:21:04 [INFO] train episode 120: reward = -1396.13
# 13:21:04 [INFO] train episode 121: reward = -1531.60
# 13:21:04 [INFO] train episode 122: reward = -969.79
# 13:21:04 [INFO] train episode 123: reward = -1335.56
# 13:21:04 [INFO] train episode 124: reward = -1606.16
# 13:21:04 [INFO] train episode 125: reward = -1720.68
# 13:21:04 [INFO] train episode 126: reward = -1703.39
# 13:21:04 [INFO] train episode 127: reward = -956.76
# 13:21:04 [INFO] train episode 128: reward = -1281.33
# 13:21:04 [INFO] train episode 129: reward = -1067.35
# 13:21:04 [INFO] train episode 130: reward = -986.50
# 13:21:04 [INFO] train episode 131: reward = -857.24
# 13:21:04 [INFO] train episode 132: reward = -1120.56
# 13:21:04 [INFO] train episode 133: reward = -1345.77
# 13:21:04 [INFO] train episode 134: reward = -824.10
# 13:21:04 [INFO] train episode 135: reward = -1643.08
# 13:21:04 [INFO] train episode 136: reward = -1209.55
# 13:21:04 [INFO] train episode 137: reward = -879.02
# 13:21:04 [INFO] train episode 138: reward = -895.08
# 13:21:04 [INFO] train episode 139: reward = -1432.18
# 13:21:04 [INFO] train episode 140: reward = -761.38
# 13:21:04 [INFO] train episode 141: reward = -1516.69
# 13:21:04 [INFO] train episode 142: reward = -910.37
# 13:21:05 [INFO] train episode 143: reward = -1213.92
# 13:21:05 [INFO] train episode 144: reward = -977.81
# 13:21:05 [INFO] train episode 145: reward = -1172.80
# 13:21:05 [INFO] train episode 146: reward = -1288.11
# 13:21:05 [INFO] train episode 147: reward = -1666.65
# 13:21:05 [INFO] train episode 148: reward = -1598.17
# 13:21:05 [INFO] train episode 149: reward = -1338.92
# 13:21:05 [INFO] train episode 150: reward = -1056.78
# 13:21:05 [INFO] train episode 151: reward = -1627.01
# 13:21:05 [INFO] train episode 152: reward = -1272.51
# 13:21:05 [INFO] train episode 153: reward = -1812.26
# 13:21:05 [INFO] train episode 154: reward = -887.67
# 13:21:05 [INFO] train episode 155: reward = -1305.03
# 13:21:05 [INFO] train episode 156: reward = -769.17
# 13:21:05 [INFO] train episode 157: reward = -1403.58
# 13:21:05 [INFO] train episode 158: reward = -883.33
# 13:21:05 [INFO] train episode 159: reward = -938.10
# 13:21:05 [INFO] train episode 160: reward = -938.63
# 13:21:05 [INFO] train episode 161: reward = -1216.92
# 13:21:05 [INFO] train episode 162: reward = -1824.39
# 13:21:05 [INFO] train episode 163: reward = -1453.11
# 13:21:05 [INFO] train episode 164: reward = -1179.79
# 13:21:05 [INFO] train episode 165: reward = -1177.18
# 13:21:05 [INFO] train episode 166: reward = -1799.68
# 13:21:05 [INFO] train episode 167: reward = -1351.96
# 13:21:05 [INFO] train episode 168: reward = -1146.45
# 13:21:05 [INFO] train episode 169: reward = -890.10
# 13:21:05 [INFO] train episode 170: reward = -1580.39
# 13:21:05 [INFO] train episode 171: reward = -988.58
# 13:21:05 [INFO] train episode 172: reward = -1001.01
# 13:21:05 [INFO] train episode 173: reward = -882.24
# 13:21:05 [INFO] train episode 174: reward = -1079.26
# 13:21:05 [INFO] train episode 175: reward = -852.46
# 13:21:05 [INFO] train episode 176: reward = -1750.35
# 13:21:05 [INFO] train episode 177: reward = -962.32
# 13:21:05 [INFO] train episode 178: reward = -1147.34
# 13:21:05 [INFO] train episode 179: reward = -1317.84
# 13:21:05 [INFO] train episode 180: reward = -1535.02
# 13:21:06 [INFO] train episode 181: reward = -1676.97
# 13:21:06 [INFO] train episode 182: reward = -1691.91
# 13:21:06 [INFO] train episode 183: reward = -1535.76
# 13:21:06 [INFO] train episode 184: reward = -1807.91
# 13:21:06 [INFO] train episode 185: reward = -1746.02
# 13:21:06 [INFO] train episode 186: reward = -1058.67
# 13:21:06 [INFO] train episode 187: reward = -894.04
# 13:21:06 [INFO] train episode 188: reward = -876.96
# 13:21:06 [INFO] train episode 189: reward = -1322.61
# 13:21:06 [INFO] train episode 190: reward = -1494.12
# 13:21:06 [INFO] train episode 191: reward = -1172.19
# 13:21:06 [INFO] train episode 192: reward = -1588.90
# 13:21:06 [INFO] train episode 193: reward = -1624.63
# 13:21:06 [INFO] train episode 194: reward = -1160.10
# 13:21:06 [INFO] train episode 195: reward = -1491.39
# 13:21:06 [INFO] train episode 196: reward = -1341.40
# 13:21:06 [INFO] train episode 197: reward = -977.51
# 13:21:06 [INFO] train episode 198: reward = -963.61
# 13:21:06 [INFO] train episode 199: reward = -862.82
# 13:21:06 [INFO] train episode 200: reward = -1196.86
# 13:21:06 [INFO] train episode 201: reward = -1427.80
# 13:21:06 [INFO] train episode 202: reward = -1676.32
# 13:21:06 [INFO] train episode 203: reward = -1183.16
# 13:21:06 [INFO] train episode 204: reward = -870.29
# 13:21:06 [INFO] train episode 205: reward = -1110.51
# 13:21:06 [INFO] train episode 206: reward = -974.24
# 13:21:06 [INFO] train episode 207: reward = -1588.02
# 13:21:06 [INFO] train episode 208: reward = -1259.87
# 13:21:06 [INFO] train episode 209: reward = -983.02
# 13:21:06 [INFO] train episode 210: reward = -1179.18
# 13:21:06 [INFO] train episode 211: reward = -1409.93
# 13:21:06 [INFO] train episode 212: reward = -962.90
# 13:21:06 [INFO] train episode 213: reward = -1286.00
# 13:21:06 [INFO] train episode 214: reward = -1177.57
# 13:21:06 [INFO] train episode 215: reward = -981.48
# 13:21:06 [INFO] train episode 216: reward = -866.41
# 13:21:06 [INFO] train episode 217: reward = -1528.14
# 13:21:06 [INFO] train episode 218: reward = -1081.67
# 13:21:06 [INFO] train episode 219: reward = -939.60
# 13:21:06 [INFO] train episode 220: reward = -850.35
# 13:21:06 [INFO] train episode 221: reward = -1455.01
# 13:21:06 [INFO] train episode 222: reward = -1374.57
# 13:21:06 [INFO] train episode 223: reward = -1583.21
# 13:21:06 [INFO] train episode 224: reward = -884.80
# 13:21:06 [INFO] train episode 225: reward = -874.35
# 13:21:06 [INFO] train episode 226: reward = -1463.82
# 13:21:06 [INFO] train episode 227: reward = -1756.12
# 13:21:06 [INFO] train episode 228: reward = -874.60
# 13:21:06 [INFO] train episode 229: reward = -887.61
# 13:21:06 [INFO] train episode 230: reward = -1561.27
# 13:21:06 [INFO] train episode 231: reward = -983.64
# 13:21:06 [INFO] train episode 232: reward = -1330.45
# 13:21:07 [INFO] train episode 233: reward = -1532.11
# 13:21:07 [INFO] train episode 234: reward = -1669.30
# 13:21:07 [INFO] train episode 235: reward = -992.13
# 13:21:07 [INFO] train episode 236: reward = -1533.58
# 13:21:07 [INFO] train episode 237: reward = -1171.23
# 13:21:07 [INFO] train episode 238: reward = -1359.37
# 13:21:07 [INFO] train episode 239: reward = -1129.44
# 13:21:07 [INFO] train episode 240: reward = -1068.33
# 13:21:07 [INFO] train episode 241: reward = -1156.04
# 13:21:07 [INFO] train episode 242: reward = -1071.90
# 13:21:07 [INFO] train episode 243: reward = -1611.86
# 13:21:07 [INFO] train episode 244: reward = -1576.41
# 13:21:07 [INFO] train episode 245: reward = -860.37
# 13:21:07 [INFO] train episode 246: reward = -1595.34
# 13:21:07 [INFO] train episode 247: reward = -1589.20
# 13:21:07 [INFO] train episode 248: reward = -1340.95
# 13:21:07 [INFO] train episode 249: reward = -1002.52
# 13:21:07 [INFO] train episode 250: reward = -943.82
# /tmp/ipykernel_1249038/2669543450.py:261: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/aten/src/ATen/native/Scalar.cpp:22.)
#   return float(Q_loss1.item()), float(Q_loss2.item()), float(P_loss.item())
# 13:21:10 [INFO] train episode 251: reward = -1517.27
# 13:21:12 [INFO] train episode 252: reward = -1458.95
# 13:21:14 [INFO] train episode 253: reward = -1568.14
# 13:21:17 [INFO] train episode 254: reward = -1563.91
# 13:21:19 [INFO] train episode 255: reward = -1497.67
# 13:21:21 [INFO] train episode 256: reward = -1781.85
# 13:21:23 [INFO] train episode 257: reward = -1609.88
# 13:21:23 [INFO] train episode 258: reward = -1595.95
# 13:21:26 [INFO] train episode 259: reward = -1386.77
# 13:21:28 [INFO] train episode 260: reward = -1542.47
# 13:21:30 [INFO] train episode 261: reward = -1298.50
# 13:21:32 [INFO] train episode 262: reward = -1372.44
# 13:21:34 [INFO] train episode 263: reward = -1393.17
# 13:21:36 [INFO] train episode 264: reward = -1145.64
# 13:21:39 [INFO] train episode 265: reward = -1088.36
# 13:21:41 [INFO] train episode 266: reward = -1516.83
# 13:21:43 [INFO] train episode 267: reward = -1060.28
# 13:21:46 [INFO] train episode 268: reward = -1120.55
# 13:21:48 [INFO] train episode 269: reward = -919.70
# 13:21:50 [INFO] train episode 270: reward = -881.17
# 13:21:53 [INFO] train episode 271: reward = -801.75
# 13:21:53 [INFO] train episode 272: reward = -827.55
# 13:21:55 [INFO] train episode 273: reward = -138.98
# 13:21:57 [INFO] train episode 274: reward = -738.76
# 13:21:59 [INFO] train episode 275: reward = -1501.89
# 13:22:01 [INFO] train episode 276: reward = -264.38
# 13:22:03 [INFO] train episode 277: reward = -139.94
# 13:22:05 [INFO] train episode 278: reward = -142.63
# 13:22:07 [INFO] train episode 279: reward = -324.59
# 13:22:09 [INFO] train episode 280: reward = -382.72
# 13:22:11 [INFO] train episode 281: reward = -512.78
# 13:22:13 [INFO] train episode 282: reward = -504.12
# 13:22:15 [INFO] train episode 283: reward = -640.65
# 13:22:17 [INFO] train episode 284: reward = -512.43
# 13:22:19 [INFO] train episode 285: reward = -569.31
# 13:22:21 [INFO] train episode 286: reward = -569.46
# 13:22:23 [INFO] train episode 287: reward = -274.26
# 13:22:24 [INFO] train episode 288: reward = -133.55
# 13:22:26 [INFO] train episode 289: reward = -392.03
# 13:22:28 [INFO] train episode 290: reward = -380.05
# 13:22:30 [INFO] train episode 291: reward = -264.77
# 13:22:32 [INFO] train episode 292: reward = -384.74
# 13:22:34 [INFO] train episode 293: reward = -493.30
# 13:22:36 [INFO] train episode 294: reward = -260.56
# 13:22:38 [INFO] train episode 295: reward = -605.73
# 13:22:40 [INFO] train episode 296: reward = -385.28
# 13:22:42 [INFO] train episode 297: reward = -506.54
# 13:22:44 [INFO] train episode 298: reward = -504.43
# 13:22:47 [INFO] train episode 299: reward = -501.90
# 13:22:49 [INFO] train episode 300: reward = -502.15
# 13:22:51 [INFO] train episode 301: reward = -507.96
# 13:22:53 [INFO] train episode 302: reward = -506.15
# 13:22:53 [INFO] train episode 303: reward = -506.40
# 13:22:55 [INFO] train episode 304: reward = -508.57
# 13:22:58 [INFO] train episode 305: reward = -504.38
# 13:23:00 [INFO] train episode 306: reward = -486.93
# 13:23:02 [INFO] train episode 307: reward = -490.62
# 13:23:04 [INFO] train episode 308: reward = -507.85
# 13:23:06 [INFO] train episode 309: reward = -508.36
# 13:23:09 [INFO] train episode 310: reward = -493.54
# 13:23:11 [INFO] train episode 311: reward = -387.86
# 13:23:13 [INFO] train episode 312: reward = -381.88
# 13:23:15 [INFO] train episode 313: reward = -391.64
# 13:23:17 [INFO] train episode 314: reward = -252.03
# 13:23:20 [INFO] train episode 315: reward = -267.61
# 13:23:22 [INFO] train episode 316: reward = -137.78
# 13:23:24 [INFO] train episode 317: reward = -145.34
# 13:23:25 [INFO] train episode 318: reward = -263.47
# 13:23:27 [INFO] train episode 319: reward = -22.17
# 13:23:29 [INFO] train episode 320: reward = -476.07
# 13:23:31 [INFO] train episode 321: reward = -247.40
# 13:23:34 [INFO] train episode 322: reward = -142.32
# 13:23:36 [INFO] train episode 323: reward = -264.34
# 13:23:38 [INFO] train episode 324: reward = -259.31
# 13:23:41 [INFO] train episode 325: reward = -133.77
# 13:23:43 [INFO] train episode 326: reward = -135.97
# 13:23:45 [INFO] train episode 327: reward = -135.39
# 13:23:48 [INFO] train episode 328: reward = -136.22
# 13:23:50 [INFO] train episode 329: reward = -245.70
# 13:23:52 [INFO] train episode 330: reward = -369.25
# 13:23:54 [INFO] train episode 331: reward = -17.81
# 13:23:54 [INFO] train episode 332: reward = -240.91
# 13:23:57 [INFO] train episode 333: reward = -450.81
# 13:23:59 [INFO] train episode 334: reward = -258.03
# 13:24:02 [INFO] train episode 335: reward = -259.33
# 13:24:03 [INFO] train episode 336: reward = -372.17
# 13:24:05 [INFO] train episode 337: reward = -139.99
# 13:24:07 [INFO] train episode 338: reward = -254.25
# 13:24:09 [INFO] train episode 339: reward = -252.98
# 13:24:11 [INFO] train episode 340: reward = -134.68
# 13:24:13 [INFO] train episode 341: reward = -373.81
# 13:24:15 [INFO] train episode 342: reward = -135.88
# 13:24:17 [INFO] train episode 343: reward = -261.07
# 13:24:19 [INFO] train episode 344: reward = -132.24
# 13:24:21 [INFO] train episode 345: reward = -357.49
# 13:24:23 [INFO] train episode 346: reward = -241.16
# 13:24:25 [INFO] train episode 347: reward = -133.98
# 13:24:26 [INFO] train episode 348: reward = -132.56
# 13:24:28 [INFO] train episode 349: reward = -398.86
# 13:24:30 [INFO] train episode 350: reward = -332.18
# 13:24:32 [INFO] train episode 351: reward = -132.62
# 13:24:33 [INFO] train episode 352: reward = -252.60
# 13:24:35 [INFO] train episode 353: reward = -251.00
# 13:24:38 [INFO] train episode 354: reward = -366.30
# 13:24:40 [INFO] train episode 355: reward = -254.02
# 13:24:42 [INFO] train episode 356: reward = -236.40
# 13:24:44 [INFO] train episode 357: reward = -137.67
# 13:24:46 [INFO] train episode 358: reward = -358.30
# 13:24:49 [INFO] train episode 359: reward = -320.95
# 13:24:51 [INFO] train episode 360: reward = -348.24
# 13:24:53 [INFO] train episode 361: reward = -354.28
# 13:24:55 [INFO] train episode 362: reward = -370.33
# 13:24:55 [INFO] train episode 363: reward = -250.56
# 13:24:57 [INFO] train episode 364: reward = -127.31
# 13:25:00 [INFO] train episode 365: reward = -253.11
# 13:25:02 [INFO] train episode 366: reward = -7.70
# 13:25:04 [INFO] train episode 367: reward = -124.22
# 13:25:06 [INFO] train episode 368: reward = -350.00
# 13:25:09 [INFO] train episode 369: reward = -133.25
# 13:25:11 [INFO] train episode 370: reward = -132.67
# 13:25:13 [INFO] train episode 371: reward = -123.92
# 13:25:16 [INFO] train episode 372: reward = -132.59
# 13:25:18 [INFO] train episode 373: reward = -246.24
# 13:25:20 [INFO] train episode 374: reward = -256.41
# 13:25:22 [INFO] train episode 375: reward = -330.74
# 13:25:24 [INFO] train episode 376: reward = -124.51
# 13:25:26 [INFO] train episode 377: reward = -445.94
# 13:25:26 [INFO] train episode 378: reward = -249.92
# 13:25:28 [INFO] train episode 379: reward = -230.17
# 13:25:30 [INFO] train episode 380: reward = -119.99
# 13:25:32 [INFO] train episode 381: reward = -128.42
# 13:25:34 [INFO] train episode 382: reward = -120.75
# 13:25:36 [INFO] train episode 383: reward = -123.43
# 13:25:39 [INFO] train episode 384: reward = -121.71
# 13:25:41 [INFO] train episode 385: reward = -124.09
# 13:25:44 [INFO] train episode 386: reward = -125.42
# 13:25:46 [INFO] train episode 387: reward = -132.07
# 13:25:49 [INFO] train episode 388: reward = -125.66
# 13:25:51 [INFO] train episode 389: reward = -238.27
# 13:25:53 [INFO] train episode 390: reward = -129.47
# 13:25:56 [INFO] train episode 391: reward = -254.97
# 13:25:58 [INFO] train episode 392: reward = -251.83
# 13:26:00 [INFO] train episode 393: reward = -124.72
# 13:26:03 [INFO] train episode 394: reward = -127.79
# 13:26:05 [INFO] train episode 395: reward = -132.87
# 13:26:07 [INFO] train episode 396: reward = -123.52
# 13:26:09 [INFO] train episode 397: reward = -238.28
# 13:26:11 [INFO] train episode 398: reward = -126.32
# 13:26:11 [INFO] train episode 399: reward = -128.13
# 13:26:13 [INFO] train episode 400: reward = -132.26
# 13:26:15 [INFO] train episode 401: reward = -362.93
# 13:26:17 [INFO] train episode 402: reward = -130.84
# 13:26:19 [INFO] train episode 403: reward = -367.75
# 13:26:21 [INFO] train episode 404: reward = -130.30
# 13:26:23 [INFO] train episode 405: reward = -131.76
# 13:26:25 [INFO] train episode 406: reward = -368.40
# 13:26:27 [INFO] train episode 407: reward = -233.26
# 13:26:29 [INFO] train episode 408: reward = -131.58
# 13:26:31 [INFO] train episode 409: reward = -246.70
# 13:26:33 [INFO] train episode 410: reward = -247.19
# 13:26:35 [INFO] train episode 411: reward = -354.48
# 13:26:37 [INFO] train episode 412: reward = -238.48
# 13:26:39 [INFO] train episode 413: reward = -126.68
# 13:26:42 [INFO] train episode 414: reward = -132.84
# 13:26:42 [INFO] train episode 415: reward = -20.38
# 13:26:44 [INFO] train episode 416: reward = -135.20
# 13:26:46 [INFO] train episode 417: reward = -130.01
# 13:26:49 [INFO] train episode 418: reward = -138.84
# 13:26:51 [INFO] train episode 419: reward = -126.10
# 13:26:53 [INFO] train episode 420: reward = -255.54
# 13:26:55 [INFO] train episode 421: reward = -359.41
# 13:26:58 [INFO] train episode 422: reward = -11.25
# 13:27:00 [INFO] train episode 423: reward = -19.39
# 13:27:02 [INFO] train episode 424: reward = -130.37
# 13:27:05 [INFO] train episode 425: reward = -247.89
# 13:27:07 [INFO] train episode 426: reward = -366.77
# 13:27:09 [INFO] train episode 427: reward = -246.92
# 13:27:11 [INFO] train episode 428: reward = -338.62
# 13:27:11 [INFO] train episode 429: reward = -237.65
# 13:27:13 [INFO] train episode 430: reward = -374.14
# 13:27:15 [INFO] train episode 431: reward = -133.52
# 13:27:18 [INFO] train episode 432: reward = -247.02
# 13:27:20 [INFO] train episode 433: reward = -128.88
# 13:27:22 [INFO] train episode 434: reward = -371.76
# 13:27:24 [INFO] train episode 435: reward = -137.02
# 13:27:27 [INFO] train episode 436: reward = -18.12
# 13:27:29 [INFO] train episode 437: reward = -15.14
# 13:27:31 [INFO] train episode 438: reward = -15.01
# 13:27:34 [INFO] train episode 439: reward = -14.45
# 13:27:36 [INFO] train episode 440: reward = -304.86
# 13:27:38 [INFO] train episode 441: reward = -130.49
# 13:27:41 [INFO] train episode 442: reward = -132.64
# 13:27:43 [INFO] train episode 443: reward = -137.63
# 13:27:45 [INFO] train episode 444: reward = -130.29
# 13:27:47 [INFO] train episode 445: reward = -241.03
# 13:27:49 [INFO] train episode 446: reward = -129.80
# 13:27:51 [INFO] train episode 447: reward = -255.61
# 13:27:53 [INFO] train episode 448: reward = -249.12
# 13:27:55 [INFO] train episode 449: reward = -362.81
# 13:27:57 [INFO] train episode 450: reward = -125.46
# 13:27:57 [INFO] train episode 451: reward = -134.60
# 13:27:59 [INFO] train episode 452: reward = -140.53
# 13:28:01 [INFO] train episode 453: reward = -131.60
# 13:28:03 [INFO] train episode 454: reward = -250.90
# 13:28:05 [INFO] train episode 455: reward = -246.72
# 13:28:07 [INFO] train episode 456: reward = -132.01
# 13:28:09 [INFO] train episode 457: reward = -119.77
# 13:28:11 [INFO] train episode 458: reward = -121.21
# 13:28:13 [INFO] train episode 459: reward = -229.87
# 13:28:16 [INFO] train episode 460: reward = -256.30
# 13:28:18 [INFO] train episode 461: reward = -378.77
# 13:28:21 [INFO] train episode 462: reward = -123.07
# 13:28:23 [INFO] train episode 463: reward = -122.48
# 13:28:27 [INFO] train episode 464: reward = -122.26
# 13:28:31 [INFO] train episode 465: reward = -131.53
# 13:28:36 [INFO] train episode 466: reward = -242.06
# 13:28:40 [INFO] train episode 467: reward = -123.74
# 13:28:43 [INFO] train episode 468: reward = -347.33
# 13:28:46 [INFO] train episode 469: reward = -136.99
# 13:28:49 [INFO] train episode 470: reward = -125.72
# 13:28:51 [INFO] train episode 471: reward = -123.37
# 13:28:54 [INFO] train episode 472: reward = -123.12
# 13:28:56 [INFO] train episode 473: reward = -250.58
# 13:29:00 [INFO] train episode 474: reward = -1.22
# 13:29:01 [INFO] train episode 475: reward = -369.35
# 13:29:03 [INFO] train episode 476: reward = -19.51
# 13:29:05 [INFO] train episode 477: reward = -120.37
# 13:29:07 [INFO] train episode 478: reward = -244.92
# 13:29:10 [INFO] train episode 479: reward = -125.06
# 13:29:12 [INFO] train episode 480: reward = -231.22
# 13:29:14 [INFO] train episode 481: reward = -251.91
# 13:29:16 [INFO] train episode 482: reward = -365.83
# 13:29:18 [INFO] train episode 483: reward = -347.15
# 13:29:21 [INFO] train episode 484: reward = -242.68
# 13:29:23 [INFO] train episode 485: reward = -261.47
# 13:29:25 [INFO] train episode 486: reward = -233.80
# 13:29:28 [INFO] train episode 487: reward = -243.34
# 13:29:30 [INFO] train episode 488: reward = -245.86
# 13:29:30 [INFO] train episode 489: reward = -140.03
# 13:29:32 [INFO] train episode 490: reward = -118.17
# 13:29:34 [INFO] train episode 491: reward = -378.84
# 13:29:36 [INFO] train episode 492: reward = -124.71
# 13:29:38 [INFO] train episode 493: reward = -138.03
# 13:29:40 [INFO] train episode 494: reward = -123.01
# 13:29:42 [INFO] train episode 495: reward = -119.23
# 13:29:45 [INFO] train episode 496: reward = -139.80
# 13:29:47 [INFO] train episode 497: reward = -128.46
# 13:29:50 [INFO] train episode 498: reward = -123.88
# 13:29:52 [INFO] train episode 499: reward = -0.21
# 13:29:54 [INFO] train episode 500: reward = -131.65
# 13:29:56 [INFO] train episode 501: reward = -249.51
# 13:29:59 [INFO] train episode 502: reward = -255.05
# 13:30:01 [INFO] train episode 503: reward = -393.24
# 13:30:01 [INFO] train episode 504: reward = -362.21
# 13:30:04 [INFO] train episode 505: reward = -134.25
# 13:30:06 [INFO] train episode 506: reward = -123.41
# 13:30:08 [INFO] train episode 507: reward = -237.58
# 13:30:10 [INFO] train episode 508: reward = -122.34
# 13:30:12 [INFO] train episode 509: reward = -378.30
# 13:30:15 [INFO] train episode 510: reward = -361.92
# 13:30:17 [INFO] train episode 511: reward = -131.07
# 13:30:19 [INFO] train episode 512: reward = -240.66
# 13:30:21 [INFO] train episode 513: reward = -490.62
# 13:30:23 [INFO] train episode 514: reward = -127.26
# 13:30:25 [INFO] train episode 515: reward = -119.14
# 13:30:27 [INFO] train episode 516: reward = -244.43
# 13:30:29 [INFO] train episode 517: reward = -126.14
# 13:30:30 [INFO] train episode 518: reward = -131.02
# 13:30:32 [INFO] train episode 519: reward = -133.91
# 13:30:34 [INFO] train episode 520: reward = -0.91
# 13:30:36 [INFO] train episode 521: reward = -256.92
# 13:30:38 [INFO] train episode 522: reward = -0.35
# 13:30:40 [INFO] train episode 523: reward = -441.94
# 13:30:42 [INFO] train episode 524: reward = -127.30
# 13:30:45 [INFO] train episode 525: reward = -245.92
# 13:30:47 [INFO] train episode 526: reward = -239.26
# 13:30:49 [INFO] train episode 527: reward = -128.87
# 13:30:51 [INFO] train episode 528: reward = -127.11
# 13:30:54 [INFO] train episode 529: reward = -363.61
# 13:30:56 [INFO] train episode 530: reward = -124.96
# 13:30:58 [INFO] train episode 531: reward = -253.71
# 13:31:00 [INFO] train episode 532: reward = -358.02
# 13:31:01 [INFO] train episode 533: reward = -366.12
# 13:31:03 [INFO] train episode 534: reward = -254.65
# 13:31:05 [INFO] train episode 535: reward = -365.96
# 13:31:07 [INFO] train episode 536: reward = -375.13
# 13:31:09 [INFO] train episode 537: reward = -380.52
# 13:31:12 [INFO] train episode 538: reward = -0.09
# 13:31:14 [INFO] train episode 539: reward = -503.96
# 13:31:16 [INFO] train episode 540: reward = -240.20
# 13:31:19 [INFO] train episode 541: reward = -383.16
# 13:31:21 [INFO] train episode 542: reward = -129.33
# 13:31:24 [INFO] train episode 543: reward = -247.28
# 13:31:26 [INFO] train episode 544: reward = -376.00
# 13:31:29 [INFO] train episode 545: reward = -351.84
# 13:31:31 [INFO] train episode 546: reward = -236.36
# 13:31:31 [INFO] train episode 547: reward = -383.78
# 13:31:33 [INFO] train episode 548: reward = -254.63
# 13:31:36 [INFO] train episode 549: reward = -497.83
# 13:31:38 [INFO] train episode 550: reward = -127.32
# 13:31:40 [INFO] train episode 551: reward = -0.36
# 13:31:43 [INFO] train episode 552: reward = -247.37
# 13:31:45 [INFO] train episode 553: reward = -372.77
# 13:31:47 [INFO] train episode 554: reward = -367.00
# 13:31:49 [INFO] train episode 555: reward = -377.60
# 13:31:52 [INFO] train episode 556: reward = -121.51
# 13:31:54 [INFO] train episode 557: reward = -502.31
# 13:31:56 [INFO] train episode 558: reward = -254.72
# 13:31:58 [INFO] train episode 559: reward = -243.46
# 13:32:01 [INFO] train episode 560: reward = -257.00
# 13:32:01 [INFO] train episode 561: reward = -506.54
# 13:32:03 [INFO] train episode 562: reward = -608.72
# 13:32:05 [INFO] train episode 563: reward = -504.56
# 13:32:07 [INFO] train episode 564: reward = -383.77
# 13:32:09 [INFO] train episode 565: reward = -642.09
# 13:32:11 [INFO] train episode 566: reward = -358.99
# 13:32:13 [INFO] train episode 567: reward = -356.10
# 13:32:15 [INFO] train episode 568: reward = -248.33
# 13:32:17 [INFO] train episode 569: reward = -502.30
# 13:32:19 [INFO] train episode 570: reward = -374.52
# 13:32:22 [INFO] train episode 571: reward = -253.97
# 13:32:24 [INFO] train episode 572: reward = -342.65
# 13:32:26 [INFO] train episode 573: reward = -380.25
# 13:32:28 [INFO] train episode 574: reward = -387.53
# 13:32:30 [INFO] train episode 575: reward = -493.00
# 13:32:32 [INFO] train episode 576: reward = -373.89
# 13:32:32 [INFO] train episode 577: reward = -386.18
# 13:32:34 [INFO] train episode 578: reward = -486.96
# 13:32:36 [INFO] train episode 579: reward = -244.70
# 13:32:38 [INFO] train episode 580: reward = -248.13
# 13:32:40 [INFO] train episode 581: reward = -129.63
# 13:32:42 [INFO] train episode 582: reward = -260.71
# 13:32:44 [INFO] train episode 583: reward = -260.29
# 13:32:47 [INFO] train episode 584: reward = -253.13
# 13:32:49 [INFO] train episode 585: reward = -127.75
# 13:32:51 [INFO] train episode 586: reward = -377.36
# 13:32:53 [INFO] train episode 587: reward = -396.72
# 13:32:56 [INFO] train episode 588: reward = -253.82
# 13:32:58 [INFO] train episode 589: reward = -377.39
# 13:33:00 [INFO] train episode 590: reward = -377.66
# 13:33:02 [INFO] train episode 591: reward = -436.80
# 13:33:03 [INFO] train episode 592: reward = -519.10
# 13:33:05 [INFO] train episode 593: reward = -247.60
# 13:33:07 [INFO] train episode 594: reward = -490.24
# 13:33:10 [INFO] train episode 595: reward = -129.07
# 13:33:12 [INFO] train episode 596: reward = -129.68
# 13:33:14 [INFO] train episode 597: reward = -262.42
# 13:33:16 [INFO] train episode 598: reward = -386.14
# 13:33:18 [INFO] train episode 599: reward = -12.42
# 13:33:20 [INFO] train episode 600: reward = -378.62
# 13:33:22 [INFO] train episode 601: reward = -247.34
# 13:33:24 [INFO] train episode 602: reward = -123.32
# 13:33:26 [INFO] train episode 603: reward = -495.01
# 13:33:28 [INFO] train episode 604: reward = -488.42
# 13:33:31 [INFO] train episode 605: reward = -134.76
# 13:33:33 [INFO] train episode 606: reward = -132.46
# 13:33:33 [INFO] train episode 607: reward = -373.27
# 13:33:35 [INFO] train episode 608: reward = -255.20
# 13:33:37 [INFO] train episode 609: reward = -246.65
# 13:33:39 [INFO] train episode 610: reward = -377.68
# 13:33:41 [INFO] train episode 611: reward = -7.19
# 13:33:44 [INFO] train episode 612: reward = -246.46
# 13:33:46 [INFO] train episode 613: reward = -251.40
# 13:33:48 [INFO] train episode 614: reward = -7.26
# 13:33:50 [INFO] train episode 615: reward = -380.16
# 13:33:53 [INFO] train episode 616: reward = -123.09
# 13:33:55 [INFO] train episode 617: reward = -129.84
# 13:33:57 [INFO] train episode 618: reward = -368.84
# 13:33:59 [INFO] train episode 619: reward = -252.93
# 13:34:02 [INFO] train episode 620: reward = -372.46
# 13:34:02 [INFO] train episode 621: reward = -257.43
# 13:34:04 [INFO] train episode 622: reward = -257.52
# 13:34:07 [INFO] train episode 623: reward = -243.55
# 13:34:09 [INFO] train episode 624: reward = -1.79
# 13:34:11 [INFO] train episode 625: reward = -375.91
# 13:34:14 [INFO] train episode 626: reward = -256.72
# 13:34:15 [INFO] train episode 627: reward = -376.65
# 13:34:18 [INFO] train episode 628: reward = -256.14
# 13:34:20 [INFO] train episode 629: reward = -253.64
# 13:34:22 [INFO] train episode 630: reward = -374.60
# 13:34:24 [INFO] train episode 631: reward = -445.53
# 13:34:26 [INFO] train episode 632: reward = -129.41
# 13:34:28 [INFO] train episode 633: reward = -129.26
# 13:34:30 [INFO] train episode 634: reward = -120.23
# 13:34:32 [INFO] train episode 635: reward = -255.24
# 13:34:32 [INFO] train episode 636: reward = -355.53
# 13:34:33 [INFO] train episode 637: reward = -490.43
# 13:34:35 [INFO] train episode 638: reward = -242.89
# 13:34:37 [INFO] train episode 639: reward = -251.05
# 13:34:40 [INFO] train episode 640: reward = -257.45
# 13:34:42 [INFO] train episode 641: reward = -358.56
# 13:34:44 [INFO] train episode 642: reward = -504.67
# 13:34:46 [INFO] train episode 643: reward = -249.98
# 13:34:48 [INFO] train episode 644: reward = -381.02
# 13:34:51 [INFO] train episode 645: reward = -364.82
# 13:34:53 [INFO] train episode 646: reward = -361.79
# 13:34:55 [INFO] train episode 647: reward = -255.71
# 13:34:57 [INFO] train episode 648: reward = -132.33
# 13:35:00 [INFO] train episode 649: reward = -243.06
# 13:35:02 [INFO] train episode 650: reward = -130.70
# 13:35:02 [INFO] train episode 651: reward = -241.36
# 13:35:04 [INFO] train episode 652: reward = -353.75
# 13:35:07 [INFO] train episode 653: reward = -129.27
# 13:35:09 [INFO] train episode 654: reward = -260.57
# 13:35:11 [INFO] train episode 655: reward = -472.72
# 13:35:14 [INFO] train episode 656: reward = -131.03
# 13:35:16 [INFO] train episode 657: reward = -490.20
# 13:35:19 [INFO] train episode 658: reward = -125.44
# 13:35:21 [INFO] train episode 659: reward = -492.74
# 13:35:24 [INFO] train episode 660: reward = -247.97
# 13:35:26 [INFO] train episode 661: reward = -126.02
# 13:35:28 [INFO] train episode 662: reward = -123.93
# 13:35:31 [INFO] train episode 663: reward = -366.13
# 13:35:33 [INFO] train episode 664: reward = -261.16
# 13:35:34 [INFO] train episode 665: reward = -247.44
# 13:35:36 [INFO] train episode 666: reward = -235.09
# 13:35:38 [INFO] train episode 667: reward = -125.96
# 13:35:40 [INFO] train episode 668: reward = -492.85
# 13:35:43 [INFO] train episode 669: reward = -239.81
# 13:35:45 [INFO] train episode 670: reward = -383.89
# 13:35:48 [INFO] train episode 671: reward = -254.33
# 13:35:50 [INFO] train episode 672: reward = -241.25
# 13:35:52 [INFO] train episode 673: reward = -255.60
# 13:35:54 [INFO] train episode 674: reward = -128.54
# 13:35:57 [INFO] train episode 675: reward = -3.54
# 13:35:59 [INFO] train episode 676: reward = -258.32
# 13:36:01 [INFO] train episode 677: reward = -129.77
# 13:36:02 [INFO] train episode 678: reward = -247.80
# 13:36:05 [INFO] train episode 679: reward = -132.07
# 13:36:08 [INFO] train episode 680: reward = -130.22
# 13:36:10 [INFO] train episode 681: reward = -4.62
# 13:36:12 [INFO] train episode 682: reward = -134.61
# 13:36:14 [INFO] train episode 683: reward = -130.63
# 13:36:16 [INFO] train episode 684: reward = -131.02
# 13:36:18 [INFO] train episode 685: reward = -237.93
# 13:36:20 [INFO] train episode 686: reward = -518.19
# 13:36:23 [INFO] train episode 687: reward = -256.75
# 13:36:25 [INFO] train episode 688: reward = -253.68
# 13:36:27 [INFO] train episode 689: reward = -262.34
# 13:36:29 [INFO] train episode 690: reward = -501.49
# 13:36:31 [INFO] train episode 691: reward = -260.23
# 13:36:33 [INFO] train episode 692: reward = -699.49
# 13:36:33 [INFO] train episode 693: reward = -249.87
# 13:36:35 [INFO] train episode 694: reward = -372.98
# 13:36:37 [INFO] train episode 695: reward = -254.60
# 13:36:39 [INFO] train episode 696: reward = -364.39
# 13:36:41 [INFO] train episode 697: reward = -128.35
# 13:36:44 [INFO] train episode 698: reward = -497.40
# 13:36:46 [INFO] train episode 699: reward = -259.05
# 13:36:48 [INFO] train episode 700: reward = -339.05
# 13:36:51 [INFO] train episode 701: reward = -628.01
# 13:36:53 [INFO] train episode 702: reward = -263.14
# 13:36:55 [INFO] train episode 703: reward = -4.48
# 13:36:58 [INFO] train episode 704: reward = -384.81
# 13:37:00 [INFO] train episode 705: reward = -252.46
# 13:37:03 [INFO] train episode 706: reward = -521.72
# 13:37:03 [INFO] train episode 707: reward = -489.19
# 13:37:06 [INFO] train episode 708: reward = -376.41
# 13:37:08 [INFO] train episode 709: reward = -495.56
# 13:37:11 [INFO] train episode 710: reward = -4.98
# 13:37:13 [INFO] train episode 711: reward = -379.66
# 13:37:16 [INFO] train episode 712: reward = -388.94
# 13:37:18 [INFO] train episode 713: reward = -247.09
# 13:37:21 [INFO] train episode 714: reward = -252.18
# 13:37:23 [INFO] train episode 715: reward = -256.89
# 13:37:26 [INFO] train episode 716: reward = -253.49
# 13:37:28 [INFO] train episode 717: reward = -249.61
# 13:37:31 [INFO] train episode 718: reward = -623.54
# 13:37:33 [INFO] train episode 719: reward = -391.53
# 13:37:33 [INFO] train episode 720: reward = -382.94
# 13:37:36 [INFO] train episode 721: reward = -622.23
# 13:37:39 [INFO] train episode 722: reward = -516.78
# 13:37:41 [INFO] train episode 723: reward = -500.75
# 13:37:43 [INFO] train episode 724: reward = -384.79
# 13:37:46 [INFO] train episode 725: reward = -250.29
# 13:37:48 [INFO] train episode 726: reward = -501.00
# 13:37:50 [INFO] train episode 727: reward = -266.07
# 13:37:52 [INFO] train episode 728: reward = -2.84
# 13:37:55 [INFO] train episode 729: reward = -19.05
# 13:37:57 [INFO] train episode 730: reward = -267.85
# 13:37:59 [INFO] train episode 731: reward = -253.27
# 13:38:02 [INFO] train episode 732: reward = -267.07
# 13:38:04 [INFO] train episode 733: reward = -2.84
# 13:38:04 [INFO] train episode 734: reward = -128.48
# 13:38:06 [INFO] train episode 735: reward = -509.97
# 13:38:08 [INFO] train episode 736: reward = -127.62
# 13:38:10 [INFO] train episode 737: reward = -257.78
# 13:38:13 [INFO] train episode 738: reward = -362.84
# 13:38:15 [INFO] train episode 739: reward = -502.49
# 13:38:17 [INFO] train episode 740: reward = -257.67
# 13:38:19 [INFO] train episode 741: reward = -381.60
# 13:38:22 [INFO] train episode 742: reward = -512.83
# 13:38:24 [INFO] train episode 743: reward = -186.01
# 13:38:26 [INFO] train episode 744: reward = -379.09
# 13:38:28 [INFO] train episode 745: reward = -509.53
# 13:38:31 [INFO] train episode 746: reward = -358.93
# 13:38:33 [INFO] train episode 747: reward = -151.00
# 13:38:33 [INFO] train episode 748: reward = -250.84
# 13:38:35 [INFO] train episode 749: reward = -145.15
# 13:38:37 [INFO] train episode 750: reward = -388.52
# 13:38:40 [INFO] train episode 751: reward = -256.61
# 13:38:42 [INFO] train episode 752: reward = -261.15
# 13:38:44 [INFO] train episode 753: reward = -131.60
# 13:38:47 [INFO] train episode 754: reward = -363.37
# 13:38:49 [INFO] train episode 755: reward = -509.54
# 13:38:51 [INFO] train episode 756: reward = -255.46
# 13:38:54 [INFO] train episode 757: reward = -401.65
# 13:38:56 [INFO] train episode 758: reward = -259.51
# 13:38:58 [INFO] train episode 759: reward = -247.53
# 13:39:00 [INFO] train episode 760: reward = -258.91
# 13:39:03 [INFO] train episode 761: reward = -500.38
# 13:39:03 [INFO] train episode 762: reward = -364.42
# 13:39:05 [INFO] train episode 763: reward = -369.04
# 13:39:08 [INFO] train episode 764: reward = -508.92
# 13:39:10 [INFO] train episode 765: reward = -381.12
# 13:39:13 [INFO] train episode 766: reward = -145.19
# 13:39:15 [INFO] train episode 767: reward = -259.95
# 13:39:17 [INFO] train episode 768: reward = -250.89
# 13:39:19 [INFO] train episode 769: reward = -256.19
# 13:39:21 [INFO] train episode 770: reward = -2.43
# 13:39:24 [INFO] train episode 771: reward = -380.43
# 13:39:26 [INFO] train episode 772: reward = -142.16
# 13:39:28 [INFO] train episode 773: reward = -124.43
# 13:39:30 [INFO] train episode 774: reward = -265.84
# 13:39:33 [INFO] train episode 775: reward = -270.75
# 13:39:35 [INFO] train episode 776: reward = -127.89
# 13:39:35 [INFO] train episode 777: reward = -360.64
# 13:39:37 [INFO] train episode 778: reward = -381.78
# 13:39:39 [INFO] train episode 779: reward = -25.49
# 13:39:42 [INFO] train episode 780: reward = -252.34
# 13:39:44 [INFO] train episode 781: reward = -122.79
# 13:39:46 [INFO] train episode 782: reward = -372.51
# 13:39:49 [INFO] train episode 783: reward = -256.64
# 13:39:51 [INFO] train episode 784: reward = -256.42
# 13:39:53 [INFO] train episode 785: reward = -366.90
# 13:39:56 [INFO] train episode 786: reward = -387.22
# 13:39:58 [INFO] train episode 787: reward = -528.23
# 13:40:00 [INFO] train episode 788: reward = -262.11
# 13:40:02 [INFO] train episode 789: reward = -479.58
# 13:40:05 [INFO] train episode 790: reward = -131.46
# 13:40:05 [INFO] train episode 791: reward = -374.16
# 13:40:07 [INFO] train episode 792: reward = -144.57
# 13:40:09 [INFO] train episode 793: reward = -247.57
# 13:40:12 [INFO] train episode 794: reward = -400.06
# 13:40:14 [INFO] train episode 795: reward = -20.01
# 13:40:16 [INFO] train episode 796: reward = -245.63
# 13:40:18 [INFO] train episode 797: reward = -125.98
# 13:40:21 [INFO] train episode 798: reward = -370.27
# 13:40:23 [INFO] train episode 799: reward = -126.68
# 13:40:25 [INFO] train episode 800: reward = -129.46
# 13:40:27 [INFO] train episode 801: reward = -245.94
# 13:40:29 [INFO] train episode 802: reward = -6.18
# 13:40:32 [INFO] train episode 803: reward = -376.08
# 13:40:34 [INFO] train episode 804: reward = -264.74
# 13:40:34 [INFO] train episode 805: reward = -129.32
# 13:40:36 [INFO] train episode 806: reward = -144.69
# 13:40:38 [INFO] train episode 807: reward = -118.72
# 13:40:40 [INFO] train episode 808: reward = -126.99
# 13:40:43 [INFO] train episode 809: reward = -129.91
# 13:40:45 [INFO] train episode 810: reward = -255.28
# 13:40:47 [INFO] train episode 811: reward = -246.70
# 13:40:50 [INFO] train episode 812: reward = -130.65
# 13:40:52 [INFO] train episode 813: reward = -129.76
# 13:40:54 [INFO] train episode 814: reward = -6.53
# 13:40:57 [INFO] train episode 815: reward = -132.38
# 13:40:59 [INFO] train episode 816: reward = -241.21
# 13:41:01 [INFO] train episode 817: reward = -244.21
# 13:41:03 [INFO] train episode 818: reward = -121.80
# 13:41:05 [INFO] train episode 819: reward = -123.25
# 13:41:05 [INFO] train episode 820: reward = -146.74
# 13:41:07 [INFO] train episode 821: reward = -123.59
# 13:41:09 [INFO] train episode 822: reward = -127.48
# 13:41:11 [INFO] train episode 823: reward = -259.99
# 13:41:13 [INFO] train episode 824: reward = -5.04
# 13:41:15 [INFO] train episode 825: reward = -393.99
# 13:41:17 [INFO] train episode 826: reward = -457.53
# 13:41:20 [INFO] train episode 827: reward = -123.76
# 13:41:22 [INFO] train episode 828: reward = -243.82
# 13:41:24 [INFO] train episode 829: reward = -250.67
# 13:41:26 [INFO] train episode 830: reward = -353.50
# 13:41:28 [INFO] train episode 831: reward = -126.17
# 13:41:31 [INFO] train episode 832: reward = -126.58
# 13:41:33 [INFO] train episode 833: reward = -222.53
# 13:41:35 [INFO] train episode 834: reward = -5.16
# 13:41:35 [INFO] train episode 835: reward = -4.69
# 13:41:37 [INFO] train episode 836: reward = -124.52
# 13:41:39 [INFO] train episode 837: reward = -366.55
# 13:41:41 [INFO] train episode 838: reward = -130.49
# 13:41:43 [INFO] train episode 839: reward = -121.31
# 13:41:46 [INFO] train episode 840: reward = -375.51
# 13:41:48 [INFO] train episode 841: reward = -129.56
# 13:41:51 [INFO] train episode 842: reward = -256.35
# 13:41:53 [INFO] train episode 843: reward = -258.61
# 13:41:55 [INFO] train episode 844: reward = -259.16
# 13:41:58 [INFO] train episode 845: reward = -241.58
# 13:42:01 [INFO] train episode 846: reward = -222.96
# 13:42:03 [INFO] train episode 847: reward = -254.25
# 13:42:04 [INFO] train episode 848: reward = -248.18
# 13:42:06 [INFO] train episode 849: reward = -128.10
# 13:42:09 [INFO] train episode 850: reward = -121.97
# 13:42:11 [INFO] train episode 851: reward = -124.52
# 13:42:13 [INFO] train episode 852: reward = -9.04
# 13:42:16 [INFO] train episode 853: reward = -129.08
# 13:42:18 [INFO] train episode 854: reward = -126.90
# 13:42:20 [INFO] train episode 855: reward = -260.29
# 13:42:23 [INFO] train episode 856: reward = -127.64
# 13:42:25 [INFO] train episode 857: reward = -12.03
# 13:42:27 [INFO] train episode 858: reward = -239.51
# 13:42:29 [INFO] train episode 859: reward = -127.97
# 13:42:32 [INFO] train episode 860: reward = -124.66
# 13:42:34 [INFO] train episode 861: reward = -116.51
# 13:42:34 [INFO] train episode 862: reward = -258.33
# 13:42:37 [INFO] train episode 863: reward = -115.83
# 13:42:39 [INFO] train episode 864: reward = -241.75
# 13:42:41 [INFO] train episode 865: reward = -242.95
# 13:42:44 [INFO] train episode 866: reward = -122.14
# 13:42:46 [INFO] train episode 867: reward = -129.62
# 13:42:48 [INFO] train episode 868: reward = -124.09
# 13:42:50 [INFO] train episode 869: reward = -129.55
# 13:42:53 [INFO] train episode 870: reward = -238.92
# 13:42:55 [INFO] train episode 871: reward = -128.29
# 13:42:57 [INFO] train episode 872: reward = -135.06
# 13:43:00 [INFO] train episode 873: reward = -252.07
# 13:43:02 [INFO] train episode 874: reward = -9.75
# 13:43:04 [INFO] train episode 875: reward = -149.47
# 13:43:06 [INFO] train episode 876: reward = -9.64
# 13:43:06 [INFO] train episode 877: reward = -132.08
# 13:43:08 [INFO] train episode 878: reward = -382.44
# 13:43:10 [INFO] train episode 879: reward = -363.69
# 13:43:12 [INFO] train episode 880: reward = -146.10
# 13:43:14 [INFO] train episode 881: reward = -10.21
# 13:43:16 [INFO] train episode 882: reward = -136.28
# 13:43:18 [INFO] train episode 883: reward = -130.71
# 13:43:20 [INFO] train episode 884: reward = -135.74
# 13:43:23 [INFO] train episode 885: reward = -139.86
# 13:43:25 [INFO] train episode 886: reward = -136.13
# 13:43:27 [INFO] train episode 887: reward = -128.62
# 13:43:29 [INFO] train episode 888: reward = -130.85
# 13:43:31 [INFO] train episode 889: reward = -25.61
# 13:43:33 [INFO] train episode 890: reward = -378.88
# 13:43:36 [INFO] train episode 891: reward = -260.61
# 13:43:36 [INFO] train episode 892: reward = -488.75
# 13:43:38 [INFO] train episode 893: reward = -9.59
# 13:43:40 [INFO] train episode 894: reward = -393.23
# 13:43:42 [INFO] train episode 895: reward = -367.82
# 13:43:45 [INFO] train episode 896: reward = -10.75
# 13:43:47 [INFO] train episode 897: reward = -252.70
# 13:43:49 [INFO] train episode 898: reward = -257.49
# 13:43:51 [INFO] train episode 899: reward = -130.09
# 13:43:54 [INFO] train episode 900: reward = -375.38
# 13:43:56 [INFO] train episode 901: reward = -135.79
# 13:43:58 [INFO] train episode 902: reward = -243.84
# 13:44:00 [INFO] train episode 903: reward = -261.53
# 13:44:02 [INFO] train episode 904: reward = -131.97
# 13:44:04 [INFO] train episode 905: reward = -119.98
# 13:44:06 [INFO] train episode 906: reward = -129.86
# 13:44:06 [INFO] train episode 907: reward = -5.63
# 13:44:09 [INFO] train episode 908: reward = -241.50
# 13:44:11 [INFO] train episode 909: reward = -242.11
# 13:44:13 [INFO] train episode 910: reward = -130.45
# 13:44:15 [INFO] train episode 911: reward = -128.29
# 13:44:18 [INFO] train episode 912: reward = -121.78
# 13:44:20 [INFO] train episode 913: reward = -120.26
# 13:44:22 [INFO] train episode 914: reward = -133.71
# ...
# 14:03:06 [INFO] train episode 1449: reward = -593.19
# 14:03:09 [INFO] train episode 1450: reward = -483.14
# 14:03:09 [INFO] train episode 1451: reward = -269.34
# 14:03:11 [INFO] train episode 1452: reward = -512.95
# 14:03:14 [INFO] train episode 1453: reward = -387.46
# 14:03:16 [INFO] train episode 1454: reward = -383.04
# 14:03:18 [INFO] train episode 1455: reward = -273.03
# 14:03:21 [INFO] train episode 1456: reward = -272.12
# 14:03:23 [INFO] train episode 1457: reward = -512.31
# 14:03:26 [INFO] train episode 1458: reward = -276.20
# 14:03:28 [INFO] train episode 1459: reward = -390.29
# 14:03:31 [INFO] train episode 1460: reward = -385.03
# 14:03:33 [INFO] train episode 1461: reward = -510.81
# 14:03:35 [INFO] train episode 1462: reward = -645.09
# 14:03:37 [INFO] train episode 1463: reward = -483.68
# 14:03:40 [INFO] train episode 1464: reward = -360.73
# 14:03:40 [INFO] train episode 1465: reward = -510.65
# 14:03:42 [INFO] train episode 1466: reward = -626.58
# 14:03:44 [INFO] train episode 1467: reward = -626.71
# 14:03:47 [INFO] train episode 1468: reward = -735.37
# 14:03:49 [INFO] train episode 1469: reward = -534.19
# 14:03:51 [INFO] train episode 1470: reward = -386.13
# 14:03:53 [INFO] train episode 1471: reward = -487.95
# 14:03:56 [INFO] train episode 1472: reward = -509.13
# 14:03:58 [INFO] train episode 1473: reward = -607.63
# 14:04:00 [INFO] train episode 1474: reward = -505.33
# 14:04:03 [INFO] train episode 1475: reward = -633.79
# 14:04:05 [INFO] train episode 1476: reward = -493.74
# 14:04:07 [INFO] train episode 1477: reward = -504.53
# 14:04:09 [INFO] train episode 1478: reward = -255.29
# 14:04:08 [INFO] train episode 1479: reward = -257.95
# 14:04:11 [INFO] train episode 1480: reward = -255.70
# 14:04:13 [INFO] train episode 1481: reward = -388.95
# 14:04:15 [INFO] train episode 1482: reward = -491.05
# 14:04:17 [INFO] train episode 1483: reward = -8.21
# 14:04:19 [INFO] train episode 1484: reward = -132.68
# 14:04:21 [INFO] train episode 1485: reward = -380.35
# 14:04:23 [INFO] train episode 1486: reward = -259.37
# 14:04:25 [INFO] train episode 1487: reward = -250.96
# 14:04:27 [INFO] train episode 1488: reward = -322.51
# 14:04:30 [INFO] train episode 1489: reward = -254.14
# 14:04:32 [INFO] train episode 1490: reward = -366.90
# 14:04:34 [INFO] train episode 1491: reward = -250.33
# 14:04:36 [INFO] train episode 1492: reward = -258.40
# 14:04:38 [INFO] train episode 1493: reward = -126.17
# 14:04:41 [INFO] train episode 1494: reward = -127.41
# 14:04:43 [INFO] train episode 1495: reward = -5.42
# 14:04:45 [INFO] train episode 1496: reward = -490.79
# 14:04:48 [INFO] train episode 1497: reward = -125.09
# 14:04:50 [INFO] train episode 1498: reward = -4.53
# 14:04:52 [INFO] train episode 1499: reward = -244.56
# 14:04:55 [INFO] train episode 1500: reward = -246.41
# 14:04:54 [INFO] train episode 1501: reward = -4.10
# 14:04:56 [INFO] train episode 1502: reward = -256.58
# 14:04:58 [INFO] train episode 1503: reward = -255.58
# 14:05:01 [INFO] train episode 1504: reward = -375.32
# 14:05:03 [INFO] train episode 1505: reward = -376.04
# 14:05:05 [INFO] train episode 1506: reward = -120.69
# 14:05:08 [INFO] train episode 1507: reward = -3.69
# 14:05:10 [INFO] train episode 1508: reward = -4.07
# 14:05:12 [INFO] train episode 1509: reward = -2.69
# 14:05:15 [INFO] train episode 1510: reward = -123.52
# 14:05:17 [INFO] train episode 1511: reward = -480.33
# 14:05:19 [INFO] train episode 1512: reward = -2.67
# 14:05:22 [INFO] train episode 1513: reward = -253.49
# 14:05:24 [INFO] train episode 1514: reward = -251.64
# 14:05:24 [INFO] train episode 1515: reward = -328.68
# 14:05:27 [INFO] train episode 1516: reward = -126.46
# 14:05:29 [INFO] train episode 1517: reward = -254.98
# 14:05:32 [INFO] train episode 1518: reward = -120.06
# 14:05:34 [INFO] train episode 1519: reward = -124.88
# 14:05:36 [INFO] train episode 1520: reward = -128.95
# 14:05:39 [INFO] train episode 1521: reward = -473.33
# 14:05:42 [INFO] train episode 1522: reward = -381.26
# 14:05:44 [INFO] train episode 1523: reward = -126.30
# 14:05:46 [INFO] train episode 1524: reward = -4.63
# 14:05:49 [INFO] train episode 1525: reward = -242.94
# 14:05:51 [INFO] train episode 1526: reward = -371.24
# 14:05:53 [INFO] train episode 1527: reward = -357.13
# 14:05:55 [INFO] train episode 1528: reward = -363.46
# 14:05:57 [INFO] train episode 1529: reward = -126.27
# 14:06:00 [INFO] train episode 1530: reward = -255.41
# 14:06:03 [INFO] train episode 1531: reward = -474.91
# 14:06:05 [INFO] train episode 1532: reward = -2.28
# 14:06:07 [INFO] train episode 1533: reward = -123.67
# 14:06:10 [INFO] train episode 1534: reward = -2.31
# 14:06:12 [INFO] train episode 1535: reward = -120.69
# 14:06:14 [INFO] train episode 1536: reward = -380.70
# 14:06:16 [INFO] train episode 1537: reward = -356.70
# 14:06:18 [INFO] train episode 1538: reward = -123.53
# 14:06:20 [INFO] train episode 1539: reward = -117.58
# 14:06:22 [INFO] train episode 1540: reward = -466.79
# 14:06:24 [INFO] train episode 1541: reward = -121.07
# 14:06:24 [INFO] train episode 1542: reward = -387.07
# 14:06:26 [INFO] train episode 1543: reward = -253.31
# 14:06:29 [INFO] train episode 1544: reward = -126.80
# 14:06:31 [INFO] train episode 1545: reward = -121.35
# 14:06:34 [INFO] train episode 1546: reward = -3.05
# 14:06:36 [INFO] train episode 1547: reward = -253.36
# 14:06:39 [INFO] train episode 1548: reward = -118.82
# 14:06:42 [INFO] train episode 1549: reward = -3.18
# 14:06:44 [INFO] train episode 1550: reward = -3.87
# 14:06:47 [INFO] train episode 1551: reward = -122.52
# 14:06:50 [INFO] train episode 1552: reward = -245.19
# 14:06:53 [INFO] train episode 1553: reward = -367.44
# 14:06:55 [INFO] train episode 1554: reward = -363.51
# 14:06:55 [INFO] train episode 1555: reward = -249.92
# 14:06:57 [INFO] train episode 1556: reward = -357.95
# 14:07:00 [INFO] train episode 1557: reward = -375.13
# 14:07:02 [INFO] train episode 1558: reward = -4.38
# 14:07:05 [INFO] train episode 1559: reward = -252.82
# 14:07:07 [INFO] train episode 1560: reward = -251.95
# 14:07:10 [INFO] train episode 1561: reward = -228.96
# 14:07:12 [INFO] train episode 1562: reward = -248.37
# 14:07:15 [INFO] train episode 1563: reward = -230.39
# 14:07:17 [INFO] train episode 1564: reward = -126.44
# 14:07:19 [INFO] train episode 1565: reward = -240.39
# 14:07:22 [INFO] train episode 1566: reward = -226.47
# 14:07:24 [INFO] train episode 1567: reward = -127.68
# 14:07:24 [INFO] train episode 1568: reward = -245.98
# 14:07:26 [INFO] train episode 1569: reward = -120.35
# 14:07:28 [INFO] train episode 1570: reward = -356.89
# 14:07:30 [INFO] train episode 1571: reward = -231.76
# 14:07:32 [INFO] train episode 1572: reward = -124.31
# 14:07:35 [INFO] train episode 1573: reward = -248.08
# 14:07:38 [INFO] train episode 1574: reward = -375.19
# 14:07:40 [INFO] train episode 1575: reward = -126.95
# 14:07:42 [INFO] train episode 1576: reward = -256.07
# 14:07:45 [INFO] train episode 1577: reward = -362.72
# 14:07:47 [INFO] train episode 1578: reward = -631.19
# 14:07:50 [INFO] train episode 1579: reward = -495.39
# 14:07:52 [INFO] train episode 1580: reward = -119.36
# 14:07:55 [INFO] train episode 1581: reward = -250.78
# 14:07:55 [INFO] train episode 1582: reward = -245.33
# 14:07:58 [INFO] train episode 1583: reward = -256.06
# 14:08:01 [INFO] train episode 1584: reward = -247.51
# 14:08:04 [INFO] train episode 1585: reward = -252.53
# 14:08:06 [INFO] train episode 1586: reward = -245.10
# 14:08:09 [INFO] train episode 1587: reward = -123.99
# 14:08:12 [INFO] train episode 1588: reward = -358.98
# 14:08:15 [INFO] train episode 1589: reward = -254.91
# 14:08:18 [INFO] train episode 1590: reward = -125.88
# 14:08:20 [INFO] train episode 1591: reward = -131.83
# 14:08:23 [INFO] train episode 1592: reward = -340.70
# 14:08:26 [INFO] train episode 1593: reward = -130.83
# 14:08:26 [INFO] train episode 1594: reward = -274.57
# 14:08:29 [INFO] train episode 1595: reward = -127.95
# 14:08:32 [INFO] train episode 1596: reward = -129.50
# 14:08:34 [INFO] train episode 1597: reward = -134.42
# 14:08:37 [INFO] train episode 1598: reward = -122.90
# 14:08:40 [INFO] train episode 1599: reward = -264.98
# 14:08:42 [INFO] train episode 1600: reward = -28.46
# 14:08:46 [INFO] train episode 1601: reward = -388.27
# 14:08:48 [INFO] train episode 1602: reward = -480.99
# 14:08:51 [INFO] train episode 1603: reward = -132.54
# 14:08:53 [INFO] train episode 1604: reward = -257.56
# 14:08:55 [INFO] train episode 1605: reward = -383.57
# 14:08:55 [INFO] train episode 1606: reward = -244.00
# 14:08:58 [INFO] train episode 1607: reward = -375.63
# 14:09:00 [INFO] train episode 1608: reward = -247.27
# 14:09:03 [INFO] train episode 1609: reward = -382.96
# 14:09:06 [INFO] train episode 1610: reward = -256.20
# 14:09:09 [INFO] train episode 1611: reward = -367.16
# 14:09:11 [INFO] train episode 1612: reward = -255.06
# 14:09:14 [INFO] train episode 1613: reward = -2.19
# 14:09:16 [INFO] train episode 1614: reward = -359.42
# 14:09:18 [INFO] train episode 1615: reward = -5.36
# 14:09:21 [INFO] train episode 1616: reward = -245.54
# 14:09:23 [INFO] train episode 1617: reward = -123.53
# 14:09:26 [INFO] train episode 1618: reward = -333.18
# 14:09:26 [INFO] train episode 1619: reward = -121.24
# 14:09:28 [INFO] train episode 1620: reward = -256.03
# 14:09:31 [INFO] train episode 1621: reward = -256.50
# 14:09:33 [INFO] train episode 1622: reward = -126.05
# 14:09:35 [INFO] train episode 1623: reward = -365.97
# 14:09:37 [INFO] train episode 1624: reward = -365.87
# 14:09:40 [INFO] train episode 1625: reward = -256.50
# 14:09:43 [INFO] train episode 1626: reward = -133.02
# 14:09:45 [INFO] train episode 1627: reward = -137.74
# 14:09:48 [INFO] train episode 1628: reward = -254.28
# 14:09:51 [INFO] train episode 1629: reward = -140.44
# 14:09:53 [INFO] train episode 1630: reward = -128.20
# 14:09:55 [INFO] train episode 1631: reward = -264.72
# 14:09:55 [INFO] train episode 1632: reward = -138.71
# 14:09:58 [INFO] train episode 1633: reward = -265.70
# 14:10:01 [INFO] train episode 1634: reward = -370.78
# 14:10:03 [INFO] train episode 1635: reward = -262.61
# 14:10:06 [INFO] train episode 1636: reward = -256.05
# 14:10:08 [INFO] train episode 1637: reward = -247.27
# 14:10:11 [INFO] train episode 1638: reward = -369.63
# 14:10:13 [INFO] train episode 1639: reward = -136.44
# 14:10:16 [INFO] train episode 1640: reward = -258.91
# 14:10:19 [INFO] train episode 1641: reward = -380.88
# 14:10:21 [INFO] train episode 1642: reward = -244.40
# 14:10:23 [INFO] train episode 1643: reward = -474.86
# 14:10:26 [INFO] train episode 1644: reward = -350.45
# 14:10:25 [INFO] train episode 1645: reward = -496.18
# 14:10:28 [INFO] train episode 1646: reward = -511.80
# 14:10:30 [INFO] train episode 1647: reward = -491.97
# 14:10:32 [INFO] train episode 1648: reward = -377.94
# 14:10:34 [INFO] train episode 1649: reward = -499.01
# 14:10:36 [INFO] train episode 1650: reward = -621.64
# 14:10:38 [INFO] train episode 1651: reward = -147.42
# 14:10:40 [INFO] train episode 1652: reward = -380.65
# 14:10:42 [INFO] train episode 1653: reward = -498.50
# 14:10:45 [INFO] train episode 1654: reward = -299.61
# 14:10:47 [INFO] train episode 1655: reward = -371.20
# 14:10:50 [INFO] train episode 1656: reward = -371.84
# 14:10:53 [INFO] train episode 1657: reward = -245.15
# 14:10:55 [INFO] train episode 1658: reward = -372.66
# 14:10:56 [INFO] train episode 1659: reward = -306.90
# 14:10:59 [INFO] train episode 1660: reward = -255.21
# 14:11:01 [INFO] train episode 1661: reward = -243.77
# 14:11:04 [INFO] train episode 1662: reward = -383.03
# 14:11:06 [INFO] train episode 1663: reward = -498.67
# 14:11:09 [INFO] train episode 1664: reward = -500.69
# 14:11:12 [INFO] train episode 1665: reward = -499.10
# 14:11:14 [INFO] train episode 1666: reward = -380.60
# 14:11:16 [INFO] train episode 1667: reward = -368.13
# 14:11:19 [INFO] train episode 1668: reward = -131.08
# 14:11:21 [INFO] train episode 1669: reward = -132.35
# 14:11:23 [INFO] train episode 1670: reward = -124.54
# 14:11:25 [INFO] train episode 1671: reward = -127.33
# 14:11:26 [INFO] train episode 1672: reward = -258.76
# 14:11:28 [INFO] train episode 1673: reward = -131.49
# 14:11:31 [INFO] train episode 1674: reward = -259.19
# 14:11:33 [INFO] train episode 1675: reward = -133.83
# 14:11:35 [INFO] train episode 1676: reward = -257.03
# 14:11:38 [INFO] train episode 1677: reward = -260.02
# 14:11:40 [INFO] train episode 1678: reward = -234.55
# 14:11:43 [INFO] train episode 1679: reward = -339.64
# 14:11:46 [INFO] train episode 1680: reward = -256.74
# 14:11:48 [INFO] train episode 1681: reward = -257.09
# 14:11:51 [INFO] train episode 1682: reward = -259.91
# 14:11:53 [INFO] train episode 1683: reward = -127.41
# 14:11:56 [INFO] train episode 1684: reward = -4.99
# 14:11:58 [INFO] train episode 1685: reward = -501.48
# 14:12:00 [INFO] train episode 1686: reward = -125.80
# 14:12:03 [INFO] train episode 1687: reward = -259.90
# 14:12:05 [INFO] train episode 1688: reward = -363.30
# 14:12:08 [INFO] train episode 1689: reward = -131.27
# 14:12:10 [INFO] train episode 1690: reward = -122.58
# 14:12:12 [INFO] train episode 1691: reward = -249.11
# 14:12:12 [INFO] train episode 1692: reward = -128.57
# 14:12:14 [INFO] train episode 1693: reward = -124.74
# 14:12:16 [INFO] train episode 1694: reward = -256.33
# 14:12:19 [INFO] train episode 1695: reward = -2.26
# 14:12:21 [INFO] train episode 1696: reward = -135.82
# 14:12:22 [INFO] train episode 1697: reward = -366.79
# 14:12:24 [INFO] train episode 1698: reward = -144.40
# 14:12:26 [INFO] train episode 1699: reward = -262.76
# 14:12:27 [INFO] train episode 1700: reward = -126.47
# 14:12:29 [INFO] train episode 1701: reward = -259.19
# 14:12:30 [INFO] train episode 1702: reward = -262.01
# 14:12:31 [INFO] train episode 1703: reward = -260.05
# 14:12:33 [INFO] train episode 1704: reward = -256.75
# 14:12:34 [INFO] train episode 1705: reward = -128.09
# 14:12:36 [INFO] train episode 1706: reward = -250.78
# 14:12:37 [INFO] train episode 1707: reward = -25.94
# 14:12:38 [INFO] train episode 1708: reward = -132.42
# 14:12:40 [INFO] train episode 1709: reward = -248.26
# 14:12:41 [INFO] train episode 1710: reward = -137.23
# 14:12:41 [INFO] train episode 1711: reward = -132.47
# 14:12:43 [INFO] train episode 1712: reward = -131.50
# 14:12:44 [INFO] train episode 1713: reward = -124.86
# 14:12:46 [INFO] train episode 1714: reward = -8.43
# 14:12:48 [INFO] train episode 1715: reward = -138.30
# 14:12:49 [INFO] train episode 1716: reward = -269.30
# 14:12:51 [INFO] train episode 1717: reward = -131.60
# 14:12:52 [INFO] train episode 1718: reward = -137.46
# 14:12:54 [INFO] train episode 1719: reward = -247.80
# 14:12:55 [INFO] train episode 1720: reward = -138.08
# 14:12:57 [INFO] train episode 1721: reward = -504.22
# 14:12:58 [INFO] train episode 1722: reward = -134.80
# 14:13:00 [INFO] train episode 1723: reward = -378.53
# 14:13:02 [INFO] train episode 1724: reward = -243.35
# 14:13:03 [INFO] train episode 1725: reward = -369.95
# 14:13:05 [INFO] train episode 1726: reward = -262.28
# 14:13:06 [INFO] train episode 1727: reward = -137.28
# 14:13:08 [INFO] train episode 1728: reward = -130.65
# 14:13:10 [INFO] train episode 1729: reward = -140.01
# 14:13:11 [INFO] train episode 1730: reward = -130.63
# 14:13:11 [INFO] train episode 1731: reward = -138.00
# 14:13:12 [INFO] train episode 1732: reward = -245.95
# 14:13:14 [INFO] train episode 1733: reward = -266.17
# 14:13:15 [INFO] train episode 1734: reward = -18.04
# 14:13:17 [INFO] train episode 1735: reward = -268.68
# 14:13:19 [INFO] train episode 1736: reward = -393.89
# 14:13:20 [INFO] train episode 1737: reward = -272.96
# 14:13:22 [INFO] train episode 1738: reward = -150.66
# 14:13:23 [INFO] train episode 1739: reward = -506.20
# 14:13:25 [INFO] train episode 1740: reward = -272.79
# 14:13:27 [INFO] train episode 1741: reward = -389.78
# 14:13:28 [INFO] train episode 1742: reward = -145.60
# 14:13:30 [INFO] train episode 1743: reward = -372.44
# 14:13:32 [INFO] train episode 1744: reward = -384.33
# 14:13:34 [INFO] train episode 1745: reward = -147.25
# 14:13:36 [INFO] train episode 1746: reward = -382.79
# 14:13:38 [INFO] train episode 1747: reward = -524.30
# 14:13:40 [INFO] train episode 1748: reward = -270.98
# 14:13:42 [INFO] train episode 1749: reward = -615.64
# 14:13:42 [INFO] train episode 1750: reward = -384.65

# %%
env.close()

# %%
from pathlib import Path
from datetime import datetime

def make_unique_path(path: str | Path) -> Path:
    """
    path が既に存在する場合、末尾に _1, _2, ... を付けて未使用のパスを返す。
    例: ddpg_final_20251221_235959.pth -> ddpg_final_20251221_235959_1.pth -> ...
    """
    p = Path(path)

    # 存在しないならそのまま使う
    if not p.exists():
        return p

    parent = p.parent
    stem = p.stem      # 拡張子抜きファイル名
    suffix = p.suffix  # ".pth"

    i = 1
    while True:
        cand = parent / f"{stem}_{i}{suffix}"
        if not cand.exists():
            return cand
        i += 1


# 推論用に eval モードにしておく（保存自体は train のままでも可）
agent.mode2eval()

stamp = datetime.now().strftime("%Y%m%d_%H%M%S")

models_dir = Path("./models")
models_dir.mkdir(parents=True, exist_ok=True)

base_path = models_dir / f"td3_final_{stamp}.pth"
save_path = make_unique_path(base_path)

agent.save_all(
    save_path.as_posix(),
    extra={
        "total_step": int(total_step),
        "reward_history": rh,  # 必要ならそのままでOK
    }
)

print(f"saved to {save_path}")
# Out:
# saved to models/td3_final_20260131_141342.pth
